# %%
import os
os.chdir( "../")

# %%
rp3_best_params = {'topK': 29,
 'alpha': 0.33723025040409343,
 'beta': 0.15542352567862933,
 'normalize_similarity': True}

slimen_best_params = {'topK': 638, 'l1_ratio': 0.026639245044358113, 'alpha': 0.001535792379351249}

# %%
import psutil
num_cpus = psutil.cpu_count(logical=False)
num_cpus
# Out:
# 8

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

seeds = [
    1811854, 3772146, 6407100, 6926227, 1340378, 
    68679, 3822303, 4058970, 1264160, 1100338, 
    6552126, 725363, 8362134, 9446122, 5256199, 
    4686339, 3830906, 7315366, 9428914, 5564236, 
    3420043, 9223036, 851434, 3300082, 7899660, 
    2053768, 4305274, 3709256, 8795594, 1418903, 
    7428566, 157832
]

seeds = seeds[:num_cpus]

urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation = []
urm_test = []
urm_train = []
urm_validation = []

for i in range(len(seeds)):
    a, b = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=seeds[i])
    c, d = split_train_in_two_percentage_global_sample(a, train_percentage = 0.80,seed=seeds[i])
    urm_train_validation.append(a)
    urm_test.append(b)
    urm_train.append(c)
    urm_validation.append(d)
# Out:
# Warning: 229 (1.81 %) of 12638 users have no train items
# Warning: 2166 (17.14 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2565 (20.30 %) of 12638 users have no sampled items
# Warning: 217 (1.72 %) of 12638 users have no train items
# Warning: 2150 (17.01 %) of 12638 users have no sampled items
# Warning: 453 (3.58 %) of 12638 users have no train items
# Warning: 2625 (20.77 %) of 12638 users have no sampled items
# Warning: 223 (1.76 %) of 12638 users have no train items
# Warning: 2190 (17.33 %) of 12638 users have no sampled items
# Warning: 446 (3.53 %) of 12638 users have no train items
# Warning: 2596 (20.54 %) of 12638 users have no sampled items
# Warning: 227 (1.80 %) of 12638 users have no train items
# Warning: 2194 (17.36 %) of 12638 users have no sampled items
# Warning: 450 (3.56 %) of 12638 users have no train items
# Warning: 2666 (21.10 %) of 12638 users have no sampled items
# Warning: 243 (1.92 %) of 12638 users have no train items
# Warning: 2165 (17.13 %) of 12638 users have no sampled items
# Warning: 474 (3.75 %) of 12638 users have no train items
# Warning: 2621 (20.74 %) of 12638 users have no sampled items
# Warning: 239 (1.89 %) of 12638 users have no train items
# Warning: 2145 (16.97 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2652 (20.98 %) of 12638 users have no sampled items
# Warning: 201 (1.59 %) of 12638 users have no train items
# Warning: 2171 (17.18 %) of 12638 users have no sampled items
# Warning: 443 (3.51 %) of 12638 users have no train items
# Warning: 2570 (20.34 %) of 12638 users have no sampled items
# Warning: 220 (1.74 %) of 12638 users have no train items
# Warning: 2198 (17.39 %) of 12638 users have no sampled items
# Warning: 467 (3.70 %) of 12638 users have no train items
# Warning: 2646 (20.94 %) of 12638 users have no sampled items

# %%
from Recommenders.Recommender_import_list import *
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from concurrent.futures import ProcessPoolExecutor

recommenderClass = SLIMElasticNetRecommender
earlystopping_keywargs = {}

def build_fold(fold, **hyperparams):
    recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1
    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )

    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]
    else:
        recommender.fit(**hyperparams)

    recommender.save_model("/home/japo/RecSys-Challenge/result_experiments_more_data/Hybrids/", recommender.RECOMMENDER_NAME + "_split_" + str(fold) + ".zip")
    return 1

def prepare_models(fold, hyperparameters):
    return build_fold(fold, **hyperparameters)

#with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
#    fold_results = list(executor.map(prepare_models, range(len(seeds)), [slimen_best_params]*len(seeds)))
# Out:
# 2024-01-04 20:52:08.638899: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-04 20:52:08.638925: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = []
for u in urm_validation:
    evaluator_validation.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2565 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2625 (20.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2596 (20.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2666 (21.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2621 (20.7%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2652 (21.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2570 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2646 (20.9%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = []
for u in urm_test:
    evaluator_test.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2166 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2150 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2190 (17.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2194 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2165 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2145 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2171 (17.2%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2198 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_more_data/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 500  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial
from skopt.space import Real, Integer, Categorical

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from concurrent.futures import ProcessPoolExecutor
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
import time
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping

# %%
n_points = 10000
n_jobs = 1  # Using all available CPUs
acq_func = 'gp_hedge'
acq_optimizer = 'auto'
verbose = True
n_restarts_optimizer = 10
xi = 0.01
kappa = 1.96
x0 = None
y0 = None
noise = 1e-5
random_state = int(os.getpid() + time.time()) % np.iinfo(int).max
model_counter=0

# %%
rp3_Ws = []
slim_Ws = []
for i in range(len(seeds)):
    rp3 = RP3betaRecommender(urm_train[i],verbose=True)
    rp3.load_model("result_experiments_more_data/Hybrids", rp3.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    W = rp3.W_sparse
    #W = (W - W.min()) / (W.max() - W.min())
    rp3_Ws.append(W)

    slim = SLIMElasticNetRecommender(urm_train[i], verbose=True)
    slim.load_model("result_experiments_more_data/Hybrids", slim.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    W = slim.W_sparse
    #W = (W - W.min()) / (W.max() - W.min())
    slim_Ws.append(W)
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_0.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_0.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_1.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_1.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_2.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_2.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_3.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_3.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_4.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_4.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_5.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_5.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_6.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_6.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_7.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_7.zip'
# SLIMElasticNetRecommender: Loading complete

# %%
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender

recommenderClass = ItemKNNSimilarityHybridRecommender

hyperparameters_range_dictionary = {
        "topK": Integer(5, 300),
        "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
        "beta": Real(low = 0, high = 1.35, prior = 'uniform'),
        "normalize_similarity": Categorical([True, False]),
        #"implicit" : Categorical([True])
}

hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "alpha" : Real(low = 0 , high=1, prior = 'uniform') 
}


#hyperparameters_range_dictionary = {
#                "topK": Integer(5, 1000),
#                "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
#                "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
#            }

#IALS
#hyperparameters_range_dictionary = {
#                "num_factors": Integer(1, 500),
#                "epochs": Integer(50,2500),
#                "confidence_scaling": Categorical(["linear", "log"]),
#                "alpha": Real(low = 1e-3, high = 50.0, prior = 'log-uniform'),
#                "epsilon": Real(low = 1e-3, high = 10.0, prior = 'log-uniform'),
#                "reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
#            }

hyperparameters_range_dictionary
# Out:
# {'topK': Integer(low=5, high=1000, prior='uniform', transform='identity'),
#  'alpha': Real(low=0, high=1, prior='uniform', transform='identity')}

# %%
if issubclass(recommenderClass, Incremental_Training_Early_Stopping):
    print("Using EarlyStop")

# %%
from concurrent.futures import ProcessPoolExecutor
import os

import multiprocessing
from skopt import dump
from skopt.callbacks import CheckpointSaver

# Define a function to save your optimization after every `n` calls
def checkpoint_saver(n_calls=10, checkpoint_path="checkpoint.pkl"):
    return CheckpointSaver(checkpoint_path, compress=9) # keyword arguments will be passed to `skopt.dump`

print(f"RUNNING ON {num_cpus} threads")

sum_map = lambda results: sum(item[metric_to_optimize] for item in results)

hyperparams = dict()
hyperparams_names = list()
hyperparams_values = list()

skopt_types = [Real, Integer, Categorical]

for name, hyperparam in hyperparameters_range_dictionary.items():
    if any(isinstance(hyperparam, sko_type) for sko_type in skopt_types):
        hyperparams_names.append(name)
        hyperparams_values.append(hyperparam)
        hyperparams[name] = hyperparam

columns = ["Fold",metric_to_optimize]
for h in hyperparams_names:
    columns.append(h)

fold_results_df = pd.DataFrame(columns=columns)
if os.path.exists(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv"):
    fold_results_df = pd.read_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")


def run_fold(fold, **hyperparams):
    # Fit the model on this fold and return the evaluation metric
    # ...
    
    if issubclass(recommenderClass, ItemKNNSimilarityHybridRecommender):
        recommender = recommenderClass(urm_train_validation[fold], rp3_Ws[fold], slim_Ws[fold], verbose=True)
    else:
        recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1

    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )
    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]        
    else:
        recommender.fit(**hyperparams)

    result, _ = evaluator_test[fold].evaluateRecommender(recommender)
    metric_result = result[metric_to_optimize].item()
    
    print(f"Fold {fold}: hyperparams {hyperparams}, ended with {metric_to_optimize} {metric_result}")

    return {'Fold': fold, metric_to_optimize: metric_result, 'epochs': epochs, **hyperparams}

def run_fold_wrapper(fold, hyperparameters):
    return run_fold(fold, **hyperparameters)


def evaluate_model(hyperparams):

    global fold_results_df

    current_fit_hyperparameters_dict = dict(zip(hyperparams_names, hyperparams))

    if issubclass(recommenderClass, ImplicitALSRecommender):
        fold_results=[]
        for i, seed in  enumerate(seeds):
            fold_results.append(run_fold(i, **current_fit_hyperparameters_dict))
    else:
        # Start the process pool
        with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
            fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))


    print(fold_results)
    for res in fold_results:
        fold_results_df = pd.concat([fold_results_df, pd.DataFrame([res])], ignore_index=True)
    fold_results_df.to_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")

    # Compute average score across all folds
    average_score = sum_map(fold_results) / len(fold_results)

    print(f"Finished trial with Average {metric_to_optimize}: {average_score}")

    return -average_score  # Assuming a score that needs to be minimized




from skopt import load
checkpointPath = output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl"
print(checkpointPath)
checkpoint_callback = checkpoint_saver(n_calls=1, checkpoint_path=checkpointPath)

if os.path.exists(checkpointPath):
    res = load(checkpointPath)
    #UNCOMMENT TO RESTART LAST CHECKPOINT
    x0 = res.x_iters
    y0 = res.func_vals
    model_counter = len(res.x_iters)
    res.fun

print(f"Still need to run {n_cases - model_counter} trials")

result = gp_minimize(evaluate_model, hyperparams_values,
                     base_estimator=None,
                     n_calls=max(0, n_cases - model_counter),
                     n_initial_points= max(0, n_random_starts - model_counter),
                     initial_point_generator = "random",
                     acq_func=acq_func,
                     acq_optimizer=acq_optimizer,
                     x0=x0,
                     y0=y0,
                     random_state=random_state,
                     verbose=verbose,
                     callback=[checkpoint_callback],
                     n_points=n_points,
                     n_restarts_optimizer=n_restarts_optimizer,
                     xi=xi,
                     kappa=kappa,
                     noise=noise,
                     n_jobs=1
                    )
# Out:
# RUNNING ON 8 threads
# result_experiments_more_data/ItemKNNSimilarityHybridRecommender_checkpoint.pkl
# Still need to run 500 trials
# Iteration No: 1 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
#
#
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.29 sec. Users per second: 1984
# Fold 1: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05111335101037678
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.25 sec. Users per second: 1995
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.24 sec. Users per second: 1992
# Fold 0: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05113999008694449
# Fold 7: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.0507106975612726
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.37 sec. Users per second: 1945
# Fold 2: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.051136729289725576
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.38 sec. Users per second: 1950
# Fold 5: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05074272114894487
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.43 sec. Users per second: 1928
# Fold 4: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05126986400403824
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.40 sec. Users per second: 1935
# Fold 3: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05047915412813991
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.56 sec. Users per second: 1882
# Fold 6: hyperparams {'topK': 756, 'alpha': 0.6269862009392201}, ended with MAP 0.05073731349168504
# [{'Fold': 0, 'MAP': 0.05113999008694449, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 1, 'MAP': 0.05111335101037678, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 2, 'MAP': 0.051136729289725576, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 3, 'MAP': 0.05047915412813991, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 4, 'MAP': 0.05126986400403824, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 5, 'MAP': 0.05074272114894487, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 6, 'MAP': 0.05073731349168504, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}, {'Fold': 7, 'MAP': 0.0507106975612726, 'epochs': -1, 'topK': 756, 'alpha': 0.6269862009392201}]
# Finished trial with Average MAP: 0.05091622759014093
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 10.0726
# Function value obtained: -0.0509
# Current minimum: -0.0509
# Iteration No: 2 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.19 sec. Users per second: 2017
# Fold 6: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.050239111280957795
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.24 sec. Users per second: 2002
# Fold 5: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.05023257379447269
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.21 sec. Users per second: 2004
# Fold 7: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.05035113726205725
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.27 sec. Users per second: 1986
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.28 sec. Users per second: 1987
# Fold 0: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.050556643111791054
# Fold 1: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.05059870388531749
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.32 sec. Users per second: 1963
# Fold 3: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.04990899308785249
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.38 sec. Users per second: 1940
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.36 sec. Users per second: 1953
# Fold 2: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.050470216066263646
# Fold 4: hyperparams {'topK': 490, 'alpha': 0.7568382577148763}, ended with MAP 0.05094305235382343
# [{'Fold': 0, 'MAP': 0.050556643111791054, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 1, 'MAP': 0.05059870388531749, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 2, 'MAP': 0.050470216066263646, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 3, 'MAP': 0.04990899308785249, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 4, 'MAP': 0.05094305235382343, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 5, 'MAP': 0.05023257379447269, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 6, 'MAP': 0.050239111280957795, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}, {'Fold': 7, 'MAP': 0.05035113726205725, 'epochs': -1, 'topK': 490, 'alpha': 0.7568382577148763}]
# Finished trial with Average MAP: 0.05041255385531698
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 9.8167
# Function value obtained: -0.0504
# Current minimum: -0.0509
# Iteration No: 3 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.38 sec. Users per second: 1946
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.44 sec. Users per second: 1930
# Fold 0: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.049428779087393244
# Fold 1: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.04988464518784939
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.35 sec. Users per second: 1950
# Fold 3: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.04918004869508185
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.36 sec. Users per second: 1954
# Fold 6: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.049618616179952425
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.42 sec. Users per second: 1926
# Fold 7: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.04965252311013865
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.45 sec. Users per second: 1926
# Fold 5: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.049590936663747635
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.49 sec. Users per second: 1909
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.46 sec. Users per second: 1914Fold 4: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.050205797523185734
#
# Fold 2: hyperparams {'topK': 801, 'alpha': 0.8846767881764088}, ended with MAP 0.04967206452514697
# [{'Fold': 0, 'MAP': 0.049428779087393244, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 1, 'MAP': 0.04988464518784939, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 2, 'MAP': 0.04967206452514697, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 3, 'MAP': 0.04918004869508185, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 4, 'MAP': 0.050205797523185734, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 5, 'MAP': 0.049590936663747635, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 6, 'MAP': 0.049618616179952425, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}, {'Fold': 7, 'MAP': 0.04965252311013865, 'epochs': -1, 'topK': 801, 'alpha': 0.8846767881764088}]
# Finished trial with Average MAP: 0.049654176371561984
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 9.9634
# Function value obtained: -0.0497
# Current minimum: -0.0509
# Iteration No: 4 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
#
#
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.40 sec. Users per second: 1945
# Fold 5: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05080216364953868
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.39 sec. Users per second: 1945
# Fold 4: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.051479840830314046EvaluatorHoldout: Processed 10472 (100.0%) in 5.39 sec. Users per second: 1942
#
# Fold 0: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05141848027089681
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.49 sec. Users per second: 1903
# Fold 3: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05063208996735476
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.41 sec. Users per second: 1933
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.60 sec. Users per second: 1872
# Fold 6: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05073804140298911
# Fold 1: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05136060259344065
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.55 sec. Users per second: 1881
# Fold 7: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.05083393769385187
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.59 sec. Users per second: 1868
# Fold 2: hyperparams {'topK': 993, 'alpha': 0.5351947471837013}, ended with MAP 0.0512933780901338
# [{'Fold': 0, 'MAP': 0.05141848027089681, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 1, 'MAP': 0.05136060259344065, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 2, 'MAP': 0.0512933780901338, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 3, 'MAP': 0.05063208996735476, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 4, 'MAP': 0.051479840830314046, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 5, 'MAP': 0.05080216364953868, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 6, 'MAP': 0.05073804140298911, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}, {'Fold': 7, 'MAP': 0.05083393769385187, 'epochs': -1, 'topK': 993, 'alpha': 0.5351947471837013}]
# Finished trial with Average MAP: 0.051069816812314955
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 10.4417
# Function value obtained: -0.0511
# Current minimum: -0.0511
# Iteration No: 5 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.19 sec. Users per second: 2011
# Fold 7: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.051031065651037405
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.24 sec. Users per second: 1996
# Fold 2: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.05122819511291049
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.22 sec. Users per second: 2006
# Fold 6: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.05091525368467232
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.22 sec. Users per second: 2003
# Fold 3: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.050329295927486715
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.21 sec. Users per second: 2010
# Fold 4: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.05143720284510937
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.25 sec. Users per second: 1999
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.32 sec. Users per second: 1968
# Fold 5: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.050498106069201916
# Fold 0: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.05162759421950651
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.19 sec. Users per second: 2019
# Fold 1: hyperparams {'topK': 665, 'alpha': 0.288069384192614}, ended with MAP 0.05112455429031572
# [{'Fold': 0, 'MAP': 0.05162759421950651, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 1, 'MAP': 0.05112455429031572, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 2, 'MAP': 0.05122819511291049, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 3, 'MAP': 0.050329295927486715, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 4, 'MAP': 0.05143720284510937, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 5, 'MAP': 0.050498106069201916, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 6, 'MAP': 0.05091525368467232, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}, {'Fold': 7, 'MAP': 0.051031065651037405, 'epochs': -1, 'topK': 665, 'alpha': 0.288069384192614}]
# Finished trial with Average MAP: 0.05102390847503005
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 9.9287
# Function value obtained: -0.0510
# Current minimum: -0.0511
# Iteration No: 6 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
#
#
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.23 sec. Users per second: 1996
# Fold 3: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.0502455043679676
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.27 sec. Users per second: 1987
# Fold 0: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.05150935753089164
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.35 sec. Users per second: 1952
# Fold 2: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.051013716455189165
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.26 sec. Users per second: 1994
# Fold 1: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.05087156296538503
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.33 sec. Users per second: 1962
# Fold 6: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.05076450780305804
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.32 sec. Users per second: 1973
# Fold 5: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.05039072155435523
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.35 sec. Users per second: 1959
# Fold 4: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.051332216326487906
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.34 sec. Users per second: 1957
# Fold 7: hyperparams {'topK': 701, 'alpha': 0.20082434076181405}, ended with MAP 0.050796186067019765
# [{'Fold': 0, 'MAP': 0.05150935753089164, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 1, 'MAP': 0.05087156296538503, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 2, 'MAP': 0.051013716455189165, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 3, 'MAP': 0.0502455043679676, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 4, 'MAP': 0.051332216326487906, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 5, 'MAP': 0.05039072155435523, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 6, 'MAP': 0.05076450780305804, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}, {'Fold': 7, 'MAP': 0.050796186067019765, 'epochs': -1, 'topK': 701, 'alpha': 0.20082434076181405}]
# Finished trial with Average MAP: 0.05086547163379428
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 9.9541
# Function value obtained: -0.0509
# Current minimum: -0.0511
# Iteration No: 7 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.48 sec. Users per second: 1906
# Fold 7: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.05059636699507433
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.66 sec. Users per second: 1848
# Fold 6: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.05039106276566914
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.69 sec. Users per second: 1840
# Fold 0: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.051294047922199736
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.75 sec. Users per second: 1820
# Fold 4: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.05104544338503156
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.79 sec. Users per second: 1813
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.79 sec. Users per second: 1813
# Fold 1: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.05063816319179649
# Fold 5: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.0501345227884356
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.55 sec. Users per second: 1881
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.86 sec. Users per second: 1783
# Fold 3: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.050021889229329534
# Fold 2: hyperparams {'topK': 963, 'alpha': 0.1149972097527199}, ended with MAP 0.05063537640681659
# [{'Fold': 0, 'MAP': 0.051294047922199736, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 1, 'MAP': 0.05063816319179649, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 2, 'MAP': 0.05063537640681659, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 3, 'MAP': 0.050021889229329534, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 4, 'MAP': 0.05104544338503156, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 5, 'MAP': 0.0501345227884356, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 6, 'MAP': 0.05039106276566914, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}, {'Fold': 7, 'MAP': 0.05059636699507433, 'epochs': -1, 'topK': 963, 'alpha': 0.1149972097527199}]
# Finished trial with Average MAP: 0.050594609085544126
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 10.5221
# Function value obtained: -0.0506
# Current minimum: -0.0511
# Iteration No: 8 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.03 sec. Users per second: 2075
# Fold 7: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05092650367937781
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.08 sec. Users per second: 2061
# Fold 0: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.051503696175440455
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.13 sec. Users per second: 2038
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.16 sec. Users per second: 2034
# Fold 2: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05120518243029778
# Fold 5: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05050349136763964
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.20 sec. Users per second: 2018
# Fold 1: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.051203843697408276
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.11 sec. Users per second: 2050
# Fold 6: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05076716164635384
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.10 sec. Users per second: 2047
# Fold 3: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05048698500848107
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.15 sec. Users per second: 2032
# Fold 4: hyperparams {'topK': 459, 'alpha': 0.31298791623538796}, ended with MAP 0.05151031223145276
# [{'Fold': 0, 'MAP': 0.051503696175440455, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 1, 'MAP': 0.051203843697408276, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 2, 'MAP': 0.05120518243029778, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 3, 'MAP': 0.05048698500848107, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 4, 'MAP': 0.05151031223145276, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 5, 'MAP': 0.05050349136763964, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 6, 'MAP': 0.05076716164635384, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}, {'Fold': 7, 'MAP': 0.05092650367937781, 'epochs': -1, 'topK': 459, 'alpha': 0.31298791623538796}]
# Finished trial with Average MAP: 0.051013397029556456
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 9.4169
# Function value obtained: -0.0510
# Current minimum: -0.0511
# Iteration No: 9 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10467 (100.0%) in 4.08 sec. Users per second: 2566
# EvaluatorHoldout: Processed 10444 (100.0%) in 4.11 sec. Users per second: 2539
# Fold 6: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05039492600326704
# Fold 3: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05004112637011963
# EvaluatorHoldout: Processed 10440 (100.0%) in 4.12 sec. Users per second: 2535
# Fold 7: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05059769734841622
# EvaluatorHoldout: Processed 10493 (100.0%) in 4.11 sec. Users per second: 2551
# Fold 5: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.050308009572519866
# EvaluatorHoldout: Processed 10448 (100.0%) in 4.26 sec. Users per second: 2452
# Fold 2: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05085153002625298
# EvaluatorHoldout: Processed 10488 (100.0%) in 4.19 sec. Users per second: 2505EvaluatorHoldout: Processed 10473 (100.0%) in 4.26 sec. Users per second: 2456
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 4.31 sec. Users per second: 2430
# Fold 4: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05121197895116594Fold 1: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.050792493007882654
# Fold 0: hyperparams {'topK': 146, 'alpha': 0.23435343817962412}, ended with MAP 0.05126804130743259
#
# [{'Fold': 0, 'MAP': 0.05126804130743259, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 1, 'MAP': 0.050792493007882654, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 2, 'MAP': 0.05085153002625298, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 3, 'MAP': 0.05004112637011963, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 4, 'MAP': 0.05121197895116594, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 5, 'MAP': 0.050308009572519866, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 6, 'MAP': 0.05039492600326704, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}, {'Fold': 7, 'MAP': 0.05059769734841622, 'epochs': -1, 'topK': 146, 'alpha': 0.23435343817962412}]
# Finished trial with Average MAP: 0.05068322532338212
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 6.5081
# Function value obtained: -0.0507
# Current minimum: -0.0511
# Iteration No: 10 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.11 sec. Users per second: 2042
# Fold 7: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.05090145882746516
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.09 sec. Users per second: 2054
# Fold 3: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.0505013207248946
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.18 sec. Users per second: 2024
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.19 sec. Users per second: 2022
# Fold 4: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.05149085554843278
# Fold 1: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.0513078022653256
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.24 sec. Users per second: 1992
# Fold 2: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.051280396187316744
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.22 sec. Users per second: 2005
# Fold 0: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.05153446226975694
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.29 sec. Users per second: 1985
# Fold 5: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.05082557305777604
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.31 sec. Users per second: 1972
# Fold 6: hyperparams {'topK': 554, 'alpha': 0.4601433648861374}, ended with MAP 0.050845078485520404
# [{'Fold': 0, 'MAP': 0.05153446226975694, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 1, 'MAP': 0.0513078022653256, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 2, 'MAP': 0.051280396187316744, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 3, 'MAP': 0.0505013207248946, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 4, 'MAP': 0.05149085554843278, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 5, 'MAP': 0.05082557305777604, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 6, 'MAP': 0.050845078485520404, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}, {'Fold': 7, 'MAP': 0.05090145882746516, 'epochs': -1, 'topK': 554, 'alpha': 0.4601433648861374}]
# Finished trial with Average MAP: 0.05108586842081103
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 9.9028
# Function value obtained: -0.0511
# Current minimum: -0.0511
# Iteration No: 11 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 4.35 sec. Users per second: 2410
# Fold 0: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.05133725459880957
# EvaluatorHoldout: Processed 10493 (100.0%) in 4.36 sec. Users per second: 2409
# Fold 5: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.050530531314149606
# EvaluatorHoldout: Processed 10473 (100.0%) in 4.39 sec. Users per second: 2387
# Fold 4: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.051255393688078264
# EvaluatorHoldout: Processed 10467 (100.0%) in 4.41 sec. Users per second: 2372
# Fold 6: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.050420334657222655
# EvaluatorHoldout: Processed 10440 (100.0%) in 4.51 sec. Users per second: 2314
# Fold 7: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.05066286565711903
# EvaluatorHoldout: Processed 10448 (100.0%) in 4.39 sec. Users per second: 2381
# Fold 2: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.05098358613481182
# EvaluatorHoldout: Processed 10488 (100.0%) in 4.48 sec. Users per second: 2342
# Fold 1: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.05092728045960379
# EvaluatorHoldout: Processed 10444 (100.0%) in 4.52 sec. Users per second: 2313
# Fold 3: hyperparams {'topK': 136, 'alpha': 0.3285370186912366}, ended with MAP 0.0503217386150176
# [{'Fold': 0, 'MAP': 0.05133725459880957, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 1, 'MAP': 0.05092728045960379, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 2, 'MAP': 0.05098358613481182, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 3, 'MAP': 0.0503217386150176, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 4, 'MAP': 0.051255393688078264, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 5, 'MAP': 0.050530531314149606, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 6, 'MAP': 0.050420334657222655, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}, {'Fold': 7, 'MAP': 0.05066286565711903, 'epochs': -1, 'topK': 136, 'alpha': 0.3285370186912366}]
# Finished trial with Average MAP: 0.05080487314060154
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 6.7382
# Function value obtained: -0.0508
# Current minimum: -0.0511
# Iteration No: 12 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 5.30 sec. Users per second: 1969
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.39 sec. Users per second: 1936
# Fold 3: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.050629016128346395
# Fold 7: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.05085834397616051
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.42 sec. Users per second: 1928
# Fold 2: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.05126206276282888
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.38 sec. Users per second: 1946
# Fold 0: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.05135373088629442
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.51 sec. Users per second: 1906
# Fold 5: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.05076164532969135
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.35 sec. Users per second: 1959
# Fold 4: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.051437218001240285
# EvaluatorHoldout: Processed 10488 (100.0%) in 5.44 sec. Users per second: 1928
# EvaluatorHoldout: Processed 10467 (100.0%) in 5.43 sec. Users per second: 1927
# Fold 1: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.05131320148196645
# Fold 6: hyperparams {'topK': 659, 'alpha': 0.5546846222607681}, ended with MAP 0.050692270188544976
# [{'Fold': 0, 'MAP': 0.05135373088629442, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 1, 'MAP': 0.05131320148196645, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 2, 'MAP': 0.05126206276282888, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 3, 'MAP': 0.050629016128346395, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 4, 'MAP': 0.051437218001240285, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 5, 'MAP': 0.05076164532969135, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 6, 'MAP': 0.050692270188544976, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}, {'Fold': 7, 'MAP': 0.05085834397616051, 'epochs': -1, 'topK': 659, 'alpha': 0.5546846222607681}]
# Finished trial with Average MAP: 0.05103843609438416
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 9.8817
# Function value obtained: -0.0510
# Current minimum: -0.0511
# Iteration No: 13 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ...
# Finished trial with Average MAP: 0.050193212507870705
# Iteration No: 200 ended. Search finished for the next optimal point.
# Time taken: 13.0118
# Function value obtained: -0.0502
# Current minimum: -0.0511
# Iteration No: 201 started. Searching for the next optimal point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 4.97 sec. Users per second: 2102
# Fold 3: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05050578140103273
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.05 sec. Users per second: 2079
# Fold 5: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05065801993468133
# EvaluatorHoldout: Processed 10467 (100.0%) in 4.97 sec. Users per second: 2106
# Fold 6: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05087386131166632
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.14 sec. Users per second: 2033EvaluatorHoldout: Processed 10488 (100.0%) in 5.15 sec. Users per second: 2038
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 5.08 sec. Users per second: 2061
# Fold 1: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05121394594578288
# Fold 2: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05127296710542361
# Fold 0: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05162460438720997
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.03 sec. Users per second: 2075
# Fold 7: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.05100248966125449
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.05 sec. Users per second: 2074
# Fold 4: hyperparams {'topK': 417, 'alpha': 0.3722591568132824}, ended with MAP 0.051415378016638924
# [{'Fold': 0, 'MAP': 0.05162460438720997, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 1, 'MAP': 0.05121394594578288, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 2, 'MAP': 0.05127296710542361, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 3, 'MAP': 0.05050578140103273, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 4, 'MAP': 0.051415378016638924, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 5, 'MAP': 0.05065801993468133, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 6, 'MAP': 0.05087386131166632, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}, {'Fold': 7, 'MAP': 0.05100248966125449, 'epochs': -1, 'topK': 417, 'alpha': 0.3722591568132824}]
# Finished trial with Average MAP: 0.05107088097046128
# Iteration No: 201 ended. Search finished for the next optimal point.
# Time taken: 12.1132
# Function value obtained: -0.0511
# Current minimum: -0.0511
# Iteration No: 202 started. Searching for the next optimal point.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 2.98 sec. Users per second: 3508
# Fold 3: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04869517243894935
# EvaluatorHoldout: Processed 10440 (100.0%) in 3.08 sec. Users per second: 3385
# EvaluatorHoldout: Processed 10473 (100.0%) in 3.06 sec. Users per second: 3425
# Fold 7: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04907094204220706
# Fold 4: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04934086744599576
# EvaluatorHoldout: Processed 10448 (100.0%) in 3.13 sec. Users per second: 3333
# Fold 2: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.049513060903279775
# EvaluatorHoldout: Processed 10488 (100.0%) in 3.13 sec. Users per second: 3353
# Fold 1: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04940175014831841
# EvaluatorHoldout: Processed 10493 (100.0%) in 3.15 sec. Users per second: 3328
# Fold 5: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04916626579473322
# EvaluatorHoldout: Processed 10467 (100.0%) in 3.17 sec. Users per second: 3305
# Fold 6: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.04872258011194751
# EvaluatorHoldout: Processed 10472 (100.0%) in 3.27 sec. Users per second: 3207
# Fold 0: hyperparams {'topK': 11, 'alpha': 0.6678779414541812}, ended with MAP 0.05002583988140773
# [{'Fold': 0, 'MAP': 0.05002583988140773, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 1, 'MAP': 0.04940175014831841, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 2, 'MAP': 0.049513060903279775, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 3, 'MAP': 0.04869517243894935, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 4, 'MAP': 0.04934086744599576, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 5, 'MAP': 0.04916626579473322, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 6, 'MAP': 0.04872258011194751, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}, {'Fold': 7, 'MAP': 0.04907094204220706, 'epochs': -1, 'topK': 11, 'alpha': 0.6678779414541812}]
# Finished trial with Average MAP: 0.049242059845854856
# Iteration No: 202 ended. Search finished for the next optimal point.
# Time taken: 6.7232
# Function value obtained: -0.0492
# Current minimum: -0.0511
# Iteration No: 203 started. Searching for the next optimal point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 4.91 sec. Users per second: 2128
# Fold 3: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.050398071650465774
# EvaluatorHoldout: Processed 10472 (100.0%) in 4.96 sec. Users per second: 2110
# Fold 0: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.051281709653558806
# EvaluatorHoldout: Processed 10467 (100.0%) in 4.97 sec. Users per second: 2105
# Fold 6: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.05052986256124745
# EvaluatorHoldout: Processed 10473 (100.0%) in 5.01 sec. Users per second: 2089
# Fold 4: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.051357788508318895
# EvaluatorHoldout: Processed 10488 (100.0%) in 4.98 sec. Users per second: 2106
# EvaluatorHoldout: Processed 10448 (100.0%) in 5.08 sec. Users per second: 2055
# EvaluatorHoldout: Processed 10493 (100.0%) in 5.08 sec. Users per second: 2065
# Fold 2: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.050997832804638446Fold 1: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.05089358738028718
#
# Fold 5: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.05047898145248829
# EvaluatorHoldout: Processed 10440 (100.0%) in 5.12 sec. Users per second: 2040
# Fold 7: hyperparams {'topK': 237, 'alpha': 0.30982995054121804}, ended with MAP 0.05081031822051984
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 120
#     116     res.fun
#     118 print(f"Still need to run {n_cases - model_counter} trials")
# --> 120 result = gp_minimize(evaluate_model, hyperparams_values,
#     121                      base_estimator=None,
#     122                      n_calls=max(0, n_cases - model_counter),
#     123                      n_initial_points= max(0, n_random_starts - model_counter),
#     124                      initial_point_generator = "random",
#     125                      acq_func=acq_func,
#     126                      acq_optimizer=acq_optimizer,
#     127                      x0=x0,
#     128                      y0=y0,
#     129                      random_state=random_state,
#     130                      verbose=verbose,
#     131                      callback=[checkpoint_callback],
#     132                      n_points=n_points,
#     133                      n_restarts_optimizer=n_restarts_optimizer,
#     134                      xi=xi,
#     135                      kappa=kappa,
#     136                      noise=noise,
#     137                      n_jobs=1
#     138                     )
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py:301, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299 for n in range(n_calls):
#     300     next_x = optimizer.ask()
# --> 301     next_y = func(next_x)
#     302     result = optimizer.tell(next_x, next_y)
#     303     result.specs = specs
#
# Cell In[25], line 87, in evaluate_model(hyperparams)
#      82 else:
#      83     # Start the process pool
#      84     with ProcessPoolExecutor(max_workers=num_cpus) as executor:
#      85         # Submit all tasks to the process pool and wait for them to complete
#      86         #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
# ---> 87         fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))
#      90 print(fold_results)
#      91 for res in fold_results:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/process.py:484, in _chain_from_iterable_of_lists(iterable)
#     478 def _chain_from_iterable_of_lists(iterable):
#     479     """
#     480     Specialized implementation of itertools.chain.from_iterable.
#     481     Each item in *iterable* should be a list.  This function is
#     482     careful not to keep references to yielded objects.
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#     486         while element:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield fs.pop().result()
#     620     else:
#     621         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
import pandas as pd

results_df = pd.DataFrame(result.x_iters, columns=[dim for dim in hyperparameters_range_dictionary])
results_df['score'] = result.func_vals

# %%
results_df['score'].min()
# Out:
# -0.030128708347317946

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'topK': 34,
#  'alpha': 0.28453879172230406,
#  'beta': 0.15344052347036438,
#  'normalize_similarity': True}

# %%
SLIMEN = {'topK': 530, 'l1_ratio': 0.05017569359096808, 'alpha': 0.001}
P3ALPHA = {'topK': 400, 'alpha': 1.6632815179401539, 'normalize_similarity': True}
RP3 = {'topK': 71, 'alpha': 0.31274648571776065, 'beta': 0.3586324430664178, 'normalize_similarity': True}

SLIMEN_KFOLD = {'Fold': 0, 'MAP': 0.029228665181843458, 'topK': 660, 'l1_ratio': 0.0012296801858497721, 'alpha': 0.001}
RP3_KFOLD = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}
IMPLICIT_IALS = {'num_factors': 128,
 'epochs': 478,
 'confidence_scaling': 'linear',
 'alpha': 3.358295366834473,
 'epsilon': 7.295986722921583,
 'reg': 6.292360640597378e-05}

# %%
#BEST 100 SINGLE SPLIT: 0.030123825632990115
OLD_BEST_PARAMS = {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}

# 0.030008733292970144
OLD_BEST_PARAMS = {'topK': 59,
 'alpha': 0.3764461506622426,
 'beta': 0.10277510174112,
 'normalize_similarity': True}

#0.030128708347317946
OLD_BEST_PARAMS = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}

old_res = 0
for i in range(len(seeds)):
    m = recommenderClass(urm_train[i])
    m.fit(**OLD_BEST_PARAMS)
    ris, _ = evaluator_validation[i].evaluateRecommender(m)
    old_res += ris["MAP"].item()
old_res = old_res / len(seeds)
old_res
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8617.41 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10073 (100.0%) in 2.34 sec. Users per second: 4304
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8584.56 column/sec. Elapsed time 2.59 sec
# EvaluatorHoldout: Processed 10013 (100.0%) in 2.34 sec. Users per second: 4283
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8529.22 column/sec. Elapsed time 2.61 sec
# EvaluatorHoldout: Processed 10042 (100.0%) in 2.25 sec. Users per second: 4469
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8330.07 column/sec. Elapsed time 2.67 sec
# EvaluatorHoldout: Processed 9972 (100.0%) in 2.29 sec. Users per second: 4357
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8599.09 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10017 (100.0%) in 2.27 sec. Users per second: 4406
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8633.67 column/sec. Elapsed time 2.57 sec
# EvaluatorHoldout: Processed 9986 (100.0%) in 2.29 sec. Users per second: 4356
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8543.68 column/sec. Elapsed time 2.60 sec
# EvaluatorHoldout: Processed 10068 (100.0%) in 2.29 sec. Users per second: 4396
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8694.54 column/sec. Elapsed time 2.56 sec
# EvaluatorHoldout: Processed 9992 (100.0%) in 2.16 sec. Users per second: 4622
# 0.030008733292970144

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt


regr = RandomForestRegressor(max_depth=2)

result_df_graph = results_df.copy()
result_df_graph["score"] *= -1

numerical_cols = result_df_graph.mean().notna()
numerical_cols = numerical_cols.index[numerical_cols]

numerical_df = result_df_graph[numerical_cols]
numerical_df = (numerical_df - numerical_df.mean())/(numerical_df.std() +1e-6)

y_train = numerical_df["score"]
X_train = numerical_df.copy()
X_train = X_train.drop(columns=["score"])

regr.fit(X_train, y_train)

plt.bar(X_train.columns, regr.feature_importances_)
plt.show()

# %%
final_model = ItemKNNSimilarityHybridRecommender(urm_all)
