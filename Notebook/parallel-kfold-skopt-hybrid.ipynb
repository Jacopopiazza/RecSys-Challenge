# %%
import os
os.chdir( "../")

# %%
import psutil
num_cpus = psutil.cpu_count(logical=False)
num_cpus
# Out:
# 8

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

seeds = [
    1811854, 3772146, 6407100, 6926227, 1340378, 
    68679, 3822303, 4058970, 1264160, 1100338, 
    6552126, 725363, 8362134, 9446122, 5256199, 
    4686339, 3830906, 7315366, 9428914, 5564236, 
    3420043, 9223036, 851434, 3300082, 7899660, 
    2053768, 4305274, 3709256, 8795594, 1418903, 
    7428566, 157832
]

seeds = seeds[:num_cpus]

urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation = []
urm_test = []
urm_train = []
urm_validation = []

for i in range(len(seeds)):
    a, b = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=seeds[i])
    c, d = split_train_in_two_percentage_global_sample(a, train_percentage = 0.80,seed=seeds[i])
    urm_train_validation.append(a)
    urm_test.append(b)
    urm_train.append(c)
    urm_validation.append(d)
# Out:
# Warning: 229 (1.81 %) of 12638 users have no train items
# Warning: 2166 (17.14 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2565 (20.30 %) of 12638 users have no sampled items
# Warning: 217 (1.72 %) of 12638 users have no train items
# Warning: 2150 (17.01 %) of 12638 users have no sampled items
# Warning: 453 (3.58 %) of 12638 users have no train items
# Warning: 2625 (20.77 %) of 12638 users have no sampled items
# Warning: 223 (1.76 %) of 12638 users have no train items
# Warning: 2190 (17.33 %) of 12638 users have no sampled items
# Warning: 446 (3.53 %) of 12638 users have no train items
# Warning: 2596 (20.54 %) of 12638 users have no sampled items
# Warning: 227 (1.80 %) of 12638 users have no train items
# Warning: 2194 (17.36 %) of 12638 users have no sampled items
# Warning: 450 (3.56 %) of 12638 users have no train items
# Warning: 2666 (21.10 %) of 12638 users have no sampled items
# Warning: 243 (1.92 %) of 12638 users have no train items
# Warning: 2165 (17.13 %) of 12638 users have no sampled items
# Warning: 474 (3.75 %) of 12638 users have no train items
# Warning: 2621 (20.74 %) of 12638 users have no sampled items
# Warning: 239 (1.89 %) of 12638 users have no train items
# Warning: 2145 (16.97 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2652 (20.98 %) of 12638 users have no sampled items
# Warning: 201 (1.59 %) of 12638 users have no train items
# Warning: 2171 (17.18 %) of 12638 users have no sampled items
# Warning: 443 (3.51 %) of 12638 users have no train items
# Warning: 2570 (20.34 %) of 12638 users have no sampled items
# Warning: 220 (1.74 %) of 12638 users have no train items
# Warning: 2198 (17.39 %) of 12638 users have no sampled items
# Warning: 467 (3.70 %) of 12638 users have no train items
# Warning: 2646 (20.94 %) of 12638 users have no sampled items

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = []
for u in urm_validation:
    evaluator_validation.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# 2024-01-03 23:05:05.276250: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-03 23:05:05.276275: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# EvaluatorHoldout: Ignoring 2565 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2625 (20.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2596 (20.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2666 (21.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2621 (20.7%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2652 (21.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2570 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2646 (20.9%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = []
for u in urm_test:
    evaluator_test.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2166 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2150 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2190 (17.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2194 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2165 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2145 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2171 (17.2%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2198 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_parallel/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 500  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial
from skopt.space import Real, Integer, Categorical

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from concurrent.futures import ProcessPoolExecutor
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
import time
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping

# %%
n_points = 10000
n_jobs = 1  # Using all available CPUs
acq_func = 'gp_hedge'
acq_optimizer = 'auto'
verbose = True
n_restarts_optimizer = 10
xi = 0.01
kappa = 1.96
x0 = None
y0 = None
noise = 1e-5
random_state = int(os.getpid() + time.time()) % np.iinfo(int).max
model_counter=0

# %%
rp3_Ws = []
slim_Ws = []
for i in range(len(seeds)):
    rp3 = RP3betaRecommender(urm_train[i],verbose=True)
    rp3.load_model("result_experiments_parallel/HybridBases", rp3.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    W = rp3.W_sparse
    W = (W - W.min()) / (W.max() - W.min())
    rp3_Ws.append(W)

    slim = SLIMElasticNetRecommender(urm_train[i], verbose=True)
    slim.load_model("result_experiments_parallel/HybridBases", slim.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    W = slim.W_sparse
    W = (W - W.min()) / (W.max() - W.min())
    slim_Ws.append(W)
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_0.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_0.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_1.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_1.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_2.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_2.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_3.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_3.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_4.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_4.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_5.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_5.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_6.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_6.zip'
# SLIMElasticNetRecommender: Loading complete
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_parallel/HybridBasesRP3betaRecommender_split_7.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_parallel/HybridBasesSLIMElasticNetRecommender_split_7.zip'
# SLIMElasticNetRecommender: Loading complete

# %%
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender

recommenderClass = ItemKNNSimilarityHybridRecommender

hyperparameters_range_dictionary = {
        "topK": Integer(5, 300),
        "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
        "beta": Real(low = 0, high = 1.35, prior = 'uniform'),
        "normalize_similarity": Categorical([True, False]),
        #"implicit" : Categorical([True])
}

hyperparameters_range_dictionary = {
    "topK": Integer(5, 100),
    "alpha" : Real(low = 0 , high=1, prior = 'uniform') 
}


#hyperparameters_range_dictionary = {
#                "topK": Integer(5, 1000),
#                "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
#                "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
#            }

#IALS
#hyperparameters_range_dictionary = {
#                "num_factors": Integer(1, 500),
#                "epochs": Integer(50,2500),
#                "confidence_scaling": Categorical(["linear", "log"]),
#                "alpha": Real(low = 1e-3, high = 50.0, prior = 'log-uniform'),
#                "epsilon": Real(low = 1e-3, high = 10.0, prior = 'log-uniform'),
#                "reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
#            }

hyperparameters_range_dictionary
# Out:
# {'topK': Integer(low=5, high=100, prior='uniform', transform='identity'),
#  'alpha': Real(low=0, high=1, prior='uniform', transform='identity')}

# %%
if issubclass(recommenderClass, Incremental_Training_Early_Stopping):
    print("Using EarlyStop")

# %%
from concurrent.futures import ProcessPoolExecutor
import os

import multiprocessing
from skopt import dump
from skopt.callbacks import CheckpointSaver

# Define a function to save your optimization after every `n` calls
def checkpoint_saver(n_calls=10, checkpoint_path="checkpoint.pkl"):
    return CheckpointSaver(checkpoint_path, compress=9) # keyword arguments will be passed to `skopt.dump`

print(f"RUNNING ON {num_cpus} threads")

sum_map = lambda results: sum(item[metric_to_optimize] for item in results)

hyperparams = dict()
hyperparams_names = list()
hyperparams_values = list()

skopt_types = [Real, Integer, Categorical]

for name, hyperparam in hyperparameters_range_dictionary.items():
    if any(isinstance(hyperparam, sko_type) for sko_type in skopt_types):
        hyperparams_names.append(name)
        hyperparams_values.append(hyperparam)
        hyperparams[name] = hyperparam

columns = ["Fold",metric_to_optimize]
for h in hyperparams_names:
    columns.append(h)

fold_results_df = pd.DataFrame(columns=columns)
if os.path.exists(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv"):
    fold_results_df = pd.read_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")


def run_fold(fold, **hyperparams):
    # Fit the model on this fold and return the evaluation metric
    # ...
    
    if issubclass(recommenderClass, ItemKNNSimilarityHybridRecommender):
        recommender = recommenderClass(urm_train[fold], rp3_Ws[fold], slim_Ws[fold], verbose=True)
    else:
        recommender = recommenderClass(urm_train[fold], verbose=True)
    epochs = -1

    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )
    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]        
    else:
        recommender.fit(**hyperparams)

    result, _ = evaluator_validation[fold].evaluateRecommender(recommender)
    metric_result = result[metric_to_optimize].item()
    
    print(f"Fold {fold}: hyperparams {hyperparams}, ended with {metric_to_optimize} {metric_result}")

    return {'Fold': fold, metric_to_optimize: metric_result, 'epochs': epochs, **hyperparams}

def run_fold_wrapper(fold, hyperparameters):
    return run_fold(fold, **hyperparameters)


def evaluate_model(hyperparams):

    global fold_results_df

    current_fit_hyperparameters_dict = dict(zip(hyperparams_names, hyperparams))

    if issubclass(recommenderClass, ImplicitALSRecommender):
        fold_results=[]
        for i, seed in  enumerate(seeds):
            fold_results.append(run_fold(i, **current_fit_hyperparameters_dict))
    else:
        # Start the process pool
        with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
            fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))


    print(fold_results)
    for res in fold_results:
        fold_results_df = pd.concat([fold_results_df, pd.DataFrame([res])], ignore_index=True)
    fold_results_df.to_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")

    # Compute average score across all folds
    average_score = sum_map(fold_results) / len(fold_results)

    print(f"Finished trial with Average {metric_to_optimize}: {average_score}")

    return -average_score  # Assuming a score that needs to be minimized




from skopt import load
checkpointPath = output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl"

checkpoint_callback = checkpoint_saver(n_calls=1, checkpoint_path=checkpointPath)

if os.path.exists(checkpointPath):
    res = load(checkpointPath)
    #UNCOMMENT TO RESTART LAST CHECKPOINT
    x0 = res.x_iters
    y0 = res.func_vals
    model_counter = len(res.x_iters)
    res.fun

print(f"Still need to run {n_cases - model_counter} trials")

result = gp_minimize(evaluate_model, hyperparams_values,
                     base_estimator=None,
                     n_calls=max(0, n_cases - model_counter),
                     n_initial_points= max(0, n_random_starts - model_counter),
                     initial_point_generator = "random",
                     acq_func=acq_func,
                     acq_optimizer=acq_optimizer,
                     x0=x0,
                     y0=y0,
                     random_state=random_state,
                     verbose=verbose,
                     callback=[checkpoint_callback],
                     n_points=n_points,
                     n_restarts_optimizer=n_restarts_optimizer,
                     xi=xi,
                     kappa=kappa,
                     noise=noise,
                     n_jobs=1
                    )
# Out:
# RUNNING ON 8 threads
# Still need to run 500 trials
# Iteration No: 1 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.49 sec. Users per second: 2885
# Fold 6: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.03128002204060033
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.71 sec. Users per second: 2687
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.70 sec. Users per second: 2710
# Fold 3: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.031284155158252835
# Fold 4: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.030964923122755134
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.71 sec. Users per second: 2692
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.67 sec. Users per second: 2735
# Fold 7: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.031082052149656453
# Fold 2: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.030347591702152833
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.72 sec. Users per second: 2691
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.77 sec. Users per second: 2645
# Fold 1: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.030756302521008604
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.75 sec. Users per second: 2689
# Fold 5: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.031233210621854947
# Fold 0: hyperparams {'topK': 45, 'alpha': 0.7911095367585851}, ended with MAP 0.03105932250129628
# [{'Fold': 0, 'MAP': 0.03105932250129628, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 1, 'MAP': 0.030756302521008604, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 2, 'MAP': 0.030347591702152833, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 3, 'MAP': 0.031284155158252835, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 4, 'MAP': 0.030964923122755134, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 5, 'MAP': 0.031233210621854947, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 6, 'MAP': 0.03128002204060033, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}, {'Fold': 7, 'MAP': 0.031082052149656453, 'epochs': -1, 'topK': 45, 'alpha': 0.7911095367585851}]
# Finished trial with Average MAP: 0.031000947477197175
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 4.9470
# Function value obtained: -0.0310
# Current minimum: -0.0310
# Iteration No: 2 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.84 sec. Users per second: 2626
# Fold 0: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030374689370768232
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.89 sec. Users per second: 2569
# Fold 7: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030454919491148695
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.90 sec. Users per second: 2556
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.95 sec. Users per second: 2539Fold 3: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030447252306458367
#
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.96 sec. Users per second: 2520
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.97 sec. Users per second: 2520
# Fold 4: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030406348889427875
# Fold 1: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030134365008029483
# Fold 5: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030855650291360535
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.94 sec. Users per second: 2546
# Fold 2: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.029822894636179112
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.99 sec. Users per second: 2526
# Fold 6: hyperparams {'topK': 21, 'alpha': 0.7653701126473482}, ended with MAP 0.030658734888473003
# [{'Fold': 0, 'MAP': 0.030374689370768232, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 1, 'MAP': 0.030134365008029483, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 2, 'MAP': 0.029822894636179112, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 3, 'MAP': 0.030447252306458367, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 4, 'MAP': 0.030406348889427875, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 5, 'MAP': 0.030855650291360535, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 6, 'MAP': 0.030658734888473003, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}, {'Fold': 7, 'MAP': 0.030454919491148695, 'epochs': -1, 'topK': 21, 'alpha': 0.7653701126473482}]
# Finished trial with Average MAP: 0.030394356860230662
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 4.8191
# Function value obtained: -0.0304
# Current minimum: -0.0310
# Iteration No: 3 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.84 sec. Users per second: 2625
# Fold 0: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.031175238221302186
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.91 sec. Users per second: 2569
# Fold 2: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.03043301862336937
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.91 sec. Users per second: 2558
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.93 sec. Users per second: 2535
# Fold 3: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.031232391171470763Fold 7: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.031113168312428007
#
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.90 sec. Users per second: 2568
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.95 sec. Users per second: 2537
# Fold 4: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.030918379231497175
# Fold 1: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.03080561936149697
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.95 sec. Users per second: 2546
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.99 sec. Users per second: 2500
# Fold 6: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.03146608222815035
# Fold 5: hyperparams {'topK': 72, 'alpha': 0.8705886696117097}, ended with MAP 0.03135431667827052
# [{'Fold': 0, 'MAP': 0.031175238221302186, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 1, 'MAP': 0.03080561936149697, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 2, 'MAP': 0.03043301862336937, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 3, 'MAP': 0.031232391171470763, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 4, 'MAP': 0.030918379231497175, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 5, 'MAP': 0.03135431667827052, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 6, 'MAP': 0.03146608222815035, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}, {'Fold': 7, 'MAP': 0.031113168312428007, 'epochs': -1, 'topK': 72, 'alpha': 0.8705886696117097}]
# Finished trial with Average MAP: 0.031062276728498164
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 5.5832
# Function value obtained: -0.0311
# Current minimum: -0.0311
# Iteration No: 4 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.74 sec. Users per second: 2678
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.72 sec. Users per second: 2707
# Fold 4: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.030935100804822525
# Fold 0: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.031231096330123616
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.83 sec. Users per second: 2600
# Fold 3: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.031246100191647964
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.85 sec. Users per second: 2602
# Fold 1: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.030903186968052828
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.86 sec. Users per second: 2590
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.86 sec. Users per second: 2590
# Fold 5: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.031289408346288246
# Fold 7: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.030985899830976212
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.91 sec. Users per second: 2571
# Fold 2: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.030409383762799707
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.97 sec. Users per second: 2535
# Fold 6: hyperparams {'topK': 61, 'alpha': 0.804164316816267}, ended with MAP 0.03143457426011085
# [{'Fold': 0, 'MAP': 0.031231096330123616, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 1, 'MAP': 0.030903186968052828, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 2, 'MAP': 0.030409383762799707, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 3, 'MAP': 0.031246100191647964, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 4, 'MAP': 0.030935100804822525, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 5, 'MAP': 0.031289408346288246, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 6, 'MAP': 0.03143457426011085, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}, {'Fold': 7, 'MAP': 0.030985899830976212, 'epochs': -1, 'topK': 61, 'alpha': 0.804164316816267}]
# Finished trial with Average MAP: 0.031054343811852743
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 5.4645
# Function value obtained: -0.0311
# Current minimum: -0.0311
# Iteration No: 5 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.
#
#
#
#
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.88 sec. Users per second: 2580
# Fold 4: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.030581681775901794
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.95 sec. Users per second: 2531
# Fold 7: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.030263695083050813
# EvaluatorHoldout: Processed 9972 (100.0%) in 4.03 sec. Users per second: 2476
# Fold 3: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.030596543337217497
# EvaluatorHoldout: Processed 10073 (100.0%) in 4.08 sec. Users per second: 2466
# EvaluatorHoldout: Processed 9986 (100.0%) in 4.03 sec. Users per second: 2476
# Fold 0: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.030602758592434158
# EvaluatorHoldout: Processed 10068 (100.0%) in 4.07 sec. Users per second: 2473
# Fold 5: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.03058516446835125
# Fold 6: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.03073134826040101
# EvaluatorHoldout: Processed 10013 (100.0%) in 4.08 sec. Users per second: 2453
# Fold 1: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.030314380987256445
# EvaluatorHoldout: Processed 10042 (100.0%) in 4.12 sec. Users per second: 2438
# Fold 2: hyperparams {'topK': 56, 'alpha': 0.468271751546112}, ended with MAP 0.029813513402440147
# [{'Fold': 0, 'MAP': 0.030602758592434158, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 1, 'MAP': 0.030314380987256445, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 2, 'MAP': 0.029813513402440147, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 3, 'MAP': 0.030596543337217497, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 4, 'MAP': 0.030581681775901794, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 5, 'MAP': 0.03058516446835125, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 6, 'MAP': 0.03073134826040101, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}, {'Fold': 7, 'MAP': 0.030263695083050813, 'epochs': -1, 'topK': 56, 'alpha': 0.468271751546112}]
# Finished trial with Average MAP: 0.030436135738381637
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 5.4459
# Function value obtained: -0.0304
# Current minimum: -0.0311
# Iteration No: 6 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10013 (100.0%) in 4.18 sec. Users per second: 2397
# Fold 1: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.030197826159326358
# EvaluatorHoldout: Processed 10073 (100.0%) in 4.26 sec. Users per second: 2365
# Fold 0: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.03043645278356899
# EvaluatorHoldout: Processed 9986 (100.0%) in 4.26 sec. Users per second: 2342
# Fold 5: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.030491354563055195
# EvaluatorHoldout: Processed 10068 (100.0%) in 4.28 sec. Users per second: 2355
# Fold 6: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.030566698040625694
# EvaluatorHoldout: Processed 9992 (100.0%) in 4.23 sec. Users per second: 2360
# Fold 7: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.030163825504848488
# EvaluatorHoldout: Processed 10017 (100.0%) in 4.37 sec. Users per second: 2293
# Fold 4: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.03031594701705531
# EvaluatorHoldout: Processed 9972 (100.0%) in 4.34 sec. Users per second: 2298
# EvaluatorHoldout: Processed 10042 (100.0%) in 4.38 sec. Users per second: 2290
# Fold 3: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.03044076986992173
# Fold 2: hyperparams {'topK': 100, 'alpha': 0.21838402935972118}, ended with MAP 0.029710252653142807
# [{'Fold': 0, 'MAP': 0.03043645278356899, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 1, 'MAP': 0.030197826159326358, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 2, 'MAP': 0.029710252653142807, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 3, 'MAP': 0.03044076986992173, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 4, 'MAP': 0.03031594701705531, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 5, 'MAP': 0.030491354563055195, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 6, 'MAP': 0.030566698040625694, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}, {'Fold': 7, 'MAP': 0.030163825504848488, 'epochs': -1, 'topK': 100, 'alpha': 0.21838402935972118}]
# Finished trial with Average MAP: 0.030290390823943074
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 6.2692
# Function value obtained: -0.0303
# Current minimum: -0.0311
# Iteration No: 7 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.
#
#
#
#
#
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.96 sec. Users per second: 2544
# Fold 6: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030576394012776953
# EvaluatorHoldout: Processed 9972 (100.0%) in 4.06 sec. Users per second: 2453
# Fold 3: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030441876142086963
# EvaluatorHoldout: Processed 9992 (100.0%) in 4.10 sec. Users per second: 2438
# Fold 7: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030133455971126342
# EvaluatorHoldout: Processed 9986 (100.0%) in 4.13 sec. Users per second: 2417
# Fold 5: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030530345658525342
# EvaluatorHoldout: Processed 10073 (100.0%) in 4.15 sec. Users per second: 2430
# Fold 0: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030447617314241126
# EvaluatorHoldout: Processed 10013 (100.0%) in 4.20 sec. Users per second: 2387
# EvaluatorHoldout: Processed 10042 (100.0%) in 4.11 sec. Users per second: 2442
# Fold 1: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030244606614575825
# Fold 2: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.02967847737913488
# EvaluatorHoldout: Processed 10017 (100.0%) in 4.19 sec. Users per second: 2389
# Fold 4: hyperparams {'topK': 93, 'alpha': 0.25242235189148826}, ended with MAP 0.030311494269266232
# [{'Fold': 0, 'MAP': 0.030447617314241126, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 1, 'MAP': 0.030244606614575825, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 2, 'MAP': 0.02967847737913488, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 3, 'MAP': 0.030441876142086963, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 4, 'MAP': 0.030311494269266232, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 5, 'MAP': 0.030530345658525342, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 6, 'MAP': 0.030576394012776953, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}, {'Fold': 7, 'MAP': 0.030133455971126342, 'epochs': -1, 'topK': 93, 'alpha': 0.25242235189148826}]
# Finished trial with Average MAP: 0.030295533420216708
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 5.9180
# Function value obtained: -0.0303
# Current minimum: -0.0311
# Iteration No: 8 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.58 sec. Users per second: 2789
# Fold 3: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029161573039431347
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.70 sec. Users per second: 2706
# Fold 4: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029641221035351207
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.76 sec. Users per second: 2655
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.70 sec. Users per second: 2700
# Fold 5: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.02949194348278084
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.76 sec. Users per second: 2676
# Fold 7: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029459555739830178
# Fold 0: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029329273289116695
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.74 sec. Users per second: 2688
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.82 sec. Users per second: 2621
# Fold 2: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.02873354925187245
# Fold 1: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029299727814159248
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.81 sec. Users per second: 2641
# Fold 6: hyperparams {'topK': 10, 'alpha': 0.6802907266053233}, ended with MAP 0.029719384376714748
# [{'Fold': 0, 'MAP': 0.029329273289116695, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 1, 'MAP': 0.029299727814159248, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 2, 'MAP': 0.02873354925187245, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 3, 'MAP': 0.029161573039431347, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 4, 'MAP': 0.029641221035351207, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 5, 'MAP': 0.02949194348278084, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 6, 'MAP': 0.029719384376714748, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}, {'Fold': 7, 'MAP': 0.029459555739830178, 'epochs': -1, 'topK': 10, 'alpha': 0.6802907266053233}]
# Finished trial with Average MAP: 0.02935452850365709
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 4.4938
# Function value obtained: -0.0294
# Current minimum: -0.0311
# Iteration No: 9 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.47 sec. Users per second: 2902
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.50 sec. Users per second: 2867
# Fold 6: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.030046891455562844
# Fold 2: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.029308795914302976
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.52 sec. Users per second: 2842
# Fold 1: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.02984666758610653
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.57 sec. Users per second: 2795
# Fold 7: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.02963819865416167
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.62 sec. Users per second: 2756
# Fold 5: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.02982005760445606EvaluatorHoldout: Processed 9972 (100.0%) in 3.65 sec. Users per second: 2736
#
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.65 sec. Users per second: 2762
# Fold 3: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.029919206317371355
# Fold 0: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.02971483566787869
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.59 sec. Users per second: 2790
# Fold 4: hyperparams {'topK': 40, 'alpha': 0.09654108245199391}, ended with MAP 0.02994097336115932
# [{'Fold': 0, 'MAP': 0.02971483566787869, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 1, 'MAP': 0.02984666758610653, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 2, 'MAP': 0.029308795914302976, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 3, 'MAP': 0.029919206317371355, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 4, 'MAP': 0.02994097336115932, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 5, 'MAP': 0.02982005760445606, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 6, 'MAP': 0.030046891455562844, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}, {'Fold': 7, 'MAP': 0.02963819865416167, 'epochs': -1, 'topK': 40, 'alpha': 0.09654108245199391}]
# Finished trial with Average MAP: 0.02977945332012493
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 4.7653
# Function value obtained: -0.0298
# Current minimum: -0.0311
# Iteration No: 10 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
#
#
#
#
#
#
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.77 sec. Users per second: 2665
# Fold 2: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.029548744479535385
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.84 sec. Users per second: 2624
# Fold 6: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.03044811945437727
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.85 sec. Users per second: 2599
# Fold 1: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.029908242300882106
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.83 sec. Users per second: 2607
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.87 sec. Users per second: 2579
# Fold 3: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.030494627019145928
# Fold 5: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.030326886212125866
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.92 sec. Users per second: 2551
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.89 sec. Users per second: 2575Fold 7: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.030029047047161733
#
# Fold 4: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.03032531601040155
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.94 sec. Users per second: 2556
# Fold 0: hyperparams {'topK': 34, 'alpha': 0.4239695055244179}, ended with MAP 0.030040576805195365
# [{'Fold': 0, 'MAP': 0.030040576805195365, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 1, 'MAP': 0.029908242300882106, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 2, 'MAP': 0.029548744479535385, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 3, 'MAP': 0.030494627019145928, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 4, 'MAP': 0.03032531601040155, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 5, 'MAP': 0.030326886212125866, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 6, 'MAP': 0.03044811945437727, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}, {'Fold': 7, 'MAP': 0.030029047047161733, 'epochs': -1, 'topK': 34, 'alpha': 0.4239695055244179}]
# Finished trial with Average MAP: 0.03014019491610315
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 5.0347
# Function value obtained: -0.0301
# Current minimum: -0.0311
# Iteration No: 11 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
#
#
#
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.56 sec. Users per second: 2801
# Fold 3: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.030675414971444034
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.56 sec. Users per second: 2831
# Fold 6: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.030683822231051327
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.67 sec. Users per second: 2723
# Fold 7: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.03030505753809423
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.76 sec. Users per second: 2669
# Fold 2: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.029686048753963773
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.81 sec. Users per second: 2645
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.77 sec. Users per second: 2650
# Fold 0: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.0306841052381112
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.79 sec. Users per second: 2643
# Fold 5: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.030792871925457765
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.84 sec. Users per second: 2611
# Fold 4: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.030122977446278107
# Fold 1: hyperparams {'topK': 48, 'alpha': 0.9835174767725354}, ended with MAP 0.03011942807683373
# [{'Fold': 0, 'MAP': 0.0306841052381112, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 1, 'MAP': 0.03011942807683373, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 2, 'MAP': 0.029686048753963773, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 3, 'MAP': 0.030675414971444034, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 4, 'MAP': 0.030122977446278107, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 5, 'MAP': 0.030792871925457765, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 6, 'MAP': 0.030683822231051327, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}, {'Fold': 7, 'MAP': 0.03030505753809423, 'epochs': -1, 'topK': 48, 'alpha': 0.9835174767725354}]
# Finished trial with Average MAP: 0.03038371577265427
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 5.0784
# Function value obtained: -0.0304
# Current minimum: -0.0311
# Iteration No: 12 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.82 sec. Users per second: 2623
# Fold 1: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.0305506016781361
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.80 sec. Users per second: 2622
# Fold 3: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.030975704193965618
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.89 sec. Users per second: 2566
# Fold 5: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.03099553263457762
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.92 sec. Users per second: 2564
# Fold 2: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.030099510626796326
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.94 sec. Users per second: 2556
# Fold 6: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.031045560821335763
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.94 sec. Users per second: 2534
# Fold 7: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.030634686320485244
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.96 sec. Users per second: 2528
# Fold 4: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.03073540061260959
# EvaluatorHoldout: Processed 10073 (100.0%) in 4.00 sec. Users per second: 2520
# Fold 0: hyperparams {'topK': 97, 'alpha': 0.5339371851508201}, ended with MAP 0.03078317961421335
# [{'Fold': 0, 'MAP': 0.03078317961421335, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 1, 'MAP': 0.0305506016781361, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 2, 'MAP': 0.030099510626796326, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 3, 'MAP': 0.030975704193965618, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 4, 'MAP': 0.03073540061260959, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 5, 'MAP': 0.03099553263457762, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 6, 'MAP': 0.031045560821335763, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}, {'Fold': 7, 'MAP': 0.030634686320485244, 'epochs': -1, 'topK': 97, 'alpha': 0.5339371851508201}]
# Finished trial with Average MAP: 0.03072752206276495
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 5.9150
# Function value obtained: -0.0307
# Current minimum: -0.0311
# Iteration No: 13 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# ...
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.72 sec. Users per second: 2702
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.78 sec. Users per second: 2664
# Fold 2: hyperparams {'topK': 66, 'alpha': 0.28216943156980806}, ended with MAP 0.02970765246283101
# Fold 0: hyperparams {'topK': 66, 'alpha': 0.28216943156980806}, ended with MAP 0.030490715396652275
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.73 sec. Users per second: 2682
# Fold 1: hyperparams {'topK': 66, 'alpha': 0.28216943156980806}, ended with MAP 0.03008880518817622
# [{'Fold': 0, 'MAP': 0.030490715396652275, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 1, 'MAP': 0.03008880518817622, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 2, 'MAP': 0.02970765246283101, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 3, 'MAP': 0.03032427702328453, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 4, 'MAP': 0.030399309269480146, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 5, 'MAP': 0.030456563792484348, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 6, 'MAP': 0.030532848850042288, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}, {'Fold': 7, 'MAP': 0.030066080642291826, 'epochs': -1, 'topK': 66, 'alpha': 0.28216943156980806}]
# Finished trial with Average MAP: 0.03025828157815533
# Iteration No: 313 ended. Search finished for the next optimal point.
# Time taken: 15.3091
# Function value obtained: -0.0303
# Current minimum: -0.0311
# Iteration No: 314 started. Searching for the next optimal point.
# ItemKNNSimilarityHybridRecommender: URM Detected 443 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 481 ( 3.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 453 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 446 ( 3.5%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 467 ( 3.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 450 ( 3.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 474 ( 3.8%) users with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 346 ( 1.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 315 ( 1.4%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 323 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 298 ( 1.3%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 329 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 328 ( 1.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 355 ( 1.6%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 320 ( 1.4%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 9986 (100.0%) in 3.48 sec. Users per second: 2872
# Fold 5: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.031372210777628674
# EvaluatorHoldout: Processed 10073 (100.0%) in 3.48 sec. Users per second: 2892
# Fold 0: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.031254481176302036
# EvaluatorHoldout: Processed 10068 (100.0%) in 3.59 sec. Users per second: 2804
# EvaluatorHoldout: Processed 9972 (100.0%) in 3.58 sec. Users per second: 2788
# Fold 6: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.03146812784178715
# Fold 3: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.031272284619156064
# EvaluatorHoldout: Processed 10013 (100.0%) in 3.58 sec. Users per second: 2795
# Fold 1: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.030954425912979963
# EvaluatorHoldout: Processed 10017 (100.0%) in 3.68 sec. Users per second: 2725
# Fold 4: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.031009636792056892
# EvaluatorHoldout: Processed 10042 (100.0%) in 3.71 sec. Users per second: 2709
# Fold 2: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.030484243953174686
# EvaluatorHoldout: Processed 9992 (100.0%) in 3.67 sec. Users per second: 2725
# Fold 7: hyperparams {'topK': 68, 'alpha': 0.8417275717069336}, ended with MAP 0.031089391354353596
# [{'Fold': 0, 'MAP': 0.031254481176302036, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 1, 'MAP': 0.030954425912979963, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 2, 'MAP': 0.030484243953174686, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 3, 'MAP': 0.031272284619156064, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 4, 'MAP': 0.031009636792056892, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 5, 'MAP': 0.031372210777628674, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 6, 'MAP': 0.03146812784178715, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}, {'Fold': 7, 'MAP': 0.031089391354353596, 'epochs': -1, 'topK': 68, 'alpha': 0.8417275717069336}]
# Finished trial with Average MAP: 0.031113100303429883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 120
#     116     res.fun
#     118 print(f"Still need to run {n_cases - model_counter} trials")
# --> 120 result = gp_minimize(evaluate_model, hyperparams_values,
#     121                      base_estimator=None,
#     122                      n_calls=max(0, n_cases - model_counter),
#     123                      n_initial_points= max(0, n_random_starts - model_counter),
#     124                      initial_point_generator = "random",
#     125                      acq_func=acq_func,
#     126                      acq_optimizer=acq_optimizer,
#     127                      x0=x0,
#     128                      y0=y0,
#     129                      random_state=random_state,
#     130                      verbose=verbose,
#     131                      callback=[checkpoint_callback],
#     132                      n_points=n_points,
#     133                      n_restarts_optimizer=n_restarts_optimizer,
#     134                      xi=xi,
#     135                      kappa=kappa,
#     136                      noise=noise,
#     137                      n_jobs=1
#     138                     )
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py:304, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     302     result = optimizer.tell(next_x, next_y)
#     303     result.specs = specs
# --> 304     if eval_callbacks(callbacks, result):
#     305         break
#     307 return result
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/utils.py:99, in eval_callbacks(callbacks, result)
#      97 if callbacks:
#      98     for c in callbacks:
# ---> 99         decision = c(result)
#     100         if decision is not None:
#     101             stop = stop or decision
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/callbacks.py:287, in CheckpointSaver.__call__(self, res)
#     280 def __call__(self, res):
#     281     """
#     282     Parameters
#     283     ----------
#     284     res : `OptimizeResult`, scipy object
#     285         The optimization as a OptimizeResult object.
#     286     """
# --> 287     dump(res, self.checkpoint_path, **self.dump_options)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/utils.py:136, in dump(res, filename, store_objective, **kwargs)
#     107 """
#     108 Store an skopt optimization result into a file.
#     109
#    (...)
#     133     All other keyword arguments will be passed to `joblib.dump`.
#     134 """
#     135 if store_objective:
# --> 136     dump_(res, filename, **kwargs)
#     138 elif 'func' in res.specs['args']:
#     139     # If the user does not want to store the objective and it is indeed
#     140     # present in the provided object, then create a deep copy of it and
#     141     # remove the objective function before dumping it with joblib.dump.
#     142     res_without_func = deepcopy(res)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:550, in dump(value, filename, compress, protocol, cache_size)
#     547 if compress_level != 0:
#     548     with _write_fileobject(filename, compress=(compress_method,
#     549                                                compress_level)) as f:
# --> 550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
#     552     with open(filename, 'wb') as f:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:713, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     710     self._batch_appends(listitems)
#     712 if dictitems is not None:
# --> 713     self._batch_setitems(dictitems)
#     715 if state is not None:
#     716     if state_setter is None:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:997, in _Pickler._batch_setitems(self, items)
#     995     for k, v in tmp:
#     996         save(k)
# --> 997         save(v)
#     998     write(SETITEMS)
#     999 elif n:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:931, in _Pickler.save_list(self, obj)
#     928     self.write(MARK + LIST)
#     930 self.memoize(obj)
# --> 931 self._batch_appends(obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:955, in _Pickler._batch_appends(self, items)
#     953     write(MARK)
#     954     for x in tmp:
# --> 955         save(x)
#     956     write(APPENDS)
#     957 elif n:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:355, in NumpyPickler.save(self, obj)
#     352     wrapper.write_array(obj, self)
#     353     return
# --> 355 return Pickler.save(self, obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:971, in _Pickler.save_dict(self, obj)
#     968     self.write(MARK + DICT)
#     970 self.memoize(obj)
# --> 971 self._batch_setitems(obj.items())
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/pickle.py:997, in _Pickler._batch_setitems(self, items)
#     995     for k, v in tmp:
#     996         save(k)
# --> 997         save(v)
#     998     write(SETITEMS)
#     999 elif n:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:352, in NumpyPickler.save(self, obj)
#     349         self.framer.commit_frame(force=True)
#     351     # And then array bytes are written right after the wrapper.
# --> 352     wrapper.write_array(obj, self)
#     353     return
#     355 return Pickler.save(self, obj)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/numpy_pickle.py:134, in NumpyArrayWrapper.write_array(self, array, pickler)
#     126         pickler.file_handle.write(padding)
#     128 for chunk in pickler.np.nditer(array,
#     129                                flags=['external_loop',
#     130                                       'buffered',
#     131                                       'zerosize_ok'],
#     132                                buffersize=buffersize,
#     133                                order=self.order):
# --> 134     pickler.file_handle.write(chunk.tobytes('C'))
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/joblib/compressor.py:479, in BinaryZlibFile.write(self, data)
#     476 if isinstance(data, memoryview):
#     477     data = data.tobytes()
# --> 479 compressed = self._compressor.compress(data)
#     480 self._fp.write(compressed)
#     481 self._pos += len(data)
#
# KeyboardInterrupt:

# %%
import pandas as pd

results_df = pd.DataFrame(result.x_iters, columns=[dim for dim in hyperparameters_range_dictionary])
results_df['score'] = result.func_vals

# %%
results_df['score'].min()
# Out:
# -0.030128708347317946

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'topK': 34,
#  'alpha': 0.28453879172230406,
#  'beta': 0.15344052347036438,
#  'normalize_similarity': True}

# %%
SLIMEN = {'topK': 530, 'l1_ratio': 0.05017569359096808, 'alpha': 0.001}
P3ALPHA = {'topK': 400, 'alpha': 1.6632815179401539, 'normalize_similarity': True}
RP3 = {'topK': 71, 'alpha': 0.31274648571776065, 'beta': 0.3586324430664178, 'normalize_similarity': True}

SLIMEN_KFOLD = {'Fold': 0, 'MAP': 0.029228665181843458, 'topK': 660, 'l1_ratio': 0.0012296801858497721, 'alpha': 0.001}
RP3_KFOLD = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}
IMPLICIT_IALS = {'num_factors': 128,
 'epochs': 478,
 'confidence_scaling': 'linear',
 'alpha': 3.358295366834473,
 'epsilon': 7.295986722921583,
 'reg': 6.292360640597378e-05}

# %%
#BEST 100 SINGLE SPLIT: 0.030123825632990115
OLD_BEST_PARAMS = {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}

# 0.030008733292970144
OLD_BEST_PARAMS = {'topK': 59,
 'alpha': 0.3764461506622426,
 'beta': 0.10277510174112,
 'normalize_similarity': True}

#0.030128708347317946
OLD_BEST_PARAMS = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}

old_res = 0
for i in range(len(seeds)):
    m = recommenderClass(urm_train[i])
    m.fit(**OLD_BEST_PARAMS)
    ris, _ = evaluator_validation[i].evaluateRecommender(m)
    old_res += ris["MAP"].item()
old_res = old_res / len(seeds)
old_res
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8617.41 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10073 (100.0%) in 2.34 sec. Users per second: 4304
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8584.56 column/sec. Elapsed time 2.59 sec
# EvaluatorHoldout: Processed 10013 (100.0%) in 2.34 sec. Users per second: 4283
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8529.22 column/sec. Elapsed time 2.61 sec
# EvaluatorHoldout: Processed 10042 (100.0%) in 2.25 sec. Users per second: 4469
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8330.07 column/sec. Elapsed time 2.67 sec
# EvaluatorHoldout: Processed 9972 (100.0%) in 2.29 sec. Users per second: 4357
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8599.09 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10017 (100.0%) in 2.27 sec. Users per second: 4406
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8633.67 column/sec. Elapsed time 2.57 sec
# EvaluatorHoldout: Processed 9986 (100.0%) in 2.29 sec. Users per second: 4356
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8543.68 column/sec. Elapsed time 2.60 sec
# EvaluatorHoldout: Processed 10068 (100.0%) in 2.29 sec. Users per second: 4396
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8694.54 column/sec. Elapsed time 2.56 sec
# EvaluatorHoldout: Processed 9992 (100.0%) in 2.16 sec. Users per second: 4622
# 0.030008733292970144

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt


regr = RandomForestRegressor(max_depth=2)

result_df_graph = results_df.copy()
result_df_graph["score"] *= -1

numerical_cols = result_df_graph.mean().notna()
numerical_cols = numerical_cols.index[numerical_cols]

numerical_df = result_df_graph[numerical_cols]
numerical_df = (numerical_df - numerical_df.mean())/(numerical_df.std() +1e-6)

y_train = numerical_df["score"]
X_train = numerical_df.copy()
X_train = X_train.drop(columns=["score"])

regr.fit(X_train, y_train)

plt.bar(X_train.columns, regr.feature_importances_)
plt.show()

# %%
final_model = ItemKNNSimilarityHybridRecommender(urm_all)
