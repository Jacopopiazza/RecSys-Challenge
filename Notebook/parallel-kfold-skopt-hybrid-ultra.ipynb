# %%
import os
os.chdir( "../")

# %%
rp3_best_params = {'topK': 29,
 'alpha': 0.33723025040409343,
 'beta': 0.15542352567862933,
 'normalize_similarity': True}

slimen_best_params = {'topK': 638, 'l1_ratio': 0.026639245044358113, 'alpha': 0.001535792379351249}

# %%
import psutil
num_cpus = psutil.cpu_count(logical=False)
num_cpus
# Out:
# 8

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

seeds = [
    1811854, 3772146, 6407100, 6926227, 1340378, 
    68679, 3822303, 4058970, 1264160, 1100338, 
    6552126, 725363, 8362134, 9446122, 5256199, 
    4686339, 3830906, 7315366, 9428914, 5564236, 
    3420043, 9223036, 851434, 3300082, 7899660, 
    2053768, 4305274, 3709256, 8795594, 1418903, 
    7428566, 157832
]

seeds = seeds[:num_cpus]

urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation = []
urm_test = []
urm_train = []
urm_validation = []

for i in range(len(seeds)):
    a, b = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=seeds[i])
    c, d = split_train_in_two_percentage_global_sample(a, train_percentage = 0.80,seed=seeds[i])
    urm_train_validation.append(a)
    urm_test.append(b)
    urm_train.append(c)
    urm_validation.append(d)
# Out:
# Warning: 229 (1.81 %) of 12638 users have no train items
# Warning: 2166 (17.14 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2565 (20.30 %) of 12638 users have no sampled items
# Warning: 217 (1.72 %) of 12638 users have no train items
# Warning: 2150 (17.01 %) of 12638 users have no sampled items
# Warning: 453 (3.58 %) of 12638 users have no train items
# Warning: 2625 (20.77 %) of 12638 users have no sampled items
# Warning: 223 (1.76 %) of 12638 users have no train items
# Warning: 2190 (17.33 %) of 12638 users have no sampled items
# Warning: 446 (3.53 %) of 12638 users have no train items
# Warning: 2596 (20.54 %) of 12638 users have no sampled items
# Warning: 227 (1.80 %) of 12638 users have no train items
# Warning: 2194 (17.36 %) of 12638 users have no sampled items
# Warning: 450 (3.56 %) of 12638 users have no train items
# Warning: 2666 (21.10 %) of 12638 users have no sampled items
# Warning: 243 (1.92 %) of 12638 users have no train items
# Warning: 2165 (17.13 %) of 12638 users have no sampled items
# Warning: 474 (3.75 %) of 12638 users have no train items
# Warning: 2621 (20.74 %) of 12638 users have no sampled items
# Warning: 239 (1.89 %) of 12638 users have no train items
# Warning: 2145 (16.97 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2652 (20.98 %) of 12638 users have no sampled items
# Warning: 201 (1.59 %) of 12638 users have no train items
# Warning: 2171 (17.18 %) of 12638 users have no sampled items
# Warning: 443 (3.51 %) of 12638 users have no train items
# Warning: 2570 (20.34 %) of 12638 users have no sampled items
# Warning: 220 (1.74 %) of 12638 users have no train items
# Warning: 2198 (17.39 %) of 12638 users have no sampled items
# Warning: 467 (3.70 %) of 12638 users have no train items
# Warning: 2646 (20.94 %) of 12638 users have no sampled items

# %%
from Recommenders.Recommender_import_list import *
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from concurrent.futures import ProcessPoolExecutor

recommenderClass = SLIMElasticNetRecommender
earlystopping_keywargs = {}

def build_fold(fold, **hyperparams):
    recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1
    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )

    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]
    else:
        recommender.fit(**hyperparams)

    recommender.save_model("/home/japo/RecSys-Challenge/result_experiments_more_data/Hybrids/", recommender.RECOMMENDER_NAME + "_split_" + str(fold) + ".zip")
    return 1

def prepare_models(fold, hyperparameters):
    return build_fold(fold, **hyperparameters)

#with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
#    fold_results = list(executor.map(prepare_models, range(len(seeds)), [slimen_best_params]*len(seeds)))
# Out:
# 2024-01-04 21:34:40.106934: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-04 21:34:40.106963: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = []
for u in urm_validation:
    evaluator_validation.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2565 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2625 (20.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2596 (20.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2666 (21.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2621 (20.7%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2652 (21.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2570 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2646 (20.9%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = []
for u in urm_test:
    evaluator_test.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2166 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2150 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2190 (17.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2194 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2165 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2145 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2171 (17.2%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2198 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_more_data/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 500  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial
from skopt.space import Real, Integer, Categorical

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from concurrent.futures import ProcessPoolExecutor
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
import time
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender

# %%
n_points = 10000
n_jobs = 1  # Using all available CPUs
acq_func = 'gp_hedge'
acq_optimizer = 'auto'
verbose = True
n_restarts_optimizer = 10
xi = 0.01
kappa = 1.96
x0 = None
y0 = None
noise = 1e-5
random_state = int(os.getpid() + time.time()) % np.iinfo(int).max
model_counter=0

# %%
rp3s = []
slims = []
ials = []
KNNs = []
for i in range(len(seeds)):
    rp3 = RP3betaRecommender(urm_train_validation[i],verbose=True)
    rp3.load_model("result_experiments_more_data/Hybrids", rp3.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    rp3s.append(rp3)

    slim = SLIMElasticNetRecommender(urm_train_validation[i], verbose=True)
    slim.load_model("result_experiments_more_data/Hybrids", slim.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    slims.append(slim)

    ials_model = ImplicitALSRecommender(urm_train_validation[i], verbose=True)
    ials_model.fit(**{'use_gpu': True, 'num_threads' : 1, 'num_factors': 128, 'epochs': 478, 'confidence_scaling': 'linear', 'alpha': 3.358295366834473, 'epsilon': 7.295986722921583, 'reg': 6.292360640597378e-05})
    ials.append(ials_model)

    knn = ItemKNNCFRecommender(urm_train_validation[i], verbose=True)
    knn.fit(**{'topK': 19, 'shrink': 28, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 1.3672226785339947})
    KNNs.append(knn)
# Out:
# RP3betaRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_0.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_0.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Similarity column 22222 (100.0%), 12916.91 column/sec. Elapsed time 1.72 sec
# RP3betaRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# RP3betaRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_1.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_1.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ImplicitALSRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12874.20 column/sec. Elapsed time 1.73 sec
# RP3betaRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_2.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_2.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12754.93 column/sec. Elapsed time 1.74 sec
# RP3betaRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_3.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_3.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12905.99 column/sec. Elapsed time 1.72 sec
# RP3betaRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# RP3betaRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_4.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_4.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ImplicitALSRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12756.28 column/sec. Elapsed time 1.74 sec
# RP3betaRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# RP3betaRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_5.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_5.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ImplicitALSRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12711.25 column/sec. Elapsed time 1.75 sec
# RP3betaRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# RP3betaRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_6.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_6.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ImplicitALSRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12906.30 column/sec. Elapsed time 1.72 sec
# RP3betaRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# RP3betaRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_7.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_7.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ImplicitALSRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12768.59 column/sec. Elapsed time 1.74 sec

# %%
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from Recommenders.Hybrid.GeneralizedLinearHybridRecommenderCold import GeneralizedLinearHybridRecommenderCold
from Recommenders.Hybrid.GeneralizedLinearHybridRecommender import GeneralizedLinearHybridRecommender

recommenderClass = GeneralizedLinearHybridRecommender

hyperparameters_range_dictionary = {
        "topK": Integer(5, 300),
        "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
        "beta": Real(low = 0, high = 1.35, prior = 'uniform'),
        "normalize_similarity": Categorical([True, False]),
        #"implicit" : Categorical([True])
}

hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "alpha" : Real(low = 0 , high=1, prior = 'uniform') 
}

hyperparameters_range_dictionary = {
    "alpha1": Real(low = 0.01, high = 2, prior = 'uniform'),
    "alpha2": Real(low = 0.01, high = 2, prior = 'uniform'),
    "alpha3": Real(low = 0.01, high = 2, prior = 'uniform'),
    "min_interaction" : Integer(low=1, high=10)
}


#hyperparameters_range_dictionary = {
#                "topK": Integer(5, 1000),
#                "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
#                "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
#            }

#IALS
#hyperparameters_range_dictionary = {
#                "num_factors": Integer(1, 500),
#                "epochs": Integer(50,2500),
#                "confidence_scaling": Categorical(["linear", "log"]),
#                "alpha": Real(low = 1e-3, high = 50.0, prior = 'log-uniform'),
#                "epsilon": Real(low = 1e-3, high = 10.0, prior = 'log-uniform'),
#                "reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
#            }

hyperparameters_range_dictionary
# Out:
# {'alpha1': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'alpha2': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'alpha3': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'min_interaction': Integer(low=1, high=15, prior='uniform', transform='identity')}

# %%
if issubclass(recommenderClass, Incremental_Training_Early_Stopping):
    print("Using EarlyStop")

# %%
from concurrent.futures import ProcessPoolExecutor
import os

import multiprocessing
from skopt import dump
from skopt.callbacks import CheckpointSaver

# Define a function to save your optimization after every `n` calls
def checkpoint_saver(n_calls=10, checkpoint_path="checkpoint.pkl"):
    return CheckpointSaver(checkpoint_path, compress=9) # keyword arguments will be passed to `skopt.dump`

print(f"RUNNING ON {num_cpus} threads")

sum_map = lambda results: sum(item[metric_to_optimize] for item in results)

hyperparams = dict()
hyperparams_names = list()
hyperparams_values = list()

skopt_types = [Real, Integer, Categorical]

for name, hyperparam in hyperparameters_range_dictionary.items():
    if any(isinstance(hyperparam, sko_type) for sko_type in skopt_types):
        hyperparams_names.append(name)
        hyperparams_values.append(hyperparam)
        hyperparams[name] = hyperparam

columns = ["Fold",metric_to_optimize]
for h in hyperparams_names:
    columns.append(h)

fold_results_df = pd.DataFrame(columns=columns)
if os.path.exists(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv"):
    fold_results_df = pd.read_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")


def run_fold(fold, **hyperparams):
    # Fit the model on this fold and return the evaluation metric
    # ...
    if issubclass(recommenderClass, GeneralizedLinearHybridRecommender):

        alphas = [hyperparams["alpha1"], hyperparams["alpha2"], hyperparams["alpha3"]]
        minint = hyperparams["min_interaction"]

        recsys_s = [rp3s[fold], slims[fold],ials[fold]]

        recommender = GeneralizedLinearHybridRecommender(urm_train_validation[fold], recsys_s, verbose=True)
    
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold):
        alphas = [hyperparams["alpha1"], hyperparams["alpha2"], hyperparams["alpha3"]]
        minint = hyperparams["min_interaction"]

        recsys_s = [rp3s[fold], slims[fold],ials[fold]]

        recommender = GeneralizedLinearHybridRecommenderCold(urm_train_validation[fold], recsys_s, verbose=True, COLD_recommender=KNNs[fold], COLD_Under_Interactions=minint)
    else:
        recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1

    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )
    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]        
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold) or issubclass(recommenderClass, GeneralizedLinearHybridRecommender):
        recommender.fit(alphas)
    else:
        recommender.fit(**hyperparams)

    result, _ = evaluator_test[fold].evaluateRecommender(recommender)
    metric_result = result[metric_to_optimize].item()
    
    print(f"Fold {fold}: hyperparams {hyperparams}, ended with {metric_to_optimize} {metric_result}")

    return {'Fold': fold, metric_to_optimize: metric_result, 'epochs': epochs, **hyperparams}

def run_fold_wrapper(fold, hyperparameters):
    return run_fold(fold, **hyperparameters)


def evaluate_model(hyperparams):

    global fold_results_df

    current_fit_hyperparameters_dict = dict(zip(hyperparams_names, hyperparams))

    if issubclass(recommenderClass, ImplicitALSRecommender):
        fold_results=[]
        for i, seed in  enumerate(seeds):
            fold_results.append(run_fold(i, **current_fit_hyperparameters_dict))
    else:
        # Start the process pool
        with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
            fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))


    print(fold_results)
    for res in fold_results:
        fold_results_df = pd.concat([fold_results_df, pd.DataFrame([res])], ignore_index=True)
    fold_results_df.to_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")

    # Compute average score across all folds
    average_score = sum_map(fold_results) / len(fold_results)

    print(f"Finished trial with Average {metric_to_optimize}: {average_score}")

    return -average_score  # Assuming a score that needs to be minimized




from skopt import load
checkpointPath = output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl"
print(checkpointPath)
checkpoint_callback = checkpoint_saver(n_calls=1, checkpoint_path=checkpointPath)

if os.path.exists(checkpointPath):
    res = load(checkpointPath)
    #UNCOMMENT TO RESTART LAST CHECKPOINT
    x0 = res.x_iters
    y0 = res.func_vals
    model_counter = len(res.x_iters)
    res.fun

print(f"Still need to run {n_cases - model_counter} trials")

result = gp_minimize(evaluate_model, hyperparams_values,
                     base_estimator=None,
                     n_calls=max(0, n_cases - model_counter),
                     n_initial_points= max(0, n_random_starts - model_counter),
                     initial_point_generator = "random",
                     acq_func=acq_func,
                     acq_optimizer=acq_optimizer,
                     x0=x0,
                     y0=y0,
                     random_state=random_state,
                     verbose=verbose,
                     callback=[checkpoint_callback],
                     n_points=n_points,
                     n_restarts_optimizer=n_restarts_optimizer,
                     xi=xi,
                     kappa=kappa,
                     noise=noise,
                     n_jobs=1
                    )
# Out:
# RUNNING ON 8 threads
# result_experiments_more_data/GeneralizedLinearHybridRecommender_checkpoint.pkl
# Still need to run 500 trials
# Iteration No: 1 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10473 (100.0%) in 9.96 sec. Users per second: 1051
# Fold 4: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.04108575490414556
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.24 sec. Users per second: 1023
# Fold 0: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.04117612575333225
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.46 sec. Users per second: 1003
# Fold 1: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.040800200228833454
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.50 sec. Users per second: 994
# Fold 7: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.03987507982120106
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.73 sec. Users per second: 978
# Fold 5: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.04046975761618905
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.75 sec. Users per second: 972
# Fold 2: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.040497771275432505
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.76 sec. Users per second: 973
# Fold 6: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.040660264838396465
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.92 sec. Users per second: 956
# Fold 3: hyperparams {'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, ended with MAP 0.04106628397561048
# [{'Fold': 0, 'MAP': 0.04117612575333225, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 1, 'MAP': 0.040800200228833454, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 2, 'MAP': 0.040497771275432505, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 3, 'MAP': 0.04106628397561048, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 4, 'MAP': 0.04108575490414556, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 5, 'MAP': 0.04046975761618905, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 6, 'MAP': 0.040660264838396465, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}, {'Fold': 7, 'MAP': 0.03987507982120106, 'epochs': -1, 'alpha1': 0.022135706345388154, 'alpha2': 0.8710785947415235, 'alpha3': 1.6042403004468924, 'min_interaction': 15}]
# Finished trial with Average MAP: 0.0407039048016426
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 11.0387
# Function value obtained: -0.0407
# Current minimum: -0.0407
# Iteration No: 2 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10473 (100.0%) in 9.42 sec. Users per second: 1112
# Fold 4: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.04955232578406524
# EvaluatorHoldout: Processed 10472 (100.0%) in 9.95 sec. Users per second: 1053
# Fold 0: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.049785262589885027
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.08 sec. Users per second: 1037
# Fold 2: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.049130641696444176
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.25 sec. Users per second: 1019
# Fold 7: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.04859754150702486
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.29 sec. Users per second: 1017
# Fold 6: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.04915310173622073
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.40 sec. Users per second: 1008
# Fold 1: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.04931646749724629
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.52 sec. Users per second: 992
# Fold 3: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.048465462816047675
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.60 sec. Users per second: 990
# Fold 5: hyperparams {'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, ended with MAP 0.04887294855678603
# [{'Fold': 0, 'MAP': 0.049785262589885027, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.04931646749724629, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.049130641696444176, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.048465462816047675, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 4, 'MAP': 0.04955232578406524, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 5, 'MAP': 0.04887294855678603, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 6, 'MAP': 0.04915310173622073, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}, {'Fold': 7, 'MAP': 0.04859754150702486, 'epochs': -1, 'alpha1': 0.8684710336646341, 'alpha2': 0.7447346844125626, 'alpha3': 0.48384560848861163, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.049109219022965
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 10.7039
# Function value obtained: -0.0491
# Current minimum: -0.0491
# Iteration No: 3 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 9.60 sec. Users per second: 1091
# Fold 0: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.045591983005323855
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.12 sec. Users per second: 1031
# Fold 7: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.04456484522289184
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.34 sec. Users per second: 1014
# Fold 1: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.04529384300122352
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.49 sec. Users per second: 1001
# Fold 5: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.04463466574087986
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.52 sec. Users per second: 995
# Fold 4: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.045543218465017944
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.56 sec. Users per second: 989
# Fold 2: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.044777332640560524
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.58 sec. Users per second: 989
# Fold 6: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.04525635747117597
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.63 sec. Users per second: 982
# Fold 3: hyperparams {'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, ended with MAP 0.04499716173332677
# [{'Fold': 0, 'MAP': 0.045591983005323855, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 1, 'MAP': 0.04529384300122352, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 2, 'MAP': 0.044777332640560524, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 3, 'MAP': 0.04499716173332677, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 4, 'MAP': 0.045543218465017944, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 5, 'MAP': 0.04463466574087986, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 6, 'MAP': 0.04525635747117597, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}, {'Fold': 7, 'MAP': 0.04456484522289184, 'epochs': -1, 'alpha1': 1.4182224175598768, 'alpha2': 0.8309786657116784, 'alpha3': 1.617966396622315, 'min_interaction': 5}]
# Finished trial with Average MAP: 0.04508242591005003
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 10.7449
# Function value obtained: -0.0451
# Current minimum: -0.0491
# Iteration No: 4 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.03 sec. Users per second: 1041
# Fold 3: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04540348221504933
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.16 sec. Users per second: 1030
# Fold 4: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04596131549153665
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.28 sec. Users per second: 1020
# Fold 1: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.0457635143111407
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.47 sec. Users per second: 998EvaluatorHoldout: Processed 10493 (100.0%) in 10.48 sec. Users per second: 1001
#
# Fold 2: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04544374331534603Fold 5: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04504895175771041
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.57 sec. Users per second: 987
# Fold 7: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04505814024204893
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.62 sec. Users per second: 986
# Fold 0: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04608641941625176
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.67 sec. Users per second: 981
# Fold 6: hyperparams {'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, ended with MAP 0.04556705048823194
# [{'Fold': 0, 'MAP': 0.04608641941625176, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 1, 'MAP': 0.0457635143111407, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 2, 'MAP': 0.04544374331534603, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 3, 'MAP': 0.04540348221504933, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 4, 'MAP': 0.04596131549153665, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 5, 'MAP': 0.04504895175771041, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 6, 'MAP': 0.04556705048823194, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}, {'Fold': 7, 'MAP': 0.04505814024204893, 'epochs': -1, 'alpha1': 1.6230309840013026, 'alpha2': 0.623266359817057, 'alpha3': 1.4527222527189452, 'min_interaction': 6}]
# Finished trial with Average MAP: 0.045541577154664475
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 10.8015
# Function value obtained: -0.0455
# Current minimum: -0.0491
# Iteration No: 5 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.18 sec. Users per second: 1029
# Fold 4: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.044967728808319535
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.27 sec. Users per second: 1021
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.31 sec. Users per second: 1013
# Fold 1: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.044837675408328226
# Fold 3: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.04466930583672325
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.39 sec. Users per second: 1008
# Fold 0: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.04497670280233354
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.40 sec. Users per second: 1004
# Fold 7: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.044040191874962595
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.46 sec. Users per second: 999
# Fold 2: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.04441579538272727
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.63 sec. Users per second: 988
# Fold 5: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.044267867921018195
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.81 sec. Users per second: 968
# Fold 6: hyperparams {'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, ended with MAP 0.04473849407283108
# [{'Fold': 0, 'MAP': 0.04497670280233354, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 1, 'MAP': 0.044837675408328226, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 2, 'MAP': 0.04441579538272727, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 3, 'MAP': 0.04466930583672325, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 4, 'MAP': 0.044967728808319535, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 5, 'MAP': 0.044267867921018195, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 6, 'MAP': 0.04473849407283108, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}, {'Fold': 7, 'MAP': 0.044040191874962595, 'epochs': -1, 'alpha1': 1.0741854894156708, 'alpha2': 1.0591060092332383, 'alpha3': 1.6988792989762285, 'min_interaction': 6}]
# Finished trial with Average MAP: 0.04461422026340547
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 10.9302
# Function value obtained: -0.0446
# Current minimum: -0.0491
# Iteration No: 6 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.14 sec. Users per second: 1029
# Fold 7: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.0469609218208362
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.26 sec. Users per second: 1021
# Fold 4: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.04798700816460825
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.56 sec. Users per second: 991
# Fold 6: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.04742624590360404
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.59 sec. Users per second: 990
# Fold 5: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.047043743448013625
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.74 sec. Users per second: 977
# Fold 1: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.047669074558377204
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.89 sec. Users per second: 962
# Fold 0: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.04814489811076007
# EvaluatorHoldout: Processed 10444 (100.0%) in 11.01 sec. Users per second: 949
# Fold 3: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.047000092709113
# EvaluatorHoldout: Processed 10448 (100.0%) in 11.30 sec. Users per second: 925
# Fold 2: hyperparams {'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, ended with MAP 0.04748694593329988
# [{'Fold': 0, 'MAP': 0.04814489811076007, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.047669074558377204, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.04748694593329988, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.047000092709113, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 4, 'MAP': 0.04798700816460825, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 5, 'MAP': 0.047043743448013625, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 6, 'MAP': 0.04742624590360404, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}, {'Fold': 7, 'MAP': 0.0469609218208362, 'epochs': -1, 'alpha1': 1.7969501013947962, 'alpha2': 1.7634300364431943, 'alpha3': 1.6235000792455725, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.047464866331076536
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 11.4323
# Function value obtained: -0.0475
# Current minimum: -0.0491
# Iteration No: 7 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.59 sec. Users per second: 989
# Fold 0: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.04916101667939964
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.73 sec. Users per second: 976
# Fold 6: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.04840659836432325
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.80 sec. Users per second: 970
# Fold 4: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.049020913945005073
# EvaluatorHoldout: Processed 10444 (100.0%) in 11.08 sec. Users per second: 943
# Fold 3: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.04774212656465691
# EvaluatorHoldout: Processed 10448 (100.0%) in 11.09 sec. Users per second: 942
# EvaluatorHoldout: Processed 10493 (100.0%) in 11.10 sec. Users per second: 945
# Fold 2: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.04836788464109529
# EvaluatorHoldout: Processed 10488 (100.0%) in 11.10 sec. Users per second: 945
# Fold 5: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.048287183897353286
# Fold 1: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.04882936129575208
# EvaluatorHoldout: Processed 10440 (100.0%) in 11.15 sec. Users per second: 936
# Fold 7: hyperparams {'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, ended with MAP 0.048051127379432484
# [{'Fold': 0, 'MAP': 0.04916101667939964, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 1, 'MAP': 0.04882936129575208, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 2, 'MAP': 0.04836788464109529, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 3, 'MAP': 0.04774212656465691, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 4, 'MAP': 0.049020913945005073, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 5, 'MAP': 0.048287183897353286, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 6, 'MAP': 0.04840659836432325, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}, {'Fold': 7, 'MAP': 0.048051127379432484, 'epochs': -1, 'alpha1': 0.39008593107470435, 'alpha2': 1.7362401557836802, 'alpha3': 0.745975431389418, 'min_interaction': 2}]
# Finished trial with Average MAP: 0.048483276595877256
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 11.2806
# Function value obtained: -0.0485
# Current minimum: -0.0491
# Iteration No: 8 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 9.78 sec. Users per second: 1070
# Fold 0: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.05021700346805445
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.14 sec. Users per second: 1032
# Fold 4: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.050310124750113844
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.18 sec. Users per second: 1025
# Fold 7: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.04911521620142367
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.29 sec. Users per second: 1020
# Fold 5: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.049538857348588164
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.55 sec. Users per second: 992
# Fold 6: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.04976229904719495
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.62 sec. Users per second: 984
# Fold 3: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.049120106934642326
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.69 sec. Users per second: 981
# Fold 1: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.05003348119695425
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.87 sec. Users per second: 961
# Fold 2: hyperparams {'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, ended with MAP 0.04982836390043571
# [{'Fold': 0, 'MAP': 0.05021700346805445, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 1, 'MAP': 0.05003348119695425, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 2, 'MAP': 0.04982836390043571, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 3, 'MAP': 0.049120106934642326, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 4, 'MAP': 0.050310124750113844, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 5, 'MAP': 0.049538857348588164, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 6, 'MAP': 0.04976229904719495, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}, {'Fold': 7, 'MAP': 0.04911521620142367, 'epochs': -1, 'alpha1': 1.805417961651708, 'alpha2': 0.6117936786930124, 'alpha3': 0.47741741386777353, 'min_interaction': 9}]
# Finished trial with Average MAP: 0.049740681605925915
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 11.0038
# Function value obtained: -0.0497
# Current minimum: -0.0497
# Iteration No: 9 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.05 sec. Users per second: 1042EvaluatorHoldout: Processed 10440 (100.0%) in 10.05 sec. Users per second: 1039
#
# Fold 7: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04745562701453536Fold 0: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04863209298871123
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.37 sec. Users per second: 1007
# Fold 3: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.047881171235250854
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.39 sec. Users per second: 1008
# Fold 4: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04872313007446263
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.81 sec. Users per second: 970
# Fold 1: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04842171476396375
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.92 sec. Users per second: 957
# Fold 2: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04823227351175342
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.97 sec. Users per second: 957EvaluatorHoldout: Processed 10467 (100.0%) in 10.96 sec. Users per second: 955
#
# Fold 6: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04836037599651882Fold 5: hyperparams {'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, ended with MAP 0.04802563008748145
#
# [{'Fold': 0, 'MAP': 0.04863209298871123, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 1, 'MAP': 0.04842171476396375, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 2, 'MAP': 0.04823227351175342, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 3, 'MAP': 0.047881171235250854, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 4, 'MAP': 0.04872313007446263, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 5, 'MAP': 0.04802563008748145, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 6, 'MAP': 0.04836037599651882, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}, {'Fold': 7, 'MAP': 0.04745562701453536, 'epochs': -1, 'alpha1': 1.1807405795379682, 'alpha2': 0.12355679121711126, 'alpha3': 0.415062469082628, 'min_interaction': 5}]
# Finished trial with Average MAP: 0.048216501959084695
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 11.1165
# Function value obtained: -0.0482
# Current minimum: -0.0497
# Iteration No: 10 started. Evaluating function at random point.
# ...
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.54 sec. Users per second: 994
# Fold 4: hyperparams {'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, ended with MAP 0.046569330205108526
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.67 sec. Users per second: 979
# Fold 2: hyperparams {'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, ended with MAP 0.04596467539925675
# [{'Fold': 0, 'MAP': 0.04646690115440176, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 1, 'MAP': 0.04630518022108474, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 2, 'MAP': 0.04596467539925675, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 3, 'MAP': 0.046114785279617404, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 4, 'MAP': 0.046569330205108526, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 5, 'MAP': 0.0456095068670125, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 6, 'MAP': 0.04618481213064253, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}, {'Fold': 7, 'MAP': 0.045482450738916706, 'epochs': -1, 'alpha1': 1.8746097773876895, 'alpha2': 0.06942128439400944, 'alpha3': 1.0395511007565919, 'min_interaction': 6}]
# Finished trial with Average MAP: 0.04608720524950512
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 10.8158
# Function value obtained: -0.0461
# Current minimum: -0.0512
# Iteration No: 33 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.62 sec. Users per second: 983
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.67 sec. Users per second: 982
# Fold 7: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.04686123654442677
# Fold 4: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.0479537518244198
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.72 sec. Users per second: 977
# Fold 6: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.04745096834950731
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.78 sec. Users per second: 968
# Fold 3: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.046950789699258526
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.86 sec. Users per second: 962
# Fold 2: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.04747362220156105
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.93 sec. Users per second: 959
# Fold 1: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.047628824476651156
# EvaluatorHoldout: Processed 10472 (100.0%) in 11.06 sec. Users per second: 947
# Fold 0: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.04808601849830903
# EvaluatorHoldout: Processed 10493 (100.0%) in 11.23 sec. Users per second: 934
# Fold 5: hyperparams {'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, ended with MAP 0.046981422989476634
# [{'Fold': 0, 'MAP': 0.04808601849830903, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 1, 'MAP': 0.047628824476651156, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 2, 'MAP': 0.04747362220156105, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 3, 'MAP': 0.046950789699258526, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 4, 'MAP': 0.0479537518244198, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 5, 'MAP': 0.046981422989476634, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 6, 'MAP': 0.04745096834950731, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}, {'Fold': 7, 'MAP': 0.04686123654442677, 'epochs': -1, 'alpha1': 1.633996015863709, 'alpha2': 1.4202875433212716, 'alpha3': 1.403707233226241, 'min_interaction': 3}]
# Finished trial with Average MAP: 0.047423329322951284
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 11.3584
# Function value obtained: -0.0474
# Current minimum: -0.0512
# Iteration No: 34 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10467 (100.0%) in 9.71 sec. Users per second: 1078
# Fold 6: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04853291372279684
# EvaluatorHoldout: Processed 10444 (100.0%) in 10.02 sec. Users per second: 1042
# Fold 3: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04800140431507811
# EvaluatorHoldout: Processed 10440 (100.0%) in 10.19 sec. Users per second: 1024
# Fold 7: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04778466140606991
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.29 sec. Users per second: 1016
# Fold 2: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04852287747028427
# EvaluatorHoldout: Processed 10488 (100.0%) in 10.35 sec. Users per second: 1013
# Fold 1: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04867529254900594
# EvaluatorHoldout: Processed 10472 (100.0%) in 10.50 sec. Users per second: 997
# Fold 0: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04910701780712345
# EvaluatorHoldout: Processed 10493 (100.0%) in 10.52 sec. Users per second: 998
# Fold 5: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.048106246946188445
# EvaluatorHoldout: Processed 10473 (100.0%) in 10.57 sec. Users per second: 991
# Fold 4: hyperparams {'alpha1': 1.6051602458877299, 'alpha2': 0.8190407997996271, 'alpha3': 0.8451328950622525, 'min_interaction': 3}, ended with MAP 0.04905838747861152
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 135
#     131     res.fun
#     133 print(f"Still need to run {n_cases - model_counter} trials")
# --> 135 result = gp_minimize(evaluate_model, hyperparams_values,
#     136                      base_estimator=None,
#     137                      n_calls=max(0, n_cases - model_counter),
#     138                      n_initial_points= max(0, n_random_starts - model_counter),
#     139                      initial_point_generator = "random",
#     140                      acq_func=acq_func,
#     141                      acq_optimizer=acq_optimizer,
#     142                      x0=x0,
#     143                      y0=y0,
#     144                      random_state=random_state,
#     145                      verbose=verbose,
#     146                      callback=[checkpoint_callback],
#     147                      n_points=n_points,
#     148                      n_restarts_optimizer=n_restarts_optimizer,
#     149                      xi=xi,
#     150                      kappa=kappa,
#     151                      noise=noise,
#     152                      n_jobs=1
#     153                     )
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py:301, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299 for n in range(n_calls):
#     300     next_x = optimizer.ask()
# --> 301     next_y = func(next_x)
#     302     result = optimizer.tell(next_x, next_y)
#     303     result.specs = specs
#
# Cell In[22], line 102, in evaluate_model(hyperparams)
#      97 else:
#      98     # Start the process pool
#      99     with ProcessPoolExecutor(max_workers=num_cpus) as executor:
#     100         # Submit all tasks to the process pool and wait for them to complete
#     101         #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
# --> 102         fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))
#     105 print(fold_results)
#     106 for res in fold_results:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/process.py:484, in _chain_from_iterable_of_lists(iterable)
#     478 def _chain_from_iterable_of_lists(iterable):
#     479     """
#     480     Specialized implementation of itertools.chain.from_iterable.
#     481     Each item in *iterable* should be a list.  This function is
#     482     careful not to keep references to yielded objects.
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#     486         while element:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield fs.pop().result()
#     620     else:
#     621         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
import pandas as pd
result = load("/home/japo/RecSys-Challenge/result_experiments_more_data/GeneralizedLinearHybridRecommender_checkpoint.pkl")
results_df = pd.DataFrame(result.x_iters, columns=[dim for dim in hyperparameters_range_dictionary])
results_df['score'] = result.func_vals

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'alpha1': 0.6464483146524337,
#  'alpha2': 0.7533801103113421,
#  'alpha3': 0.032576355148477586,
#  'min_interaction': 1}

# %%
results_df['score'].min()
# Out:
# -0.030128708347317946

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'topK': 34,
#  'alpha': 0.28453879172230406,
#  'beta': 0.15344052347036438,
#  'normalize_similarity': True}

# %%
SLIMEN = {'topK': 530, 'l1_ratio': 0.05017569359096808, 'alpha': 0.001}
P3ALPHA = {'topK': 400, 'alpha': 1.6632815179401539, 'normalize_similarity': True}
RP3 = {'topK': 71, 'alpha': 0.31274648571776065, 'beta': 0.3586324430664178, 'normalize_similarity': True}

SLIMEN_KFOLD = {'Fold': 0, 'MAP': 0.029228665181843458, 'topK': 660, 'l1_ratio': 0.0012296801858497721, 'alpha': 0.001}
RP3_KFOLD = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}
IMPLICIT_IALS = {'num_factors': 128,
 'epochs': 478,
 'confidence_scaling': 'linear',
 'alpha': 3.358295366834473,
 'epsilon': 7.295986722921583,
 'reg': 6.292360640597378e-05}

# %%
#BEST 100 SINGLE SPLIT: 0.030123825632990115
OLD_BEST_PARAMS = {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}

# 0.030008733292970144
OLD_BEST_PARAMS = {'topK': 59,
 'alpha': 0.3764461506622426,
 'beta': 0.10277510174112,
 'normalize_similarity': True}

#0.030128708347317946
OLD_BEST_PARAMS = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}

old_res = 0
for i in range(len(seeds)):
    m = recommenderClass(urm_train[i])
    m.fit(**OLD_BEST_PARAMS)
    ris, _ = evaluator_validation[i].evaluateRecommender(m)
    old_res += ris["MAP"].item()
old_res = old_res / len(seeds)
old_res
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8617.41 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10073 (100.0%) in 2.34 sec. Users per second: 4304
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8584.56 column/sec. Elapsed time 2.59 sec
# EvaluatorHoldout: Processed 10013 (100.0%) in 2.34 sec. Users per second: 4283
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8529.22 column/sec. Elapsed time 2.61 sec
# EvaluatorHoldout: Processed 10042 (100.0%) in 2.25 sec. Users per second: 4469
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8330.07 column/sec. Elapsed time 2.67 sec
# EvaluatorHoldout: Processed 9972 (100.0%) in 2.29 sec. Users per second: 4357
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8599.09 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10017 (100.0%) in 2.27 sec. Users per second: 4406
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8633.67 column/sec. Elapsed time 2.57 sec
# EvaluatorHoldout: Processed 9986 (100.0%) in 2.29 sec. Users per second: 4356
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8543.68 column/sec. Elapsed time 2.60 sec
# EvaluatorHoldout: Processed 10068 (100.0%) in 2.29 sec. Users per second: 4396
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8694.54 column/sec. Elapsed time 2.56 sec
# EvaluatorHoldout: Processed 9992 (100.0%) in 2.16 sec. Users per second: 4622
# 0.030008733292970144

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt


regr = RandomForestRegressor(max_depth=2)

result_df_graph = results_df.copy()
result_df_graph["score"] *= -1

numerical_cols = result_df_graph.mean().notna()
numerical_cols = numerical_cols.index[numerical_cols]

numerical_df = result_df_graph[numerical_cols]
numerical_df = (numerical_df - numerical_df.mean())/(numerical_df.std() +1e-6)

y_train = numerical_df["score"]
X_train = numerical_df.copy()
X_train = X_train.drop(columns=["score"])

regr.fit(X_train, y_train)

plt.bar(X_train.columns, regr.feature_importances_)
plt.show()

# %%
final_model = ItemKNNSimilarityHybridRecommender(urm_all)
