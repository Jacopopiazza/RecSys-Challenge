# %%
import os
#os.chdir( "../")

# %%
import psutil
num_cpus = psutil.cpu_count(logical=False)
num_cpus # Force it to use more folds than cores
# Out:
# 4

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
metric_to_optimize = "MAP"
output_folder_path = "results/"

n_cases = 100
n_random_starts = 0.05 * n_cases

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

seeds = [
    1811854, 3772146, 6407100, 6926227, 1340378, 
    68679, 3822303, 4058970, 1264160, 1100338, 
    6552126, 725363, 8362134, 9446122, 5256199, 
    4686339, 3830906, 7315366, 9428914, 5564236, 
    3420043, 9223036, 851434, 3300082, 7899660, 
    2053768, 4305274, 3709256, 8795594, 1418903, 
    7428566, 157832
]

seeds = seeds[:num_cpus]

urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation = []
urm_test = []
urm_train = []
urm_validation = []

for i in range(len(seeds)):
    a, b = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=seeds[i])
    c, d = split_train_in_two_percentage_global_sample(a, train_percentage = 0.80,seed=seeds[i])
    urm_train_validation.append(a)
    urm_test.append(b)
    urm_train.append(c)
    urm_validation.append(d)
# Out:
# Warning: 229 (1.81 %) of 12638 users have no train items
# Warning: 2166 (17.14 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2565 (20.30 %) of 12638 users have no sampled items
# Warning: 217 (1.72 %) of 12638 users have no train items
# Warning: 2150 (17.01 %) of 12638 users have no sampled items
# Warning: 453 (3.58 %) of 12638 users have no train items
# Warning: 2625 (20.77 %) of 12638 users have no sampled items
# Warning: 223 (1.76 %) of 12638 users have no train items
# Warning: 2190 (17.33 %) of 12638 users have no sampled items
# Warning: 446 (3.53 %) of 12638 users have no train items
# Warning: 2596 (20.54 %) of 12638 users have no sampled items
# Warning: 227 (1.80 %) of 12638 users have no train items
# Warning: 2194 (17.36 %) of 12638 users have no sampled items
# Warning: 450 (3.56 %) of 12638 users have no train items
# Warning: 2666 (21.10 %) of 12638 users have no sampled items

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = []
for u in urm_validation:
    evaluator_validation.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# Tensorflow is not available
# EvaluatorHoldout: Ignoring 2565 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2625 (20.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2596 (20.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2666 (21.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = []
for u in urm_test:
    evaluator_test.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2166 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2150 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2190 (17.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2194 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from concurrent.futures import ProcessPoolExecutor
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
import time
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender

# %%
n_points = 10000
n_jobs = 1  # Using all available CPUs
acq_func = 'gp_hedge'
acq_optimizer = 'auto'
verbose = True
n_restarts_optimizer = 10
xi = 0.01
kappa = 1.96
x0 = None
y0 = None
noise = 1e-5
random_state = int(os.getpid() + time.time()) % np.iinfo(int).max
model_counter=0

# %%
rp3s = []
slims = []
ials = []
KNNs = []
for i in range(len(seeds)):
    rp3 = RP3betaRecommender(urm_train_validation[i],verbose=True)
    rp3.load_model("result_experiments_more_data/Hybrids", rp3.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    rp3s.append(rp3)

    slim = SLIMElasticNetRecommender(urm_train_validation[i], verbose=True)
    slim.load_model("result_experiments_more_data/Hybrids", slim.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    slims.append(slim)

    ials_model = ImplicitALSRecommender(urm_train_validation[i], verbose=True)
    ials_model.fit(**{'use_gpu': True, 'num_threads' : 1, 'num_factors': 128, 'epochs': 478, 'confidence_scaling': 'linear', 'alpha': 3.358295366834473, 'epsilon': 7.295986722921583, 'reg': 6.292360640597378e-05})
    ials.append(ials_model)

    knn = ItemKNNCFRecommender(urm_train_validation[i], verbose=True)
    knn.fit(**{'topK': 19, 'shrink': 28, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 1.3672226785339947})
    KNNs.append(knn)
# Out:
# RP3betaRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_0.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_0.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Similarity column 22222 (100.0%), 13048.05 column/sec. Elapsed time 1.70 sec
# RP3betaRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# RP3betaRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_1.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_1.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ImplicitALSRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 13082.07 column/sec. Elapsed time 1.70 sec
# RP3betaRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_2.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_2.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12979.87 column/sec. Elapsed time 1.71 sec
# RP3betaRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_3.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_3.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 13047.57 column/sec. Elapsed time 1.70 sec

# %%
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from Recommenders.Hybrid.GeneralizedLinearHybridRecommenderCold import GeneralizedLinearHybridRecommenderCold
from Recommenders.Hybrid.GeneralizedLinearHybridRecommender import GeneralizedLinearHybridRecommender

recommenderClass = GeneralizedLinearHybridRecommender

# RP3
#hyperparameters_range_dictionary = {
#        "topK": Integer(5, 300),
#        "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
#        "beta": Real(low = 0, high = 1.35, prior = 'uniform'),
#        "normalize_similarity": Categorical([True, False]),
#        #"implicit" : Categorical([True])
#}

# KNN
#hyperparameters_range_dictionary = {
#    "topK": Integer(5, 1000),
#    "alpha" : Real(low = 0 , high=1, prior = 'uniform') 
#}

# SLIMEN
#hyperparameters_range_dictionary = {
#    "topK": Integer(5, 1000),
#    "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
#    "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
#}

# IALS
#hyperparameters_range_dictionary = {
#                "num_factors": Integer(1, 500),
#                "epochs": Integer(50,2500),
#                "confidence_scaling": Categorical(["linear", "log"]),
#                "alpha": Real(low = 1e-3, high = 50.0, prior = 'log-uniform'),
#                "epsilon": Real(low = 1e-3, high = 10.0, prior = 'log-uniform'),
#                "reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
#            }

# Hybrid weights
hyperparameters_range_dictionary = {
    "alpha1": Real(low = 0.01, high = 2, prior = 'uniform'),
    "alpha2": Real(low = 0.01, high = 2, prior = 'uniform'),
    "alpha3": Real(low = 0.01, high = 2, prior = 'uniform'),
    "min_interaction" : Integer(low=1, high=10)
}

hyperparameters_range_dictionary
# Out:
# {'alpha1': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'alpha2': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'alpha3': Real(low=0.01, high=2, prior='uniform', transform='identity'),
#  'min_interaction': Integer(low=1, high=10, prior='uniform', transform='identity')}

# %%
if issubclass(recommenderClass, Incremental_Training_Early_Stopping):
    print("Using EarlyStop")

# %%
from concurrent.futures import ProcessPoolExecutor
import os

import multiprocessing
from skopt import dump
from skopt.callbacks import CheckpointSaver

# Define a function to save your optimization after every `n` calls
def checkpoint_saver(n_calls=10, checkpoint_path="checkpoint.pkl"):
    return CheckpointSaver(checkpoint_path, compress=9) # keyword arguments will be passed to `skopt.dump`

print(f"RUNNING ON {num_cpus} threads")

sum_map = lambda results: sum(item[metric_to_optimize] for item in results)

hyperparams = dict()
hyperparams_names = list()
hyperparams_values = list()

skopt_types = [Real, Integer, Categorical]

for name, hyperparam in hyperparameters_range_dictionary.items():
    if any(isinstance(hyperparam, sko_type) for sko_type in skopt_types):
        hyperparams_names.append(name)
        hyperparams_values.append(hyperparam)
        hyperparams[name] = hyperparam

columns = ["Fold",metric_to_optimize]
for h in hyperparams_names:
    columns.append(h)

fold_results_df = pd.DataFrame(columns=columns)
if os.path.exists(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv"):
    fold_results_df = pd.read_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")


def run_fold(fold, **hyperparams):
    # Fit the model on this fold and return the evaluation metric
    # ...
    if issubclass(recommenderClass, GeneralizedLinearHybridRecommender):

        alphas = [hyperparams["alpha1"], hyperparams["alpha2"], hyperparams["alpha3"]]
        minint = hyperparams["min_interaction"]

        recsys_s = [rp3s[fold], slims[fold],ials[fold]]

        recommender = GeneralizedLinearHybridRecommender(urm_train_validation[fold], recsys_s, verbose=True)
    
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold):
        alphas = [hyperparams["alpha1"], hyperparams["alpha2"], hyperparams["alpha3"]]
        minint = hyperparams["min_interaction"]

        recsys_s = [rp3s[fold], slims[fold],ials[fold]]

        recommender = GeneralizedLinearHybridRecommenderCold(urm_train_validation[fold], recsys_s, verbose=True, COLD_recommender=KNNs[fold], COLD_Under_Interactions=minint)
    else:
        recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1

    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )
    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]        
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold) or issubclass(recommenderClass, GeneralizedLinearHybridRecommender):
        recommender.fit(alphas)
    else:
        recommender.fit(**hyperparams)

    result, _ = evaluator_test[fold].evaluateRecommender(recommender)
    metric_result = result[metric_to_optimize].item()
    
    print(f"Fold {fold}: hyperparams {hyperparams}, ended with {metric_to_optimize} {metric_result}")

    return {'Fold': fold, metric_to_optimize: metric_result, 'epochs': epochs, **hyperparams}

def run_fold_wrapper(fold, hyperparameters):
    return run_fold(fold, **hyperparameters)


def evaluate_model(hyperparams):

    global fold_results_df

    current_fit_hyperparameters_dict = dict(zip(hyperparams_names, hyperparams))

    # ImplicitIALS may be using cuda, multiple instances with cuda may arise problems
    if issubclass(recommenderClass, ImplicitALSRecommender):
        fold_results=[]
        for i, seed in  enumerate(seeds):
            fold_results.append(run_fold(i, **current_fit_hyperparameters_dict))
    else:
        # Start the process pool
        with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
            fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))


    print(fold_results)
    for res in fold_results:
        fold_results_df = pd.concat([fold_results_df, pd.DataFrame([res])], ignore_index=True)
    fold_results_df.to_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")

    # Compute average score across all folds
    average_score = sum_map(fold_results) / len(fold_results)

    print(f"Finished trial with Average {metric_to_optimize}: {average_score}")

    return -average_score  # Assuming a score that needs to be minimized




from skopt import load
checkpointPath = output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl"
print(checkpointPath)
checkpoint_callback = checkpoint_saver(n_calls=1, checkpoint_path=checkpointPath)

if os.path.exists(checkpointPath):
    res = load(checkpointPath)
    #UNCOMMENT TO RESTART LAST CHECKPOINT
    x0 = res.x_iters
    y0 = res.func_vals
    model_counter = len(res.x_iters)
    res.fun

print(f"Still need to run {n_cases - model_counter} trials")

result = gp_minimize(evaluate_model, hyperparams_values,
                     base_estimator=None,
                     n_calls=max(0, n_cases - model_counter),
                     n_initial_points= max(0, n_random_starts - model_counter),
                     initial_point_generator = "random",
                     acq_func=acq_func,
                     acq_optimizer=acq_optimizer,
                     x0=x0,
                     y0=y0,
                     random_state=random_state,
                     verbose=verbose,
                     callback=[checkpoint_callback],
                     n_points=n_points,
                     n_restarts_optimizer=n_restarts_optimizer,
                     xi=xi,
                     kappa=kappa,
                     noise=noise,
                     n_jobs=1
                    )
# Out:
# RUNNING ON 4 threads
# results/GeneralizedLinearHybridRecommender_checkpoint.pkl
# Still need to run 100 trials
# Iteration No: 1 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.97 sec. Users per second: 1504
# Fold 1: hyperparams {'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, ended with MAP 0.04989989693436555
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.14 sec. Users per second: 1464
# Fold 2: hyperparams {'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, ended with MAP 0.04972628618828907
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.17 sec. Users per second: 1457
# Fold 3: hyperparams {'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, ended with MAP 0.049011249718833645
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.26 sec. Users per second: 1443
# Fold 0: hyperparams {'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, ended with MAP 0.0503708074138752
# [{'Fold': 0, 'MAP': 0.0503708074138752, 'epochs': -1, 'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, {'Fold': 1, 'MAP': 0.04989989693436555, 'epochs': -1, 'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, {'Fold': 2, 'MAP': 0.04972628618828907, 'epochs': -1, 'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}, {'Fold': 3, 'MAP': 0.049011249718833645, 'epochs': -1, 'alpha1': 0.31078929603148725, 'alpha2': 1.0828508318601946, 'alpha3': 0.3179992840048129, 'min_interaction': 3}]
# Finished trial with Average MAP: 0.049752060063840864
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 7.3270
# Function value obtained: -0.0498
# Current minimum: -0.0498
# Iteration No: 2 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.18 sec. Users per second: 1461
# Fold 1: hyperparams {'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, ended with MAP 0.04182790536122966
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.24 sec. Users per second: 1447
# Fold 0: hyperparams {'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, ended with MAP 0.041943152260904885
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.34 sec. Users per second: 1423
# Fold 2: hyperparams {'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, ended with MAP 0.041277764104621445
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.40 sec. Users per second: 1412
# Fold 3: hyperparams {'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, ended with MAP 0.04177334673815963
# [{'Fold': 0, 'MAP': 0.041943152260904885, 'epochs': -1, 'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, {'Fold': 1, 'MAP': 0.04182790536122966, 'epochs': -1, 'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, {'Fold': 2, 'MAP': 0.041277764104621445, 'epochs': -1, 'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}, {'Fold': 3, 'MAP': 0.04177334673815963, 'epochs': -1, 'alpha1': 1.2392900193810406, 'alpha2': 0.02167343794429665, 'alpha3': 1.6055933976481258, 'min_interaction': 9}]
# Finished trial with Average MAP: 0.04170554211622891
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 7.4569
# Function value obtained: -0.0417
# Current minimum: -0.0498
# Iteration No: 3 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 9.36 sec. Users per second: 1119
# Fold 0: hyperparams {'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, ended with MAP 0.04622913180423733
# EvaluatorHoldout: Processed 10448 (100.0%) in 9.45 sec. Users per second: 1106
# Fold 2: hyperparams {'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, ended with MAP 0.04545791782128931
# EvaluatorHoldout: Processed 10444 (100.0%) in 9.51 sec. Users per second: 1098
# Fold 3: hyperparams {'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, ended with MAP 0.04527003428717387
# EvaluatorHoldout: Processed 10488 (100.0%) in 9.54 sec. Users per second: 1099
# Fold 1: hyperparams {'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, ended with MAP 0.04584898614289408
# [{'Fold': 0, 'MAP': 0.04622913180423733, 'epochs': -1, 'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.04584898614289408, 'epochs': -1, 'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.04545791782128931, 'epochs': -1, 'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.04527003428717387, 'epochs': -1, 'alpha1': 0.2809024740412671, 'alpha2': 0.755715381183156, 'alpha3': 0.6983440790802343, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.04570151751389864
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 9.6087
# Function value obtained: -0.0457
# Current minimum: -0.0498
# Iteration No: 4 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 8.02 sec. Users per second: 1302
# Fold 3: hyperparams {'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, ended with MAP 0.05057964092696999
# EvaluatorHoldout: Processed 10472 (100.0%) in 8.40 sec. Users per second: 1246
# Fold 0: hyperparams {'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, ended with MAP 0.05162224359440805
# EvaluatorHoldout: Processed 10448 (100.0%) in 8.56 sec. Users per second: 1221
# Fold 2: hyperparams {'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, ended with MAP 0.05132870421011745
# EvaluatorHoldout: Processed 10488 (100.0%) in 8.62 sec. Users per second: 1217
# Fold 1: hyperparams {'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, ended with MAP 0.051383342111317405
# [{'Fold': 0, 'MAP': 0.05162224359440805, 'epochs': -1, 'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, {'Fold': 1, 'MAP': 0.051383342111317405, 'epochs': -1, 'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, {'Fold': 2, 'MAP': 0.05132870421011745, 'epochs': -1, 'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}, {'Fold': 3, 'MAP': 0.05057964092696999, 'epochs': -1, 'alpha1': 1.7114335255154747, 'alpha2': 1.9528381557341545, 'alpha3': 0.125482965501838, 'min_interaction': 6}]
# Finished trial with Average MAP: 0.051228482710703224
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 8.6918
# Function value obtained: -0.0512
# Current minimum: -0.0512
# Iteration No: 5 started. Evaluating function at random point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.49 sec. Users per second: 1395
# Fold 2: hyperparams {'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, ended with MAP 0.05124508905782885
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.58 sec. Users per second: 1384
# Fold 1: hyperparams {'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, ended with MAP 0.05116772153814534
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.70 sec. Users per second: 1356
# Fold 3: hyperparams {'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, ended with MAP 0.05053523554193847
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.75 sec. Users per second: 1351
# Fold 0: hyperparams {'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, ended with MAP 0.05152509109704535
# [{'Fold': 0, 'MAP': 0.05152509109704535, 'epochs': -1, 'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, {'Fold': 1, 'MAP': 0.05116772153814534, 'epochs': -1, 'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, {'Fold': 2, 'MAP': 0.05124508905782885, 'epochs': -1, 'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}, {'Fold': 3, 'MAP': 0.05053523554193847, 'epochs': -1, 'alpha1': 1.1535944049124431, 'alpha2': 1.879879912795989, 'alpha3': 0.18010584184123204, 'min_interaction': 2}]
# Finished trial with Average MAP: 0.051118284308739506
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 7.9847
# Function value obtained: -0.0511
# Current minimum: -0.0512
# Iteration No: 6 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.26 sec. Users per second: 1444
# Fold 1: hyperparams {'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, ended with MAP 0.04349352396692272
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.45 sec. Users per second: 1401
# Fold 3: hyperparams {'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, ended with MAP 0.04329451709191336
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.47 sec. Users per second: 1403
# Fold 0: hyperparams {'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, ended with MAP 0.04385257512095789
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.55 sec. Users per second: 1384
# Fold 2: hyperparams {'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, ended with MAP 0.04308545039378746
# [{'Fold': 0, 'MAP': 0.04385257512095789, 'epochs': -1, 'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.04349352396692272, 'epochs': -1, 'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.04308545039378746, 'epochs': -1, 'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.04329451709191336, 'epochs': -1, 'alpha1': 0.7008585296676753, 'alpha2': 1.2571071503068318, 'alpha3': 1.9980360251590779, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.04343151664339536
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 7.7389
# Function value obtained: -0.0434
# Current minimum: -0.0512
# Iteration No: 7 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.16 sec. Users per second: 1465
# Fold 1: hyperparams {'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, ended with MAP 0.04820475857518262
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.25 sec. Users per second: 1443
# Fold 0: hyperparams {'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, ended with MAP 0.04864670489407947
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.38 sec. Users per second: 1414
# Fold 3: hyperparams {'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, ended with MAP 0.04739278039187156
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.39 sec. Users per second: 1413
# Fold 2: hyperparams {'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, ended with MAP 0.04801548181166337
# [{'Fold': 0, 'MAP': 0.04864670489407947, 'epochs': -1, 'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.04820475857518262, 'epochs': -1, 'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.04801548181166337, 'epochs': -1, 'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.04739278039187156, 'epochs': -1, 'alpha1': 1.3789106940315212, 'alpha2': 1.6744415262323786, 'alpha3': 1.2409797993452598, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.04806493141819925
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 7.5665
# Function value obtained: -0.0481
# Current minimum: -0.0512
# Iteration No: 8 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 6.94 sec. Users per second: 1509
# Fold 0: hyperparams {'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, ended with MAP 0.04877419907356952
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.23 sec. Users per second: 1445
# Fold 3: hyperparams {'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, ended with MAP 0.048512896445442245
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.33 sec. Users per second: 1431
# Fold 1: hyperparams {'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, ended with MAP 0.04912473666049233
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.49 sec. Users per second: 1396
# Fold 2: hyperparams {'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, ended with MAP 0.04880091731690176
# [{'Fold': 0, 'MAP': 0.04877419907356952, 'epochs': -1, 'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.04912473666049233, 'epochs': -1, 'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.04880091731690176, 'epochs': -1, 'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.048512896445442245, 'epochs': -1, 'alpha1': 1.8874797740800469, 'alpha2': 0.010916652907812081, 'alpha3': 0.02332753027926171, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.04880318737410146
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 7.6644
# Function value obtained: -0.0488
# Current minimum: -0.0512
# Iteration No: 9 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.28 sec. Users per second: 1439
# Fold 0: hyperparams {'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, ended with MAP 0.04604545606121283
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.49 sec. Users per second: 1395
# Fold 2: hyperparams {'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, ended with MAP 0.04529491859914008
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.53 sec. Users per second: 1392
# Fold 1: hyperparams {'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, ended with MAP 0.045740392648288
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.63 sec. Users per second: 1370
# Fold 3: hyperparams {'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, ended with MAP 0.045183841409665436
# [{'Fold': 0, 'MAP': 0.04604545606121283, 'epochs': -1, 'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, {'Fold': 1, 'MAP': 0.045740392648288, 'epochs': -1, 'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, {'Fold': 2, 'MAP': 0.04529491859914008, 'epochs': -1, 'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}, {'Fold': 3, 'MAP': 0.045183841409665436, 'epochs': -1, 'alpha1': 0.8896620806062635, 'alpha2': 1.9958046536925158, 'alpha3': 1.9864922696228464, 'min_interaction': 8}]
# Finished trial with Average MAP: 0.04556615217957659
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 7.7933
# Function value obtained: -0.0456
# Current minimum: -0.0512
# Iteration No: 10 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 6.51 sec. Users per second: 1605
# Fold 3: hyperparams {'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, ended with MAP 0.04852112247937658
# EvaluatorHoldout: Processed 10472 (100.0%) in 6.94 sec. Users per second: 1510
# Fold 0: hyperparams {'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, ended with MAP 0.04990808065650559
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.16 sec. Users per second: 1466
# Fold 1: hyperparams {'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, ended with MAP 0.04949897766759966
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.43 sec. Users per second: 1405
# Fold 2: hyperparams {'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, ended with MAP 0.049213144005688575
# [{'Fold': 0, 'MAP': 0.04990808065650559, 'epochs': -1, 'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, {'Fold': 1, 'MAP': 0.04949897766759966, 'epochs': -1, 'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, {'Fold': 2, 'MAP': 0.049213144005688575, 'epochs': -1, 'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}, {'Fold': 3, 'MAP': 0.04852112247937658, 'epochs': -1, 'alpha1': 0.7021813478739954, 'alpha2': 1.9995928586282419, 'alpha3': 0.7444367637825715, 'min_interaction': 2}]
# Finished trial with Average MAP: 0.0492853312022926
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 7.6087
# Function value obtained: -0.0493
# Current minimum: -0.0512
# Iteration No: 11 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.19 sec. Users per second: 1457
# Fold 0: hyperparams {'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, ended with MAP 0.05108031849103333
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.26 sec. Users per second: 1438
# Fold 2: hyperparams {'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, ended with MAP 0.051096579583850346
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.46 sec. Users per second: 1405
# Fold 1: hyperparams {'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, ended with MAP 0.051029271548436846
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.49 sec. Users per second: 1394
# Fold 3: hyperparams {'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, ended with MAP 0.05049804930908988
# [{'Fold': 0, 'MAP': 0.05108031849103333, 'epochs': -1, 'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, {'Fold': 1, 'MAP': 0.051029271548436846, 'epochs': -1, 'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, {'Fold': 2, 'MAP': 0.051096579583850346, 'epochs': -1, 'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}, {'Fold': 3, 'MAP': 0.05049804930908988, 'epochs': -1, 'alpha1': 1.931204723325902, 'alpha2': 1.0578812818544878, 'alpha3': 0.011170816501541048, 'min_interaction': 6}]
# Finished trial with Average MAP: 0.0509260547331026
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 7.6797
# Function value obtained: -0.0509
# Current minimum: -0.0512
# Iteration No: 12 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.13 sec. Users per second: 1466
# Fold 2: hyperparams {'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, ended with MAP 0.0405743485500382
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.35 sec. Users per second: 1422
# Fold 3: hyperparams {'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, ended with MAP 0.04091645237183399
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.42 sec. Users per second: 1414
# Fold 1: hyperparams {'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, ended with MAP 0.041122635998208514
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.48 sec. Users per second: 1400
# Fold 0: hyperparams {'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, ended with MAP 0.04133220712527492
# [{'Fold': 0, 'MAP': 0.04133220712527492, 'epochs': -1, 'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, {'Fold': 1, 'MAP': 0.041122635998208514, 'epochs': -1, 'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, {'Fold': 2, 'MAP': 0.0405743485500382, 'epochs': -1, 'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}, {'Fold': 3, 'MAP': 0.04091645237183399, 'epochs': -1, 'alpha1': 1.2633395914696715, 'alpha2': 0.07932012362206364, 'alpha3': 1.9989081909041377, 'min_interaction': 4}]
# Finished trial with Average MAP: 0.04098641101133891
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 7.6698
# Function value obtained: -0.0410
# Current minimum: -0.0512
# Iteration No: 13 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.12 sec. Users per second: 1468
# Fold 3: hyperparams {'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, ended with MAP 0.047006487358125355
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.28 sec. Users per second: 1439
# Fold 0: hyperparams {'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, ended with MAP 0.04818848372682463
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.47 sec. Users per second: 1404
# Fold 1: hyperparams {'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, ended with MAP 0.047884411360527526
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.56 sec. Users per second: 1382
# Fold 2: hyperparams {'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, ended with MAP 0.04764170707844183
# [{'Fold': 0, 'MAP': 0.04818848372682463, 'epochs': -1, 'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, {'Fold': 1, 'MAP': 0.047884411360527526, 'epochs': -1, 'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, {'Fold': 2, 'MAP': 0.04764170707844183, 'epochs': -1, 'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}, {'Fold': 3, 'MAP': 0.047006487358125355, 'epochs': -1, 'alpha1': 1.5925572649050708, 'alpha2': 1.983738496965304, 'alpha3': 1.5855895099633754, 'min_interaction': 8}]
# Finished trial with Average MAP: 0.047680272380979834
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 7.7724
# Function value obtained: -0.0477
# Current minimum: -0.0512
# Iteration No: 14 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.02 sec. Users per second: 1492
# Fold 0: hyperparams {'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, ended with MAP 0.05079830795954796
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.04 sec. Users per second: 1489
# Fold 1: hyperparams {'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, ended with MAP 0.05029015776155424
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.07 sec. Users per second: 1478
# Fold 3: hyperparams {'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, ended with MAP 0.04965937760269495
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.38 sec. Users per second: 1416
# Fold 2: hyperparams {'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, ended with MAP 0.05034320003524704
# [{'Fold': 0, 'MAP': 0.05079830795954796, 'epochs': -1, 'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, {'Fold': 1, 'MAP': 0.05029015776155424, 'epochs': -1, 'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, {'Fold': 2, 'MAP': 0.05034320003524704, 'epochs': -1, 'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}, {'Fold': 3, 'MAP': 0.04965937760269495, 'epochs': -1, 'alpha1': 0.01, 'alpha2': 1.739712788160434, 'alpha3': 0.01, 'min_interaction': 1}]
# Finished trial with Average MAP: 0.050272760839761045
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 7.5583
# Function value obtained: -0.0503
# Current minimum: -0.0512
# Iteration No: 15 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.07 sec. Users per second: 1476
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.08 sec. Users per second: 1480
# Fold 3: hyperparams {'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, ended with MAP 0.05030697354902698
# Fold 0: hyperparams {'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, ended with MAP 0.05135902845986938
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.34 sec. Users per second: 1423
# Fold 2: hyperparams {'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, ended with MAP 0.05106393112375172
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.35 sec. Users per second: 1427
# Fold 1: hyperparams {'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, ended with MAP 0.051136620234160816
# [{'Fold': 0, 'MAP': 0.05135902845986938, 'epochs': -1, 'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, {'Fold': 1, 'MAP': 0.051136620234160816, 'epochs': -1, 'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, {'Fold': 2, 'MAP': 0.05106393112375172, 'epochs': -1, 'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}, {'Fold': 3, 'MAP': 0.05030697354902698, 'epochs': -1, 'alpha1': 2.0, 'alpha2': 2.0, 'alpha3': 0.3430078024259934, 'min_interaction': 10}]
# Finished trial with Average MAP: 0.05096663834170222
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 7.5452
# Function value obtained: -0.0510
# Current minimum: -0.0512
# Iteration No: 16 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.50 sec. Users per second: 1614
# Fold 1: hyperparams {'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, ended with MAP 0.04871253844151506
# EvaluatorHoldout: Processed 10472 (100.0%) in 6.93 sec. Users per second: 1512
# Fold 0: hyperparams {'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, ended with MAP 0.04897371827518941
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.01 sec. Users per second: 1490
# Fold 3: hyperparams {'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, ended with MAP 0.048083607661116974
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.02 sec. Users per second: 1489
# Fold 2: hyperparams {'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, ended with MAP 0.048755666763898586
# [{'Fold': 0, 'MAP': 0.04897371827518941, 'epochs': -1, 'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, {'Fold': 1, 'MAP': 0.04871253844151506, 'epochs': -1, 'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, {'Fold': 2, 'MAP': 0.048755666763898586, 'epochs': -1, 'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}, {'Fold': 3, 'MAP': 0.048083607661116974, 'epochs': -1, 'alpha1': 1.9992963990864578, 'alpha2': 0.04965951203440417, 'alpha3': 0.48654562561924114, 'min_interaction': 10}]
# Finished trial with Average MAP: 0.04863138278543001
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 7.2237
# Function value obtained: -0.0486
# Current minimum: -0.0512
# Iteration No: 17 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.11 sec. Users per second: 1469
# Fold 3: hyperparams {'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, ended with MAP 0.050355972594578996
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.38 sec. Users per second: 1415
# Fold 2: hyperparams {'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, ended with MAP 0.051083062149056196
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.55 sec. Users per second: 1387
# Fold 0: hyperparams {'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, ended with MAP 0.05139699819321726
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.56 sec. Users per second: 1387
# Fold 1: hyperparams {'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, ended with MAP 0.05114392260845396
# [{'Fold': 0, 'MAP': 0.05139699819321726, 'epochs': -1, 'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, {'Fold': 1, 'MAP': 0.05114392260845396, 'epochs': -1, 'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, {'Fold': 2, 'MAP': 0.051083062149056196, 'epochs': -1, 'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}, {'Fold': 3, 'MAP': 0.050355972594578996, 'epochs': -1, 'alpha1': 0.11173899354402707, 'alpha2': 0.12318013088355752, 'alpha3': 0.02087867251975633, 'min_interaction': 5}]
# Finished trial with Average MAP: 0.05099498888632661
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 7.7655
# Function value obtained: -0.0510
# Current minimum: -0.0512
# Iteration No: 18 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10472 (100.0%) in 6.95 sec. Users per second: 1507
# Fold 0: hyperparams {'alpha1': 0.5021077297641435, 'alpha2': 1.9874555918235834, 'alpha3': 0.07457576040809866, 'min_interaction': 10}, ended with MAP 0.05156727842652266
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.17 sec. Users per second: 1457
# Fold 3: hyperparams {'alpha1': 0.5021077297641435, 'alpha2': 1.9874555918235834, 'alpha3': 0.07457576040809866, 'min_interaction': 10}, ended with MAP 0.05023403731465839
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.41 sec. Users per second: 1410
# ...
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.07 sec. Users per second: 1483
# Fold 1: hyperparams {'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, ended with MAP 0.04482413007155639
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.29 sec. Users per second: 1437
# Fold 0: hyperparams {'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, ended with MAP 0.04504990253677272
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.31 sec. Users per second: 1429
# Fold 3: hyperparams {'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, ended with MAP 0.044402201005514494
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.36 sec. Users per second: 1420
# Fold 2: hyperparams {'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, ended with MAP 0.04426363593548754
# [{'Fold': 0, 'MAP': 0.04504990253677272, 'epochs': -1, 'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, {'Fold': 1, 'MAP': 0.04482413007155639, 'epochs': -1, 'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, {'Fold': 2, 'MAP': 0.04426363593548754, 'epochs': -1, 'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}, {'Fold': 3, 'MAP': 0.044402201005514494, 'epochs': -1, 'alpha1': 0.7399771951316096, 'alpha2': 1.0495774252122956, 'alpha3': 1.4450459601680354, 'min_interaction': 7}]
# Finished trial with Average MAP: 0.04463496738733279
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 8.1851
# Function value obtained: -0.0446
# Current minimum: -0.0513
# Iteration No: 96 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 6.94 sec. Users per second: 1506
# Fold 3: hyperparams {'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, ended with MAP 0.045710999100266395
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.98 sec. Users per second: 1503
# Fold 1: hyperparams {'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, ended with MAP 0.04619629917184328
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.20 sec. Users per second: 1453
# Fold 0: hyperparams {'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, ended with MAP 0.04647027371554737
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.44 sec. Users per second: 1403
# Fold 2: hyperparams {'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, ended with MAP 0.04587784705510635
# [{'Fold': 0, 'MAP': 0.04647027371554737, 'epochs': -1, 'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, {'Fold': 1, 'MAP': 0.04619629917184328, 'epochs': -1, 'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, {'Fold': 2, 'MAP': 0.04587784705510635, 'epochs': -1, 'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}, {'Fold': 3, 'MAP': 0.045710999100266395, 'epochs': -1, 'alpha1': 1.5796958572102147, 'alpha2': 0.68956057184268, 'alpha3': 1.356284267757506, 'min_interaction': 2}]
# Finished trial with Average MAP: 0.046063854760690845
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 8.3052
# Function value obtained: -0.0461
# Current minimum: -0.0513
# Iteration No: 97 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10448 (100.0%) in 6.70 sec. Users per second: 1560
# Fold 2: hyperparams {'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, ended with MAP 0.04868085940348625
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.86 sec. Users per second: 1528
# Fold 1: hyperparams {'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, ended with MAP 0.04905121726417562
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.04 sec. Users per second: 1484
# Fold 3: hyperparams {'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, ended with MAP 0.048012077261647045
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.09 sec. Users per second: 1478
# Fold 0: hyperparams {'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, ended with MAP 0.049505893266398135
# [{'Fold': 0, 'MAP': 0.049505893266398135, 'epochs': -1, 'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, {'Fold': 1, 'MAP': 0.04905121726417562, 'epochs': -1, 'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, {'Fold': 2, 'MAP': 0.04868085940348625, 'epochs': -1, 'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}, {'Fold': 3, 'MAP': 0.048012077261647045, 'epochs': -1, 'alpha1': 0.448093063392533, 'alpha2': 1.4675791222727939, 'alpha3': 0.6141543293844985, 'min_interaction': 5}]
# Finished trial with Average MAP: 0.04881251179892677
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 7.9113
# Function value obtained: -0.0488
# Current minimum: -0.0513
# Iteration No: 98 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 6.88 sec. Users per second: 1518
# Fold 3: hyperparams {'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, ended with MAP 0.044056734177138894
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.95 sec. Users per second: 1508
# Fold 1: hyperparams {'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, ended with MAP 0.04425802201760506
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.06 sec. Users per second: 1480
# Fold 2: hyperparams {'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, ended with MAP 0.04380057168988106
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.17 sec. Users per second: 1461
# Fold 0: hyperparams {'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, ended with MAP 0.044417937629597816
# [{'Fold': 0, 'MAP': 0.044417937629597816, 'epochs': -1, 'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, {'Fold': 1, 'MAP': 0.04425802201760506, 'epochs': -1, 'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, {'Fold': 2, 'MAP': 0.04380057168988106, 'epochs': -1, 'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}, {'Fold': 3, 'MAP': 0.044056734177138894, 'epochs': -1, 'alpha1': 1.9591425092067007, 'alpha2': 0.4387373560130801, 'alpha3': 1.993962184754005, 'min_interaction': 2}]
# Finished trial with Average MAP: 0.044133316378555706
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 8.0597
# Function value obtained: -0.0441
# Current minimum: -0.0513
# Iteration No: 99 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
#
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 7.13 sec. Users per second: 1470
# Fold 1: hyperparams {'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, ended with MAP 0.04643999794171488
# EvaluatorHoldout: Processed 10472 (100.0%) in 7.18 sec. Users per second: 1458
# Fold 0: hyperparams {'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, ended with MAP 0.04683293393114875
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.35 sec. Users per second: 1421
# Fold 3: hyperparams {'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, ended with MAP 0.045707036165673336
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.48 sec. Users per second: 1396
# Fold 2: hyperparams {'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, ended with MAP 0.045995082980870225
# [{'Fold': 0, 'MAP': 0.04683293393114875, 'epochs': -1, 'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, {'Fold': 1, 'MAP': 0.04643999794171488, 'epochs': -1, 'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, {'Fold': 2, 'MAP': 0.045995082980870225, 'epochs': -1, 'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}, {'Fold': 3, 'MAP': 0.045707036165673336, 'epochs': -1, 'alpha1': 1.324135205593057, 'alpha2': 1.986834468514508, 'alpha3': 1.9919255098532391, 'min_interaction': 4}]
# Finished trial with Average MAP: 0.0462437627548518
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 8.4201
# Function value obtained: -0.0462
# Current minimum: -0.0513
# Iteration No: 100 started. Searching for the next optimal point.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
#
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.RP3betaSLIMElasticNetImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
#
# EvaluatorHoldout: Processed 10488 (100.0%) in 6.79 sec. Users per second: 1545
# Fold 1: hyperparams {'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, ended with MAP 0.05002291734771773
# EvaluatorHoldout: Processed 10472 (100.0%) in 6.89 sec. Users per second: 1521
# Fold 0: hyperparams {'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, ended with MAP 0.050282988195278724
# EvaluatorHoldout: Processed 10444 (100.0%) in 7.06 sec. Users per second: 1480
# Fold 3: hyperparams {'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, ended with MAP 0.0491064551379094
# EvaluatorHoldout: Processed 10448 (100.0%) in 7.26 sec. Users per second: 1440
# Fold 2: hyperparams {'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, ended with MAP 0.04979052723692896
# [{'Fold': 0, 'MAP': 0.050282988195278724, 'epochs': -1, 'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, {'Fold': 1, 'MAP': 0.05002291734771773, 'epochs': -1, 'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, {'Fold': 2, 'MAP': 0.04979052723692896, 'epochs': -1, 'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}, {'Fold': 3, 'MAP': 0.0491064551379094, 'epochs': -1, 'alpha1': 1.9892096418179486, 'alpha2': 1.4546077011801022, 'alpha3': 0.7796108421086425, 'min_interaction': 5}]
# Finished trial with Average MAP: 0.0498007219794587
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 8.1853
# Function value obtained: -0.0498
# Current minimum: -0.0513

# %%
import pandas as pd
result = load( output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl")
results_df = pd.DataFrame(result.x_iters, columns=[dim for dim in hyperparameters_range_dictionary])
results_df['score'] = result.func_vals

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'alpha1': 0.23481122211936276,
#  'alpha2': 0.3605103645601231,
#  'alpha3': 0.01,
#  'min_interaction': 4}

# %%
results_df['score'].min()
# Out:
# -0.051274746167935
