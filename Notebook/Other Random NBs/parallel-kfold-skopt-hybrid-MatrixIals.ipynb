# %%
import os
os.chdir( "../")

# %%
rp3_best_params = {'topK': 29,
 'alpha': 0.33723025040409343,
 'beta': 0.15542352567862933,
 'normalize_similarity': True}

slimen_best_params = {'topK': 638, 'l1_ratio': 0.026639245044358113, 'alpha': 0.001535792379351249}

# %%
import psutil
num_cpus = psutil.cpu_count(logical=False)
num_cpus
# Out:
# 8

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

seeds = [
    1811854, 3772146, 6407100, 6926227, 1340378, 
    68679, 3822303, 4058970, 1264160, 1100338, 
    6552126, 725363, 8362134, 9446122, 5256199, 
    4686339, 3830906, 7315366, 9428914, 5564236, 
    3420043, 9223036, 851434, 3300082, 7899660, 
    2053768, 4305274, 3709256, 8795594, 1418903, 
    7428566, 157832
]

seeds = seeds[:num_cpus]

urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation = []
urm_test = []
urm_train = []
urm_validation = []

for i in range(len(seeds)):
    a, b = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=seeds[i])
    c, d = split_train_in_two_percentage_global_sample(a, train_percentage = 0.80,seed=seeds[i])
    urm_train_validation.append(a)
    urm_test.append(b)
    urm_train.append(c)
    urm_validation.append(d)
# Out:
# Warning: 229 (1.81 %) of 12638 users have no train items
# Warning: 2166 (17.14 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2565 (20.30 %) of 12638 users have no sampled items
# Warning: 217 (1.72 %) of 12638 users have no train items
# Warning: 2150 (17.01 %) of 12638 users have no sampled items
# Warning: 453 (3.58 %) of 12638 users have no train items
# Warning: 2625 (20.77 %) of 12638 users have no sampled items
# Warning: 223 (1.76 %) of 12638 users have no train items
# Warning: 2190 (17.33 %) of 12638 users have no sampled items
# Warning: 446 (3.53 %) of 12638 users have no train items
# Warning: 2596 (20.54 %) of 12638 users have no sampled items
# Warning: 227 (1.80 %) of 12638 users have no train items
# Warning: 2194 (17.36 %) of 12638 users have no sampled items
# Warning: 450 (3.56 %) of 12638 users have no train items
# Warning: 2666 (21.10 %) of 12638 users have no sampled items
# Warning: 243 (1.92 %) of 12638 users have no train items
# Warning: 2165 (17.13 %) of 12638 users have no sampled items
# Warning: 474 (3.75 %) of 12638 users have no train items
# Warning: 2621 (20.74 %) of 12638 users have no sampled items
# Warning: 239 (1.89 %) of 12638 users have no train items
# Warning: 2145 (16.97 %) of 12638 users have no sampled items
# Warning: 481 (3.81 %) of 12638 users have no train items
# Warning: 2652 (20.98 %) of 12638 users have no sampled items
# Warning: 201 (1.59 %) of 12638 users have no train items
# Warning: 2171 (17.18 %) of 12638 users have no sampled items
# Warning: 443 (3.51 %) of 12638 users have no train items
# Warning: 2570 (20.34 %) of 12638 users have no sampled items
# Warning: 220 (1.74 %) of 12638 users have no train items
# Warning: 2198 (17.39 %) of 12638 users have no sampled items
# Warning: 467 (3.70 %) of 12638 users have no train items
# Warning: 2646 (20.94 %) of 12638 users have no sampled items

# %%
from Recommenders.Recommender_import_list import *
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from concurrent.futures import ProcessPoolExecutor

recommenderClass = SLIMElasticNetRecommender
earlystopping_keywargs = {}

def build_fold(fold, **hyperparams):
    recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1
    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )

    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]
    else:
        recommender.fit(**hyperparams)

    recommender.save_model("/home/japo/RecSys-Challenge/result_experiments_more_data/Hybrids/", recommender.RECOMMENDER_NAME + "_split_" + str(fold) + ".zip")
    return 1

def prepare_models(fold, hyperparameters):
    return build_fold(fold, **hyperparameters)

#with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
#    fold_results = list(executor.map(prepare_models, range(len(seeds)), [slimen_best_params]*len(seeds)))
# Out:
# 2024-01-04 22:59:56.244937: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-04 22:59:56.244971: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = []
for u in urm_validation:
    evaluator_validation.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2565 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2625 (20.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2596 (20.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2666 (21.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2621 (20.7%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2652 (21.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2570 (20.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2646 (20.9%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = []
for u in urm_test:
    evaluator_test.append(EvaluatorHoldout(u, cutoff_list=[10], ignore_users=[]))
# Out:
# EvaluatorHoldout: Ignoring 2166 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2150 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2190 (17.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2194 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2165 (17.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2145 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2171 (17.2%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2198 (17.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_more_data/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 500  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial
from skopt.space import Real, Integer, Categorical

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from concurrent.futures import ProcessPoolExecutor
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
import time
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender

# %%
n_points = 10000
n_jobs = 1  # Using all available CPUs
acq_func = 'gp_hedge'
acq_optimizer = 'auto'
verbose = True
n_restarts_optimizer = 10
xi = 0.01
kappa = 1.96
x0 = None
y0 = None
noise = 1e-5
random_state = int(os.getpid() + time.time()) % np.iinfo(int).max
model_counter=0

# %%
rp3s = []
slims = []
ials = []
KNNs = []
for i in range(len(seeds)):
    rp3 = RP3betaRecommender(urm_train_validation[i],verbose=True)
    rp3.load_model("result_experiments_more_data/Hybrids", rp3.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    rp3s.append(rp3)

    slim = SLIMElasticNetRecommender(urm_train_validation[i], verbose=True)
    slim.load_model("result_experiments_more_data/Hybrids", slim.RECOMMENDER_NAME + "_split_" + str(i) + ".zip")
    slims.append(slim)

    ials_model = ImplicitALSRecommender(urm_train_validation[i], verbose=True)
    ials_model.fit(**{'use_gpu': True, 'num_threads' : 1, 'num_factors': 128, 'epochs': 478, 'confidence_scaling': 'linear', 'alpha': 3.358295366834473, 'epsilon': 7.295986722921583, 'reg': 6.292360640597378e-05})
    ials.append(ials_model)

    knn = ItemKNNCFRecommender(urm_train_validation[i], verbose=True)
    knn.fit(**{'topK': 19, 'shrink': 28, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 1.3672226785339947})
    KNNs.append(knn)
# Out:
# RP3betaRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_0.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_0.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# Similarity column 22222 (100.0%), 6383.97 column/sec. Elapsed time 3.48 sec
# RP3betaRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# RP3betaRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_1.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_1.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ImplicitALSRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 6466.18 column/sec. Elapsed time 3.44 sec
# RP3betaRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_2.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_2.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 11424.48 column/sec. Elapsed time 1.95 sec
# RP3betaRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# RP3betaRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_3.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_3.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ImplicitALSRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 5265.51 column/sec. Elapsed time 4.22 sec
# RP3betaRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# RP3betaRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_4.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_4.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ImplicitALSRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 10951.59 column/sec. Elapsed time 2.03 sec
# RP3betaRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# RP3betaRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_5.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_5.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ImplicitALSRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 6343.47 column/sec. Elapsed time 3.50 sec
# RP3betaRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# RP3betaRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_6.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_6.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ImplicitALSRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 6978.78 column/sec. Elapsed time 3.18 sec
# RP3betaRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# RP3betaRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments_more_data/HybridsRP3betaRecommender_split_7.zip'
# RP3betaRecommender: Loading complete
# SLIMElasticNetRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# SLIMElasticNetRecommender: Loading model from file 'result_experiments_more_data/HybridsSLIMElasticNetRecommender_split_7.zip'
# SLIMElasticNetRecommender: Loading complete
# ImplicitALSRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ImplicitALSRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# Using gpu: True
#   0%|          | 0/478 [00:00<?, ?it/s]
# ItemKNNCFRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# Similarity column 22222 (100.0%), 12013.04 column/sec. Elapsed time 1.85 sec

# %%
from Recommenders.MatrixFactorization.ImplicitIALSRecommender import ImplicitALSRecommender
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from Recommenders.Hybrid.GeneralizedLinearHybridRecommenderCold import GeneralizedLinearHybridRecommenderCold
from Recommenders.Hybrid.GeneralizedLinearHybridRecommender import GeneralizedLinearHybridRecommender
from Recommenders.Hybrid.GeneralizedLinearCoupleHybridRecommender import GeneralizedLinearCoupleHybridRecommender

recommenderClass = GeneralizedLinearCoupleHybridRecommender

recommenderClass.RECOMMENDER_NAME = "MISCHIOTTO"

hyperparameters_range_dictionary = {
        "topK": Integer(5, 300),
        "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
        "beta": Real(low = 0, high = 1.35, prior = 'uniform'),
        "normalize_similarity": Categorical([True, False]),
        #"implicit" : Categorical([True])
}

hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "alpha" : Real(low = 0 , high=1, prior = 'uniform') 
}

hyperparameters_range_dictionary = {
    "alpha1": Real(low = 0.01, high = 1, prior = 'uniform'),
    #"alpha2": Real(low = 0.01, high = 2, prior = 'uniform'),
    #"alpha3": Real(low = 0.01, high = 2, prior = 'uniform'),
    #"min_interaction" : Integer(low=1, high=5)
}


#hyperparameters_range_dictionary = {
#                "topK": Integer(5, 1000),
#                "l1_ratio": Real(low = 1e-5, high = 1.0, prior = 'log-uniform'),
#                "alpha": Real(low = 1e-3, high = 1.0, prior = 'uniform'),
#            }

#IALS
#hyperparameters_range_dictionary = {
#                "num_factors": Integer(1, 500),
#                "epochs": Integer(50,2500),
#                "confidence_scaling": Categorical(["linear", "log"]),
#                "alpha": Real(low = 1e-3, high = 50.0, prior = 'log-uniform'),
#                "epsilon": Real(low = 1e-3, high = 10.0, prior = 'log-uniform'),
#                "reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
#            }

hyperparameters_range_dictionary
# Out:
# {'alpha1': Real(low=0.01, high=1, prior='uniform', transform='identity')}

# %%
if issubclass(recommenderClass, Incremental_Training_Early_Stopping):
    print("Using EarlyStop")

# %%
from concurrent.futures import ProcessPoolExecutor
import os

import multiprocessing
from skopt import dump
from skopt.callbacks import CheckpointSaver

# Define a function to save your optimization after every `n` calls
def checkpoint_saver(n_calls=10, checkpoint_path="checkpoint.pkl"):
    return CheckpointSaver(checkpoint_path, compress=9) # keyword arguments will be passed to `skopt.dump`

print(f"RUNNING ON {num_cpus} threads")

sum_map = lambda results: sum(item[metric_to_optimize] for item in results)

hyperparams = dict()
hyperparams_names = list()
hyperparams_values = list()

skopt_types = [Real, Integer, Categorical]

for name, hyperparam in hyperparameters_range_dictionary.items():
    if any(isinstance(hyperparam, sko_type) for sko_type in skopt_types):
        hyperparams_names.append(name)
        hyperparams_values.append(hyperparam)
        hyperparams[name] = hyperparam

columns = ["Fold",metric_to_optimize]
for h in hyperparams_names:
    columns.append(h)

fold_results_df = pd.DataFrame(columns=columns)
if os.path.exists(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv"):
    fold_results_df = pd.read_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")


def run_fold(fold, **hyperparams):
    # Fit the model on this fold and return the evaluation metric
    # ...
    if issubclass(recommenderClass, GeneralizedLinearHybridRecommender):

        alphas = [hyperparams["alpha1"], hyperparams["alpha2"], hyperparams["alpha3"]]
        minint = hyperparams["min_interaction"]

        recsys_s = [rp3s[fold], slims[fold],ials[fold]]

        recommender = GeneralizedLinearHybridRecommender(urm_train_validation[fold], recsys_s, verbose=True)

    elif issubclass(recommenderClass, GeneralizedLinearCoupleHybridRecommender):
        alpha = hyperparams["alpha1"]
        #minint = hyperparams["min_interaction"]

        rec1 = ItemKNNSimilarityHybridRecommender(urm_train_validation[fold], rp3s[fold].W_sparse, slims[fold].W_sparse)
        rec1.fit(**{'topK': 1000, 'alpha': 0.446039762079027})

        recsys_s = [rec1,ials[fold]]

        recommender = GeneralizedLinearCoupleHybridRecommender(urm_train_validation[fold], recommenders=recsys_s, verbose=True )#COLD_recommender=KNNs[fold])#, COLD_Under_Interactions=minint)
    
    
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold):
        alphas = [hyperparams["alpha1"], hyperparams["alpha2"]]
        minint = hyperparams["min_interaction"]

        rec1 = ItemKNNSimilarityHybridRecommender(urm_train_validation[fold], rp3s[fold].W_sparse, slims[fold].W_sparse)
        rec1.fit(**{'topK': 1000, 'alpha': 0.446039762079027})

        recsys_s = [rec1,ials[fold]]

        recommender = GeneralizedLinearHybridRecommenderCold(urm_train_validation[fold], recommenders=recsys_s, verbose=True, COLD_recommender=KNNs[fold], COLD_Under_Interactions=minint)
    else:
        recommender = recommenderClass(urm_train_validation[fold], verbose=True)
    epochs = -1

    if issubclass(recommenderClass, ImplicitALSRecommender):
        recommender.fit(
            use_gpu=True,
            num_threads=1,
            **hyperparams
        )
    elif issubclass(recommenderClass, Incremental_Training_Early_Stopping):
        ea_args = {**earlystopping_keywargs}
        ea_args["evaluator_object"] = ea_args["evaluator_object"][fold]
        recommender.fit(**hyperparams, **ea_args)
        epochs = recommender.get_early_stopping_final_epochs_dict()["epochs"]        
    elif issubclass(recommenderClass, GeneralizedLinearHybridRecommenderCold) or issubclass(recommenderClass, GeneralizedLinearHybridRecommender):
        recommender.fit(alphas)
    elif issubclass(recommenderClass, GeneralizedLinearCoupleHybridRecommender):
        recommender.fit(alpha)
    else:
        recommender.fit(**hyperparams)

    result, _ = evaluator_test[fold].evaluateRecommender(recommender)
    metric_result = result[metric_to_optimize].item()
    
    print(f"Fold {fold}: hyperparams {hyperparams}, ended with {metric_to_optimize} {metric_result}")

    return {'Fold': fold, metric_to_optimize: metric_result, 'epochs': epochs, **hyperparams}

def run_fold_wrapper(fold, hyperparameters):
    return run_fold(fold, **hyperparameters)


def evaluate_model(hyperparams):

    global fold_results_df

    current_fit_hyperparameters_dict = dict(zip(hyperparams_names, hyperparams))

    if issubclass(recommenderClass, ImplicitALSRecommender):
        fold_results=[]
        for i, seed in  enumerate(seeds):
            fold_results.append(run_fold(i, **current_fit_hyperparameters_dict))
    else:
        # Start the process pool
        with ProcessPoolExecutor(max_workers=num_cpus) as executor:
            # Submit all tasks to the process pool and wait for them to complete
            #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
            fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))


    print(fold_results)
    for res in fold_results:
        fold_results_df = pd.concat([fold_results_df, pd.DataFrame([res])], ignore_index=True)
    fold_results_df.to_csv(output_folder_path + recommenderClass.RECOMMENDER_NAME + "_folds_results.csv")

    # Compute average score across all folds
    average_score = sum_map(fold_results) / len(fold_results)

    print(f"Finished trial with Average {metric_to_optimize}: {average_score}")

    return -average_score  # Assuming a score that needs to be minimized




from skopt import load
checkpointPath = output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl"
print(checkpointPath)
checkpoint_callback = checkpoint_saver(n_calls=1, checkpoint_path=checkpointPath)

if os.path.exists(checkpointPath):
    res = load(checkpointPath)
    #UNCOMMENT TO RESTART LAST CHECKPOINT
    x0 = res.x_iters
    y0 = res.func_vals
    model_counter = len(res.x_iters)
    res.fun

print(f"Still need to run {n_cases - model_counter} trials")

result = gp_minimize(evaluate_model, hyperparams_values,
                     base_estimator=None,
                     n_calls=max(0, n_cases - model_counter),
                     n_initial_points= max(0, n_random_starts - model_counter),
                     initial_point_generator = "random",
                     acq_func=acq_func,
                     acq_optimizer=acq_optimizer,
                     x0=x0,
                     y0=y0,
                     random_state=random_state,
                     verbose=verbose,
                     callback=[checkpoint_callback],
                     n_points=n_points,
                     n_restarts_optimizer=n_restarts_optimizer,
                     xi=xi,
                     kappa=kappa,
                     noise=noise,
                     n_jobs=1
                    )
# Out:
# RUNNING ON 8 threads
# result_experiments_more_data/MISCHIOTTO_checkpoint.pkl
# Still need to run 500 trials
# Iteration No: 1 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10472 (100.0%) in 14.79 sec. Users per second: 708
# Fold 0: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.04049296233645032
# EvaluatorHoldout: Processed 10444 (100.0%) in 14.85 sec. Users per second: 703
# Fold 3: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.04048640747630647
# EvaluatorHoldout: Processed 10467 (100.0%) in 14.98 sec. Users per second: 699
# Fold 6: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.04017271591289971
# EvaluatorHoldout: Processed 10488 (100.0%) in 14.96 sec. Users per second: 701
# Fold 1: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.04013747003378045
# EvaluatorHoldout: Processed 10448 (100.0%) in 15.57 sec. Users per second: 671
# EvaluatorHoldout: Processed 10440 (100.0%) in 14.96 sec. Users per second: 698
# Fold 2: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.03971818484285031
# Fold 7: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.03953671775223551
# EvaluatorHoldout: Processed 10473 (100.0%) in 15.58 sec. Users per second: 672
# Fold 4: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.04049108137478268
# EvaluatorHoldout: Processed 10493 (100.0%) in 16.10 sec. Users per second: 652
# Fold 5: hyperparams {'alpha1': 0.3390298641473788}, ended with MAP 0.039881349471076404
# [{'Fold': 0, 'MAP': 0.04049296233645032, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 1, 'MAP': 0.04013747003378045, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 2, 'MAP': 0.03971818484285031, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 3, 'MAP': 0.04048640747630647, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 4, 'MAP': 0.04049108137478268, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 5, 'MAP': 0.039881349471076404, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 6, 'MAP': 0.04017271591289971, 'epochs': -1, 'alpha1': 0.3390298641473788}, {'Fold': 7, 'MAP': 0.03953671775223551, 'epochs': -1, 'alpha1': 0.3390298641473788}]
# Finished trial with Average MAP: 0.04011461115004773
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 23.4242
# Function value obtained: -0.0401
# Current minimum: -0.0401
# Iteration No: 2 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 12.79 sec. Users per second: 817
# EvaluatorHoldout: Processed 10488 (100.0%) in 12.85 sec. Users per second: 816
# Fold 3: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.042356783419355795
# Fold 1: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.042305306593779686
# EvaluatorHoldout: Processed 10467 (100.0%) in 12.86 sec. Users per second: 814
# Fold 6: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.04233460490339305
# EvaluatorHoldout: Processed 10440 (100.0%) in 13.35 sec. Users per second: 782
# Fold 7: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.04165532445417561
# EvaluatorHoldout: Processed 10473 (100.0%) in 13.57 sec. Users per second: 772
# Fold 4: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.04247650420810016
# EvaluatorHoldout: Processed 10472 (100.0%) in 13.34 sec. Users per second: 785
# Fold 0: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.0425595654928643
# EvaluatorHoldout: Processed 10493 (100.0%) in 13.44 sec. Users per second: 781
# Fold 5: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.042088115432965
# EvaluatorHoldout: Processed 10448 (100.0%) in 13.90 sec. Users per second: 751
# Fold 2: hyperparams {'alpha1': 0.44378847459812626}, ended with MAP 0.04191960867425123
# [{'Fold': 0, 'MAP': 0.0425595654928643, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 1, 'MAP': 0.042305306593779686, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 2, 'MAP': 0.04191960867425123, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 3, 'MAP': 0.042356783419355795, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 4, 'MAP': 0.04247650420810016, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 5, 'MAP': 0.042088115432965, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 6, 'MAP': 0.04233460490339305, 'epochs': -1, 'alpha1': 0.44378847459812626}, {'Fold': 7, 'MAP': 0.04165532445417561, 'epochs': -1, 'alpha1': 0.44378847459812626}]
# Finished trial with Average MAP: 0.04221197664736061
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 20.8253
# Function value obtained: -0.0422
# Current minimum: -0.0422
# Iteration No: 3 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10467 (100.0%) in 11.83 sec. Users per second: 885
# Fold 6: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.035770983180699885
# EvaluatorHoldout: Processed 10493 (100.0%) in 11.37 sec. Users per second: 923
# Fold 5: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03570963030531348EvaluatorHoldout: Processed 10488 (100.0%) in 12.25 sec. Users per second: 856
#
# Fold 1: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03585774899204574
# EvaluatorHoldout: Processed 10444 (100.0%) in 11.25 sec. Users per second: 928
# Fold 3: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03593445465764549
# EvaluatorHoldout: Processed 10448 (100.0%) in 12.58 sec. Users per second: 830
# Fold 2: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03558627458129804
# EvaluatorHoldout: Processed 10440 (100.0%) in 12.32 sec. Users per second: 847
# Fold 7: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03517003056011729
# EvaluatorHoldout: Processed 10473 (100.0%) in 11.44 sec. Users per second: 915
# Fold 4: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03581632057641831
# EvaluatorHoldout: Processed 10472 (100.0%) in 11.58 sec. Users per second: 904
# Fold 0: hyperparams {'alpha1': 0.07084548468301743}, ended with MAP 0.03597879303236478
# [{'Fold': 0, 'MAP': 0.03597879303236478, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 1, 'MAP': 0.03585774899204574, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 2, 'MAP': 0.03558627458129804, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 3, 'MAP': 0.03593445465764549, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 4, 'MAP': 0.03581632057641831, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 5, 'MAP': 0.03570963030531348, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 6, 'MAP': 0.035770983180699885, 'epochs': -1, 'alpha1': 0.07084548468301743}, {'Fold': 7, 'MAP': 0.03517003056011729, 'epochs': -1, 'alpha1': 0.07084548468301743}]
# Finished trial with Average MAP: 0.03572802948573788
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 23.1789
# Function value obtained: -0.0357
# Current minimum: -0.0422
# Iteration No: 4 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10472 (100.0%) in 14.15 sec. Users per second: 740
# Fold 0: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.03760397340754528
# EvaluatorHoldout: Processed 10467 (100.0%) in 14.70 sec. Users per second: 712
# Fold 6: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.03728447380353417
# EvaluatorHoldout: Processed 10493 (100.0%) in 14.47 sec. Users per second: 725
# Fold 5: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.037050743579620286
# EvaluatorHoldout: Processed 10440 (100.0%) in 14.52 sec. Users per second: 719
# Fold 7: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.036685048348841995
# EvaluatorHoldout: Processed 10473 (100.0%) in 15.17 sec. Users per second: 691
# Fold 4: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.037570498742799274
# EvaluatorHoldout: Processed 10444 (100.0%) in 14.78 sec. Users per second: 707
# Fold 3: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.03767104451253293
# EvaluatorHoldout: Processed 10488 (100.0%) in 15.37 sec. Users per second: 682
# Fold 1: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.03741125912607645
# EvaluatorHoldout: Processed 10448 (100.0%) in 16.06 sec. Users per second: 651
# Fold 2: hyperparams {'alpha1': 0.17695101224841467}, ended with MAP 0.03699706330975518
# [{'Fold': 0, 'MAP': 0.03760397340754528, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 1, 'MAP': 0.03741125912607645, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 2, 'MAP': 0.03699706330975518, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 3, 'MAP': 0.03767104451253293, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 4, 'MAP': 0.037570498742799274, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 5, 'MAP': 0.037050743579620286, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 6, 'MAP': 0.03728447380353417, 'epochs': -1, 'alpha1': 0.17695101224841467}, {'Fold': 7, 'MAP': 0.036685048348841995, 'epochs': -1, 'alpha1': 0.17695101224841467}]
# Finished trial with Average MAP: 0.0372842631038382
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 23.5230
# Function value obtained: -0.0373
# Current minimum: -0.0422
# Iteration No: 5 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10448 (100.0%) in 12.83 sec. Users per second: 814
# Fold 2: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03617913126838335
# EvaluatorHoldout: Processed 10444 (100.0%) in 13.07 sec. Users per second: 799
# Fold 3: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03666557619473216
# EvaluatorHoldout: Processed 10472 (100.0%) in 13.17 sec. Users per second: 795
# Fold 0: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03681507451465466
# EvaluatorHoldout: Processed 10493 (100.0%) in 13.56 sec. Users per second: 774
# Fold 5: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03633398834294696
# EvaluatorHoldout: Processed 10473 (100.0%) in 13.56 sec. Users per second: 772
# Fold 4: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03662673026179219
# EvaluatorHoldout: Processed 10440 (100.0%) in 13.79 sec. Users per second: 757
# Fold 7: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03578132031867713
# EvaluatorHoldout: Processed 10488 (100.0%) in 14.48 sec. Users per second: 724
# Fold 1: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03664439631687958
# EvaluatorHoldout: Processed 10467 (100.0%) in 15.22 sec. Users per second: 688
# Fold 6: hyperparams {'alpha1': 0.12017776007053696}, ended with MAP 0.03649936838529603
# [{'Fold': 0, 'MAP': 0.03681507451465466, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 1, 'MAP': 0.03664439631687958, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 2, 'MAP': 0.03617913126838335, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 3, 'MAP': 0.03666557619473216, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 4, 'MAP': 0.03662673026179219, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 5, 'MAP': 0.03633398834294696, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 6, 'MAP': 0.03649936838529603, 'epochs': -1, 'alpha1': 0.12017776007053696}, {'Fold': 7, 'MAP': 0.03578132031867713, 'epochs': -1, 'alpha1': 0.12017776007053696}]
# Finished trial with Average MAP: 0.03644319820042026
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 22.0100
# Function value obtained: -0.0364
# Current minimum: -0.0422
# Iteration No: 6 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 11.17 sec. Users per second: 939
# Fold 1: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03581314018742549
# EvaluatorHoldout: Processed 10472 (100.0%) in 11.15 sec. Users per second: 939
# Fold 0: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.035953335879806786
# EvaluatorHoldout: Processed 10444 (100.0%) in 11.28 sec. Users per second: 926
# Fold 3: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03589175527226131
# EvaluatorHoldout: Processed 10467 (100.0%) in 11.53 sec. Users per second: 908
# EvaluatorHoldout: Processed 10440 (100.0%) in 11.58 sec. Users per second: 901Fold 6: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03573114520162431
#
# Fold 7: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03513435048348892
# EvaluatorHoldout: Processed 10448 (100.0%) in 11.40 sec. Users per second: 916
# EvaluatorHoldout: Processed 10473 (100.0%) in 12.33 sec. Users per second: 849
# Fold 2: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03554418024866963
# Fold 4: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.035773989502864104
# EvaluatorHoldout: Processed 10493 (100.0%) in 11.97 sec. Users per second: 876
# Fold 5: hyperparams {'alpha1': 0.0676950696250717}, ended with MAP 0.03566618486398372
# [{'Fold': 0, 'MAP': 0.035953335879806786, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 1, 'MAP': 0.03581314018742549, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 2, 'MAP': 0.03554418024866963, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 3, 'MAP': 0.03589175527226131, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 4, 'MAP': 0.035773989502864104, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 5, 'MAP': 0.03566618486398372, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 6, 'MAP': 0.03573114520162431, 'epochs': -1, 'alpha1': 0.0676950696250717}, {'Fold': 7, 'MAP': 0.03513435048348892, 'epochs': -1, 'alpha1': 0.0676950696250717}]
# Finished trial with Average MAP: 0.035688510205015525
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 22.3834
# Function value obtained: -0.0357
# Current minimum: -0.0422
# Iteration No: 7 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 14.39 sec. Users per second: 729
# Fold 1: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.0507269078493339
# EvaluatorHoldout: Processed 10444 (100.0%) in 14.62 sec. Users per second: 714
# Fold 3: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.04999963524283752
# EvaluatorHoldout: Processed 10493 (100.0%) in 15.05 sec. Users per second: 697
# Fold 5: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.05048949866804685
# EvaluatorHoldout: Processed 10467 (100.0%) in 15.41 sec. Users per second: 679
# Fold 6: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.05046662526671192EvaluatorHoldout: Processed 10440 (100.0%) in 15.10 sec. Users per second: 692EvaluatorHoldout: Processed 10472 (100.0%) in 15.62 sec. Users per second: 671
#
#
# Fold 7: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.050405229428936674Fold 0: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.051132274879649504
#
# EvaluatorHoldout: Processed 10448 (100.0%) in 15.47 sec. Users per second: 675
# Fold 2: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.050608922646394404
# EvaluatorHoldout: Processed 10473 (100.0%) in 15.60 sec. Users per second: 671
# Fold 4: hyperparams {'alpha1': 0.8682008975753784}, ended with MAP 0.05103278801574484
# [{'Fold': 0, 'MAP': 0.051132274879649504, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 1, 'MAP': 0.0507269078493339, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 2, 'MAP': 0.050608922646394404, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 3, 'MAP': 0.04999963524283752, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 4, 'MAP': 0.05103278801574484, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 5, 'MAP': 0.05048949866804685, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 6, 'MAP': 0.05046662526671192, 'epochs': -1, 'alpha1': 0.8682008975753784}, {'Fold': 7, 'MAP': 0.050405229428936674, 'epochs': -1, 'alpha1': 0.8682008975753784}]
# Finished trial with Average MAP: 0.05060773524970695
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 23.8264
# Function value obtained: -0.0506
# Current minimum: -0.0506
# Iteration No: 8 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10444 (100.0%) in 12.07 sec. Users per second: 866
# Fold 3: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.04394857227967211
# EvaluatorHoldout: Processed 10467 (100.0%) in 12.67 sec. Users per second: 826
# Fold 6: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.04403900163931749
# EvaluatorHoldout: Processed 10473 (100.0%) in 13.17 sec. Users per second: 795
# EvaluatorHoldout: Processed 10493 (100.0%) in 13.38 sec. Users per second: 784
# Fold 5: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.043643335920092494Fold 4: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.04428025428956447
#
# EvaluatorHoldout: Processed 10440 (100.0%) in 13.24 sec. Users per second: 788
# Fold 7: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.043489387581342104
# EvaluatorHoldout: Processed 10488 (100.0%) in 13.79 sec. Users per second: 761
# Fold 1: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.04404412298863152
# EvaluatorHoldout: Processed 10472 (100.0%) in 13.82 sec. Users per second: 758
# Fold 0: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.044326969424133805
# EvaluatorHoldout: Processed 10448 (100.0%) in 14.57 sec. Users per second: 717
# Fold 2: hyperparams {'alpha1': 0.5263352408942455}, ended with MAP 0.04361388752157371
# [{'Fold': 0, 'MAP': 0.044326969424133805, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 1, 'MAP': 0.04404412298863152, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 2, 'MAP': 0.04361388752157371, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 3, 'MAP': 0.04394857227967211, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 4, 'MAP': 0.04428025428956447, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 5, 'MAP': 0.043643335920092494, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 6, 'MAP': 0.04403900163931749, 'epochs': -1, 'alpha1': 0.5263352408942455}, {'Fold': 7, 'MAP': 0.043489387581342104, 'epochs': -1, 'alpha1': 0.5263352408942455}]
# Finished trial with Average MAP: 0.043923191455540966
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 20.7853
# Function value obtained: -0.0439
# Current minimum: -0.0506
# Iteration No: 9 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10473 (100.0%) in 12.06 sec. Users per second: 868
# Fold 4: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.045350432480195345
# EvaluatorHoldout: Processed 10472 (100.0%) in 11.54 sec. Users per second: 908
# Fold 0: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.045533145076212755
# EvaluatorHoldout: Processed 10440 (100.0%) in 12.54 sec. Users per second: 833
# Fold 7: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.0446294395791528
# EvaluatorHoldout: Processed 10488 (100.0%) in 12.16 sec. Users per second: 862
# Fold 1: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.04532972300921454
# EvaluatorHoldout: Processed 10444 (100.0%) in 12.25 sec. Users per second: 853
# Fold 3: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.04493964408819894
# EvaluatorHoldout: Processed 10448 (100.0%) in 13.35 sec. Users per second: 783
# Fold 2: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.04480439789494208
# EvaluatorHoldout: Processed 10467 (100.0%) in 12.59 sec. Users per second: 831
# Fold 6: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.04518965122433214
# EvaluatorHoldout: Processed 10493 (100.0%) in 13.20 sec. Users per second: 795
# Fold 5: hyperparams {'alpha1': 0.5758964751421058}, ended with MAP 0.04464662760812631
# ...
# EvaluatorHoldout: Processed 10467 (100.0%) in 15.28 sec. Users per second: 685
# Fold 6: hyperparams {'alpha1': 0.1844984543952842}, ended with MAP 0.037462963721204376
# [{'Fold': 0, 'MAP': 0.037694911297852934, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 1, 'MAP': 0.03751527066458456, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 2, 'MAP': 0.03712800657526964, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 3, 'MAP': 0.03780032053035742, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 4, 'MAP': 0.03769185767180646, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 5, 'MAP': 0.03718221444681977, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 6, 'MAP': 0.037462963721204376, 'epochs': -1, 'alpha1': 0.1844984543952842}, {'Fold': 7, 'MAP': 0.03682165283099243, 'epochs': -1, 'alpha1': 0.1844984543952842}]
# Finished trial with Average MAP: 0.03741214971736095
# Iteration No: 126 ended. Evaluation done at random point.
# Time taken: 27.8282
# Function value obtained: -0.0374
# Current minimum: -0.0512
# Iteration No: 127 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
#
#
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# EvaluatorHoldout: Processed 10488 (100.0%) in 9.76 sec. Users per second: 1075
# Fold 1: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.050891158300340626
# EvaluatorHoldout: Processed 10440 (100.0%) in 9.34 sec. Users per second: 1117
# Fold 7: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.05053967873867337
# EvaluatorHoldout: Processed 10467 (100.0%) in 10.00 sec. Users per second: 1046
# Fold 6: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.0505922089226766
# EvaluatorHoldout: Processed 10493 (100.0%) in 9.67 sec. Users per second: 1086
# Fold 5: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.050662535416657786
# EvaluatorHoldout: Processed 10448 (100.0%) in 10.01 sec. Users per second: 1044
# Fold 2: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.05078506708962347
# EvaluatorHoldout: Processed 10473 (100.0%) in 9.72 sec. Users per second: 1078
# Fold 4: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.051177430550819844
# EvaluatorHoldout: Processed 10444 (100.0%) in 9.77 sec. Users per second: 1069
# Fold 3: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.05015546254247946
# EvaluatorHoldout: Processed 10472 (100.0%) in 9.83 sec. Users per second: 1065
# Fold 0: hyperparams {'alpha1': 0.885250811828315}, ended with MAP 0.05130479843452597
# [{'Fold': 0, 'MAP': 0.05130479843452597, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 1, 'MAP': 0.050891158300340626, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 2, 'MAP': 0.05078506708962347, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 3, 'MAP': 0.05015546254247946, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 4, 'MAP': 0.051177430550819844, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 5, 'MAP': 0.050662535416657786, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 6, 'MAP': 0.0505922089226766, 'epochs': -1, 'alpha1': 0.885250811828315}, {'Fold': 7, 'MAP': 0.05053967873867337, 'epochs': -1, 'alpha1': 0.885250811828315}]
# Finished trial with Average MAP: 0.05076354249947464
# Iteration No: 127 ended. Evaluation done at random point.
# Time taken: 18.3860
# Function value obtained: -0.0508
# Current minimum: -0.0512
# Iteration No: 128 started. Evaluating function at random point.
# ItemKNNSimilarityHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
#
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
#
# ItemKNNSimilarityHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.ItemKNNSimilarityHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
#
#
#
# ItemKNNSimilarityHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 201 ( 1.6%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 114 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 217 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 223 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 106 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 227 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 243 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 122 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 229 ( 1.8%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 126 ( 0.6%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 109 ( 0.5%) items with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 220 ( 1.7%) users with no interactions.
# ItemKNNSimilarityHybridImplicitALSHybridRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 10467 (100.0%) in 14.82 sec. Users per second: 706
# Fold 6: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.04817090295880857
# EvaluatorHoldout: Processed 10493 (100.0%) in 14.84 sec. Users per second: 707
# Fold 5: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.04795050819972265
# EvaluatorHoldout: Processed 10488 (100.0%) in 17.22 sec. Users per second: 609
# Fold 1: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.048496581126730595EvaluatorHoldout: Processed 10440 (100.0%) in 14.90 sec. Users per second: 701
#
# EvaluatorHoldout: Processed 10444 (100.0%) in 16.37 sec. Users per second: 638
# Fold 3: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.04755924644209856Fold 7: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.048020696496990124
#
# EvaluatorHoldout: Processed 10448 (100.0%) in 17.04 sec. Users per second: 613
# Fold 2: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.04815691922506665
# EvaluatorHoldout: Processed 10472 (100.0%) in 15.96 sec. Users per second: 656
# Fold 0: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.048915050868833014
# EvaluatorHoldout: Processed 10473 (100.0%) in 16.27 sec. Users per second: 644
# Fold 4: hyperparams {'alpha1': 0.7253814312187467}, ended with MAP 0.04867903331166062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 152
#     148     res.fun
#     150 print(f"Still need to run {n_cases - model_counter} trials")
# --> 152 result = gp_minimize(evaluate_model, hyperparams_values,
#     153                      base_estimator=None,
#     154                      n_calls=max(0, n_cases - model_counter),
#     155                      n_initial_points= max(0, n_random_starts - model_counter),
#     156                      initial_point_generator = "random",
#     157                      acq_func=acq_func,
#     158                      acq_optimizer=acq_optimizer,
#     159                      x0=x0,
#     160                      y0=y0,
#     161                      random_state=random_state,
#     162                      verbose=verbose,
#     163                      callback=[checkpoint_callback],
#     164                      n_points=n_points,
#     165                      n_restarts_optimizer=n_restarts_optimizer,
#     166                      xi=xi,
#     167                      kappa=kappa,
#     168                      noise=noise,
#     169                      n_jobs=1
#     170                     )
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py:301, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299 for n in range(n_calls):
#     300     next_x = optimizer.ask()
# --> 301     next_y = func(next_x)
#     302     result = optimizer.tell(next_x, next_y)
#     303     result.specs = specs
#
# Cell In[26], line 119, in evaluate_model(hyperparams)
#     114 else:
#     115     # Start the process pool
#     116     with ProcessPoolExecutor(max_workers=num_cpus) as executor:
#     117         # Submit all tasks to the process pool and wait for them to complete
#     118         #fold_results = list(executor.map(lambda fold: run_fold(fold, **current_fit_hyperparameters_dict), range(len(seeds))))
# --> 119         fold_results = list(executor.map(run_fold_wrapper, range(len(seeds)), [current_fit_hyperparameters_dict]*len(seeds)))
#     122 print(fold_results)
#     123 for res in fold_results:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/process.py:484, in _chain_from_iterable_of_lists(iterable)
#     478 def _chain_from_iterable_of_lists(iterable):
#     479     """
#     480     Specialized implementation of itertools.chain.from_iterable.
#     481     Each item in *iterable* should be a list.  This function is
#     482     careful not to keep references to yielded objects.
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#     486         while element:
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield fs.pop().result()
#     620     else:
#     621         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
import pandas as pd
result = load(output_folder_path + recommenderClass.RECOMMENDER_NAME +"_checkpoint.pkl")
results_df = pd.DataFrame(result.x_iters, columns=[dim for dim in hyperparameters_range_dictionary])
results_df['score'] = result.func_vals

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'alpha1': 0.9772360115456751}

# %%
results_df['score'].min()
# Out:
# -0.030128708347317946

# %%
newdict = dict()
for key in results_df[results_df["score"] == results_df["score"].min()].drop(columns=["score"]):
    newdict[key] = results_df[results_df["score"] == results_df["score"].min()][key].item()
newdict
# Out:
# {'topK': 34,
#  'alpha': 0.28453879172230406,
#  'beta': 0.15344052347036438,
#  'normalize_similarity': True}

# %%
SLIMEN = {'topK': 530, 'l1_ratio': 0.05017569359096808, 'alpha': 0.001}
P3ALPHA = {'topK': 400, 'alpha': 1.6632815179401539, 'normalize_similarity': True}
RP3 = {'topK': 71, 'alpha': 0.31274648571776065, 'beta': 0.3586324430664178, 'normalize_similarity': True}

SLIMEN_KFOLD = {'Fold': 0, 'MAP': 0.029228665181843458, 'topK': 660, 'l1_ratio': 0.0012296801858497721, 'alpha': 0.001}
RP3_KFOLD = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}
IMPLICIT_IALS = {'num_factors': 128,
 'epochs': 478,
 'confidence_scaling': 'linear',
 'alpha': 3.358295366834473,
 'epsilon': 7.295986722921583,
 'reg': 6.292360640597378e-05}

# %%
#BEST 100 SINGLE SPLIT: 0.030123825632990115
OLD_BEST_PARAMS = {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}

# 0.030008733292970144
OLD_BEST_PARAMS = {'topK': 59,
 'alpha': 0.3764461506622426,
 'beta': 0.10277510174112,
 'normalize_similarity': True}

#0.030128708347317946
OLD_BEST_PARAMS = {'topK': 34,
 'alpha': 0.28453879172230406,
 'beta': 0.15344052347036438,
 'normalize_similarity': True}

old_res = 0
for i in range(len(seeds)):
    m = recommenderClass(urm_train[i])
    m.fit(**OLD_BEST_PARAMS)
    ris, _ = evaluator_validation[i].evaluateRecommender(m)
    old_res += ris["MAP"].item()
old_res = old_res / len(seeds)
old_res
# Out:
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 320 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8617.41 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10073 (100.0%) in 2.34 sec. Users per second: 4304
# RP3betaRecommender: URM Detected 453 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 346 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8584.56 column/sec. Elapsed time 2.59 sec
# EvaluatorHoldout: Processed 10013 (100.0%) in 2.34 sec. Users per second: 4283
# RP3betaRecommender: URM Detected 446 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 355 ( 1.6%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8529.22 column/sec. Elapsed time 2.61 sec
# EvaluatorHoldout: Processed 10042 (100.0%) in 2.25 sec. Users per second: 4469
# RP3betaRecommender: URM Detected 450 ( 3.6%) users with no interactions.
# RP3betaRecommender: URM Detected 315 ( 1.4%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8330.07 column/sec. Elapsed time 2.67 sec
# EvaluatorHoldout: Processed 9972 (100.0%) in 2.29 sec. Users per second: 4357
# RP3betaRecommender: URM Detected 474 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 323 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8599.09 column/sec. Elapsed time 2.58 sec
# EvaluatorHoldout: Processed 10017 (100.0%) in 2.27 sec. Users per second: 4406
# RP3betaRecommender: URM Detected 481 ( 3.8%) users with no interactions.
# RP3betaRecommender: URM Detected 328 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8633.67 column/sec. Elapsed time 2.57 sec
# EvaluatorHoldout: Processed 9986 (100.0%) in 2.29 sec. Users per second: 4356
# RP3betaRecommender: URM Detected 443 ( 3.5%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8543.68 column/sec. Elapsed time 2.60 sec
# EvaluatorHoldout: Processed 10068 (100.0%) in 2.29 sec. Users per second: 4396
# RP3betaRecommender: URM Detected 467 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 298 ( 1.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8694.54 column/sec. Elapsed time 2.56 sec
# EvaluatorHoldout: Processed 9992 (100.0%) in 2.16 sec. Users per second: 4622
# 0.030008733292970144

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt


regr = RandomForestRegressor(max_depth=2)

result_df_graph = results_df.copy()
result_df_graph["score"] *= -1

numerical_cols = result_df_graph.mean().notna()
numerical_cols = numerical_cols.index[numerical_cols]

numerical_df = result_df_graph[numerical_cols]
numerical_df = (numerical_df - numerical_df.mean())/(numerical_df.std() +1e-6)

y_train = numerical_df["score"]
X_train = numerical_df.copy()
X_train = X_train.drop(columns=["score"])

regr.fit(X_train, y_train)

plt.bar(X_train.columns, regr.feature_importances_)
plt.show()

# %%
final_model = ItemKNNSimilarityHybridRecommender(urm_all)
