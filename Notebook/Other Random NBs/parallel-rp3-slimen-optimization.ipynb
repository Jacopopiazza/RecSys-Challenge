# %%
import os
os.chdir( "../")

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample



urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation, urm_test = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80,seed=55)
urm_train, urm_validation = split_train_in_two_percentage_global_sample(urm_train_validation, train_percentage = 0.80,seed=55)
# Out:
# Warning: 236 (1.87 %) of 12638 users have no train items
# Warning: 2144 (16.96 %) of 12638 users have no sampled items
# Warning: 470 (3.72 %) of 12638 users have no train items
# Warning: 2608 (20.64 %) of 12638 users have no sampled items

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_validation = EvaluatorHoldout(urm_validation, cutoff_list=[10], ignore_users=[])
# Out:
# /Users/japo/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# EvaluatorHoldout: Ignoring 2608 (20.6%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = EvaluatorHoldout(urm_test, cutoff_list=[10], ignore_users=[])
# Out:
# EvaluatorHoldout: Ignoring 2144 (17.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_parallel/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 200  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train_validation],     # For a CBF model simply put [URM_train_validation, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
#hyperparameterSearch = SearchBayesianSkopt(recommender_class,
#                                         evaluator_validation=evaluator_validation,
#                                         evaluator_test=evaluator_test)

# %%
similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"]

# %%
from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial


runHyperparameterSearch_Collaborative_partial = partial(runHyperparameterSearch_Collaborative,
       URM_train = urm_train,
       URM_train_last_test = urm_train_validation,
       metric_to_optimize = metric_to_optimize,
       cutoff_to_optimize = cutoff_to_optimize,
       evaluator_validation_earlystopping = evaluator_validation,
       evaluator_validation = evaluator_validation,
       evaluator_test = evaluator_test,
       output_folder_path = output_folder_path,
       parallelizeKNN = True,
       allow_weighting = True,
       resume_from_saved = True,
       save_model = "best",
       similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"],
       n_cases = n_cases,
       n_random_starts = n_random_starts)

# %%
SLIMEN = {'topK': 530, 'l1_ratio': 0.05017569359096808, 'alpha': 0.001}
P3ALPHA = {'topK': 400, 'alpha': 1.6632815179401539, 'normalize_similarity': True}
RP3 = {'topK': 71, 'alpha': 0.31274648571776065, 'beta': 0.3586324430664178, 'normalize_similarity': True}

# %%
#runHyperparameterSearch_Collaborative(recommender_class=RP3betaRecommender,URM_train = urm_train,
#       URM_train_last_test = urm_train_validation,
#       metric_to_optimize = metric_to_optimize,
#       cutoff_to_optimize = cutoff_to_optimize,
#       evaluator_validation_earlystopping = evaluator_validation,
#       evaluator_validation = evaluator_validation,
#       output_folder_path = output_folder_path,
#       evaluator_test = evaluator_test,
#       allow_weighting = True,
#       parallelizeKNN = True,
#       resume_from_saved = True,
#       save_model = "best",
#       similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"],
#       n_cases = n_cases,
#       n_random_starts = n_random_starts)

# %%
collaborative_algorithm_list = [
    SLIMElasticNetRecommender,
    P3alphaRecommender,
    RP3betaRecommender
]

# %%
#pool = multiprocessing.Pool(processes=int(multiprocessing.cpu_count()), maxtasksperchild=1)
#pool.map(runHyperparameterSearch_Collaborative_partial, collaborative_algorithm_list)

# %%
from skopt.space import Real, Integer, Categorical


hyperparameters_range_dictionary = {
    "topK": Integer(5, 300),
    "alpha": Real(low = 0.2651626829923486, high = 0.37644615066224263, prior = 'uniform'),
    "beta": Real(low = 0, high = 1.35
, prior = 'uniform'),
    "normalize_similarity": Categorical([True, False]),
}

# %%
recommender_input_args = SearchInputRecommenderArgs(
                CONSTRUCTOR_POSITIONAL_ARGS = [urm_train],
                CONSTRUCTOR_KEYWORD_ARGS = {},
                FIT_POSITIONAL_ARGS = [],
                FIT_KEYWORD_ARGS = {},
                EARLYSTOPPING_KEYWORD_ARGS = {},
            )

# %%
hyperparameterSearch = SearchBayesianSkopt(RP3betaRecommender,
                                         evaluator_validation=evaluator_validation,
                                         evaluator_test=evaluator_test)

# %%
hyperparameterSearch.search(recommender_input_args,
                               hyperparameter_search_space= hyperparameters_range_dictionary,
                               n_cases = 500,
                               n_random_starts = n_random_starts,
                               resume_from_saved = True,
                               save_model = "best",
                               evaluate_on_test = "best",
                               max_total_time = None,
                               output_folder_path = output_folder_path,
                               output_file_name_root = RP3betaRecommender.RECOMMENDER_NAME+ "_last_try",
                               metric_to_optimize = metric_to_optimize,
                               cutoff_to_optimize = cutoff_to_optimize,
                               recommender_input_args_last_test = recommender_input_args_last_test)
# Out:
# SearchBayesianSkopt: Resuming 'RP3betaRecommender_last_try'... Loaded 6 configurations.
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: -0.0005
# Current minimum: -0.0291
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 201, 'alpha': 0.30334227053358803, 'beta': 0.40658420763691366, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2953.49 column/sec. Elapsed time 7.52 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.70 sec. Users per second: 1497
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 201, 'alpha': 0.30334227053358803, 'beta': 0.40658420763691366, 'normalize_similarity': False} - results: PRECISION: 0.0549053, PRECISION_RECALL_MIN_DEN: 0.1149358, RECALL: 0.1043852, MAP: 0.0249472, MAP_MIN_DEN: 0.0528247, MRR: 0.1751471, NDCG: 0.0972063, F1: 0.0719603, HIT_RATE: 0.3847458, ARHR_ALL_HITS: 0.2081642, NOVELTY: 0.0047729, AVERAGE_POPULARITY: 0.3938429, DIVERSITY_MEAN_INTER_LIST: 0.8712889, DIVERSITY_HERFINDAHL: 0.9871202, COVERAGE_ITEM: 0.4027540, COVERAGE_ITEM_HIT: 0.0456305, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3053489, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0534270, SHANNON_ENTROPY: 8.6667666, RATIO_DIVERSITY_HERFINDAHL: 0.9874782, RATIO_DIVERSITY_GINI: 0.1552792, RATIO_SHANNON_ENTROPY: 0.6682828, RATIO_AVERAGE_POPULARITY: 3.2284014, RATIO_NOVELTY: 0.3373503,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 18.5906
# Function value obtained: -0.0249
# Current minimum: -0.0291
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 88, 'alpha': 0.26627608899390004, 'beta': 0.27197744916851135, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4069.46 column/sec. Elapsed time 5.46 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.86 sec. Users per second: 1711
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 88, 'alpha': 0.26627608899390004, 'beta': 0.27197744916851135, 'normalize_similarity': True} - results: PRECISION: 0.0652343, PRECISION_RECALL_MIN_DEN: 0.1308200, RECALL: 0.1174499, MAP: 0.0288786, MAP_MIN_DEN: 0.0587297, MRR: 0.1906795, NDCG: 0.1093315, F1: 0.0838799, HIT_RATE: 0.4271186, ARHR_ALL_HITS: 0.2333084, NOVELTY: 0.0051021, AVERAGE_POPULARITY: 0.2602139, DIVERSITY_MEAN_INTER_LIST: 0.9576917, DIVERSITY_HERFINDAHL: 0.9957596, COVERAGE_ITEM: 0.4489695, COVERAGE_ITEM_HIT: 0.0696607, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0

#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 13.0942
# Function value obtained: -0.0018
# Current minimum: -0.0291
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 48, 'alpha': 0.3117726777416583, 'beta': 1.0245263827736857, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4697.33 column/sec. Elapsed time 4.73 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.59 sec. Users per second: 1796
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 48, 'alpha': 0.3117726777416583, 'beta': 1.0245263827736857, 'normalize_similarity': True} - results: PRECISION: 0.0038385, PRECISION_RECALL_MIN_DEN: 0.0062122, RECALL: 0.0048393, MAP: 0.0013047, MAP_MIN_DEN: 0.0021966, MRR: 0.0099939, NDCG: 0.0050523, F1: 0.0042812, HIT_RATE: 0.0303091, ARHR_ALL_HITS: 0.0113440, NOVELTY: 0.0080517, AVERAGE_POPULARITY: 0.0013833, DIVERSITY_MEAN_INTER_LIST: 0.9895291, DIVERSITY_HERFINDAHL: 0.9989430, COVERAGE_ITEM: 0.3325983, COVERAGE_ITEM_HIT: 0.0151652, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0240544, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0721540, SHANNON_ENTROPY: 10.8537708, RATIO_DIVERSITY_HERFINDAHL: 0.9993053, RATIO_DIVERSITY_GINI: 0.2097070, RATIO_SHANNON_ENTROPY: 0.8369198, RATIO_AVERAGE_POPULARITY: 0.0113392, RATIO_NOVELTY: 0.5690962,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 11.4774
# Function value obtained: -0.0013
# Current minimum: -0.0291
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 77, 'alpha': 0.2889494918434066, 'beta': 0.6879181975151679, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4234.19 column/sec. Elapsed time 5.25 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.27 sec. Users per second: 1599
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 77, 'alpha': 0.2889494918434066, 'beta': 0.6879181975151679, 'normalize_similarity': True} - results: PRECISION: 0.0238684, PRECISION_RECALL_MIN_DEN: 0.0489705, RECALL: 0.0442266, MAP: 0.0099885, MAP_MIN_DEN: 0.0206300, MRR: 0.0733740, NDCG: 0.0401614, F1: 0.0310043, HIT_RATE: 0.1796610, ARHR_ALL_HITS: 0.0853022, NOVELTY: 0.0073785, AVERAGE_POPULARITY: 0.0383782, DIVERSITY_MEAN_INTER_LIST: 0.9944109, DIVERSITY_HERFINDAHL: 0.9994312, COVERAGE_ITEM: 0.5279003, COVERAGE_ITEM_HIT: 0.0468455, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.1425859, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1549354, SHANNON_ENTROPY: 11.9239274, RATIO_DIVERSITY_HERFINDAHL: 0.9997936, RATIO_DIVERSITY_GINI: 0.4503016, RATIO_SHANNON_ENTROPY: 0.9194382, RATIO_AVERAGE_POPULARITY: 0.3145927, RATIO_NOVELTY: 0.5215104,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 13.2815
# Function value obtained: -0.0100
# Current minimum: -0.0291
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 76, 'alpha': 0.3329805598746026, 'beta': 0.06268139719524762, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3780.79 column/sec. Elapsed time 5.88 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.57 sec. Users per second: 1799
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {

#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 9.9267
# Function value obtained: -0.0266
# Current minimum: -0.0291
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 195, 'alpha': 0.29091252423890435, 'beta': 1.1460178083520867, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2920.52 column/sec. Elapsed time 7.61 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.90 sec. Users per second: 1699
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 195, 'alpha': 0.29091252423890435, 'beta': 1.1460178083520867, 'normalize_similarity': True} - results: PRECISION: 0.0026421, PRECISION_RECALL_MIN_DEN: 0.0045610, RECALL: 0.0036915, MAP: 0.0008272, MAP_MIN_DEN: 0.0014107, MRR: 0.0072197, NDCG: 0.0034874, F1: 0.0030799, HIT_RATE: 0.0230309, ARHR_ALL_HITS: 0.0077034, NOVELTY: 0.0079970, AVERAGE_POPULARITY: 0.0015507, DIVERSITY_MEAN_INTER_LIST: 0.9938488, DIVERSITY_HERFINDAHL: 0.9993750, COVERAGE_ITEM: 0.4014040, COVERAGE_ITEM_HIT: 0.0109801, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0182782, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1080894, SHANNON_ENTROPY: 11.5095247, RATIO_DIVERSITY_HERFINDAHL: 0.9997374, RATIO_DIVERSITY_GINI: 0.3141492, RATIO_SHANNON_ENTROPY: 0.8874841, RATIO_AVERAGE_POPULARITY: 0.0127115, RATIO_NOVELTY: 0.5652251,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 17.2421
# Function value obtained: -0.0008
# Current minimum: -0.0291
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 11, 'alpha': 0.27735767895681723, 'beta': 1.3331988098639243, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5299.78 column/sec. Elapsed time 4.19 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.03 sec. Users per second: 1995
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'topK': 11, 'alpha': 0.27735767895681723, 'beta': 1.3331988098639243, 'normalize_similarity': False} - results: PRECISION: 0.0021037, PRECISION_RECALL_MIN_DEN: 0.0039816, RECALL: 0.0031899, MAP: 0.0006544, MAP_MIN_DEN: 0.0012350, MRR: 0.0056477, NDCG: 0.0029141, F1: 0.0025353, HIT_RATE: 0.0185444, ARHR_ALL_HITS: 0.0060602, NOVELTY: 0.0079322, AVERAGE_POPULARITY: 0.0020733, DIVERSITY_MEAN_INTER_LIST: 0.9653465, DIVERSITY_HERFINDAHL: 0.9965250, COVERAGE_ITEM: 0.3031230, COVERAGE_ITEM_HIT: 0.0085951, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0147175, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0558360, SHANNON_ENTROPY: 9.9956504, RATIO_DIVERSITY_HERFINDAHL: 0.9968864, RATIO_DIVERSITY_GINI: 0.1622808, RATIO_SHANNON_ENTROPY: 0.7707513, RATIO_AVERAGE_POPULARITY: 0.0169954, RATIO_NOVELTY: 0.5606480,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 9.7851
# Function value obtained: -0.0007
# Current minimum: -0.0291
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 126, 'alpha': 0.37252807372874575, 'beta': 0.5517426983863837, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3512.94 column/sec. Elapsed time 6.33 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.26 sec. Users per second: 1603
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 126, 'alpha': 0.37252807372874575, 'beta': 0.5517426983863837, 'normalize_similarity': False} - results: PRECISION: 0.0515952, PRECISION_RECALL_MIN_DEN: 0.1022207, RECALL: 0.0916967, MAP: 0.0230030, MAP_MIN_DEN: 0.0453981, MRR: 0.1579833, NDCG: 0.0864504, F1: 0.0660346, HIT_RATE: 0.3531406, ARHR_ALL_HITS: 0.1898933, NOVELTY: 0.0058473, AVERAGE_POPULARITY: 0.2243701, DIVERSITY_MEAN_INTER_LIST: 0.9570166, DIVERSITY_HERFINDAHL: 0.9956921, COVERAGE_ITEM: 0.5516605, COVERAGE_ITEM_HIT: 0.0634506, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.2802659, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1510730, SHANNON_ENTROPY: 10.9322065, RATIO_DIVERSITY_HERFINDAHL: 0.9960532, RATIO_DIVERSITY_GINI: 0.4390761, RATIO_SHANNON_ENTROPY: 0.8429679, RATIO_AVERAGE_POPULARITY: 1.8392021, RATIO_NOVELTY: 0.4132872,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 15.2968
# Function value obtained: -0.0230
# Current minimum: -0.0291
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 38, 'alpha': 0.28410724370417784, 'beta': 0.7181585570674073, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4952.25 column/sec. Elapsed time 4.49 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.36 sec. Users per second: 1870
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 38, 'alpha': 0.28410724370417784, 'beta': 0.7181585570674073, 'normalize_similarity': True} - results: PRECISION: 0.0214656, PRECISION_RECALL_MIN_DEN: 0.0419213, RECALL: 0.0370888, MAP: 0.0089443, MAP_MIN_DEN: 0.0177196, MRR: 0.0651352, NDCG: 0.0349711, F1: 0.0271930, HIT_RATE: 0.1618146, ARHR_ALL_HITS: 0.0758641, NOVELTY: 0.0075464, AVERAGE_POPULARITY: 0.0252573, DIVERSITY_MEAN_INTER_LIST: 0.9924878, DIVERSITY_HERFINDAHL: 0.9992389, COVERAGE_ITEM: 0.4619746, COVERAGE_ITEM_HIT: 0.0440554, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.1284222, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1221677, SHANNON_ENTROPY: 11.5280102, RATIO_DIVERSITY_HERFINDAHL: 0.9996012, RATIO_DIVERSITY_GINI: 0.3550661, RATIO_SHANNON_ENTROPY: 0.8889095, RATIO_AVERAGE_POPULARITY: 0.2070388, RATIO_NOVELTY: 0.5333760,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 10.8708
# Function value obtained: -0.0089
# Current minimum: -0.0291
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 185, 'alpha': 0.3679795327718356, 'beta': 0.35905771829241356, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3059.39 column/sec. Elapsed time 7.26 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.38 sec. Users per second: 1572
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 185, 'alpha': 0.3679795327718356, 'beta': 0.35905771829241356, 'normalize_similarity': False} - results: PRECISION: 0.0556929, PRECISION_RECALL_MIN_DEN: 0.1171058, RECALL: 0.1064628, MAP: 0.0251705, MAP_MIN_DEN: 0.0534633, MRR: 0.1764620, NDCG: 0.0985037, F1: 0.0731300, HIT_RATE: 0.3890329, ARHR_ALL_HITS: 0.2098917, NOVELTY: 0.0047386, AVERAGE_POPULARITY: 0.4006965, DIVERSITY_MEAN_INTER_LIST: 0.8660605, DIVERSITY_HERFINDAHL: 0.9865974, COVERAGE_ITEM: 0.3932139, COVERAGE_ITEM_HIT: 0.0464405, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3087514, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0509064, SHANNON_ENTROPY: 8.5959913, RATIO_DIVERSITY_HERFINDAHL: 0.9869552, RATIO_DIVERSITY_GINI: 0.1479536, RATIO_SHANNON_ENTROPY: 0.6628254, RATIO_AVERAGE_POPULARITY: 3.2845814, RATIO_NOVELTY: 0.3349224,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 17.2522
# Function value obtained: -0.0252
# Current minimum: -0.0291
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 27, 'alpha': 0.3406598534733708, 'beta': 1.050597569555266, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5206.04 column/sec. Elapsed time 4.27 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.29 sec. Users per second: 1895
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'topK': 27, 'alpha': 0.3406598534733708, 'beta': 1.050597569555266, 'normalize_similarity': False} - results: PRECISION: 0.0039083, PRECISION_RECALL_MIN_DEN: 0.0061546, RECALL: 0.0046765, MAP: 0.0013181, MAP_MIN_DEN: 0.0020945, MRR: 0.0103111, NDCG: 0.0050267, F1: 0.0042580, HIT_RATE: 0.0311067, ARHR_ALL_HITS: 0.0115932, NOVELTY: 0.0080500, AVERAGE_POPULARITY: 0.0013785, DIVERSITY_MEAN_INTER_LIST: 0.9881267, DIVERSITY_HERFINDAHL: 0.9988028, COVERAGE_ITEM: 0.2868329, COVERAGE_ITEM_HIT: 0.0150302, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0246875, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0621200, SHANNON_ENTROPY: 10.6578206, RATIO_DIVERSITY_HERFINDAHL: 0.9991650, RATIO_DIVERSITY_GINI: 0.1805444, RATIO_SHANNON_ENTROPY: 0.8218104, RATIO_AVERAGE_POPULARITY: 0.0113000, RATIO_NOVELTY: 0.5689750,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 10.3904
# Function value obtained: -0.0013
# Current minimum: -0.0291
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 248, 'alpha': 0.28695003124219715, 'beta': 1.0942562653583012, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2613.69 column/sec. Elapsed time 8.50 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.27 sec. Users per second: 1601
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 248, 'alpha': 0.28695003124219715, 'beta': 1.0942562653583012, 'normalize_similarity': False} - results: PRECISION: 0.0021236, PRECISION_RECALL_MIN_DEN: 0.0034742, RECALL: 0.0027259, MAP: 0.0006653, MAP_MIN_DEN: 0.0010036, MRR: 0.0055966, NDCG: 0.0026526, F1: 0.0023874, HIT_RATE: 0.0177468, ARHR_ALL_HITS: 0.0060784, NOVELTY: 0.0081255, AVERAGE_POPULARITY: 0.0011402, DIVERSITY_MEAN_INTER_LIST: 0.9900932, DIVERSITY_HERFINDAHL: 0.9989995, COVERAGE_ITEM: 0.2016470, COVERAGE_ITEM_HIT: 0.0087301, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0140845, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0517261, SHANNON_ENTROPY: 10.5575950, RATIO_DIVERSITY_HERFINDAHL: 0.9993617, RATIO_DIVERSITY_GINI: 0.1503359, RATIO_SHANNON_ENTROPY: 0.8140821, RATIO_AVERAGE_POPULARITY: 0.0093467, RATIO_NOVELTY: 0.5743116,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 19.3352
# Function value obtained: -0.0007
# Current minimum: -0.0291
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 265, 'alpha': 0.3622100676224441, 'beta': 1.332830956200572, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2612.16 column/sec. Elapsed time 8.51 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.55 sec. Users per second: 1531
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 265, 'alpha': 0.3622100676224441, 'beta': 1.332830956200572, 'normalize_similarity': True} - results: PRECISION: 0.0021535, PRECISION_RECALL_MIN_DEN: 0.0038155, RECALL: 0.0031211, MAP: 0.0007487, MAP_MIN_DEN: 0.0012786, MRR: 0.0069641, NDCG: 0.0030692, F1: 0.0025486, HIT_RATE: 0.0200399, ARHR_ALL_HITS: 0.0072199, NOVELTY: 0.0080003, AVERAGE_POPULARITY: 0.0015203, DIVERSITY_MEAN_INTER_LIST: 0.9945489, DIVERSITY_HERFINDAHL: 0.9994450, COVERAGE_ITEM: 0.3864639, COVERAGE_ITEM_HIT: 0.0089551, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0159044, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1091690, SHANNON_ENTROPY: 11.5696176, RATIO_DIVERSITY_HERFINDAHL: 0.9998074, RATIO_DIVERSITY_GINI: 0.3172870, RATIO_SHANNON_ENTROPY: 0.8921178, RATIO_AVERAGE_POPULARITY: 0.0124621, RATIO_NOVELTY: 0.5654637,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 19.8823
# Function value obtained: -0.0007
# Current minimum: -0.0291
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 87, 'alpha': 0.3691825517808545, 'beta': 0.3680178860696852, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4056.94 column/sec. Elapsed time 5.48 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.69 sec. Users per second: 1764
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'topK': 87, 'alpha': 0.3691825517808545, 'beta': 0.3680178860696852, 'normalize_similarity': True} - results: PRECISION: 0.0625823, PRECISION_RECALL_MIN_DEN: 0.1247947, RECALL: 0.1117979, MAP: 0.0281544, MAP_MIN_DEN: 0.0567293, MRR: 0.1863758, NDCG: 0.1054196, F1: 0.0802450, HIT_RATE: 0.4108674, ARHR_ALL_HITS: 0.2281737, NOVELTY: 0.0051903, AVERAGE_POPULARITY: 0.2583861, DIVERSITY_MEAN_INTER_LIST: 0.9584910, DIVERSITY_HERFINDAHL: 0.9958395, COVERAGE_ITEM: 0.4970750, COVERAGE_ITEM_HIT: 0.0652507, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3260801, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0943989, SHANNON_ENTROPY: 10.2248186, RATIO_DIVERSITY_HERFINDAHL: 0.9962007, RATIO_DIVERSITY_GINI: 0.2743594, RATIO_SHANNON_ENTROPY: 0.7884221, RATIO_AVERAGE_POPULARITY: 2.1180374, RATIO_NOVELTY: 0.3668531,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 13.3105
# Function value obtained: -0.0282
# Current minimum: -0.0291
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 196, 'alpha': 0.3763805155734704, 'beta': 0.7479700080586561, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2943.83 column/sec. Elapsed time 7.55 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.55 sec. Users per second: 1531
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'topK': 196, 'alpha': 0.3763805155734704, 'beta': 0.7479700080586561, 'normalize_similarity': True} - results: PRECISION: 0.0124327, PRECISION_RECALL_MIN_DEN: 0.0268445, RECALL: 0.0241450, MAP: 0.0043778, MAP_MIN_DEN: 0.0092958, MRR: 0.0330606, NDCG: 0.0195351, F1: 0.0164137, HIT_RATE: 0.0982054, ARHR_ALL_HITS: 0.0378889, NOVELTY: 0.0077002, AVERAGE_POPULARITY: 0.0085722, DIVERSITY_MEAN_INTER_LIST: 0.9965860, DIVERSITY_HERFINDAHL: 0.9996487, COVERAGE_ITEM: 0.5884259, COVERAGE_ITEM_HIT: 0.0376204, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0779395, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.2075121, SHANNON_ENTROPY: 12.4558081, RATIO_DIVERSITY_HERFINDAHL: 1.0000112, RATIO_DIVERSITY_GINI: 0.6031096, RATIO_SHANNON_ENTROPY: 0.9604508, RATIO_AVERAGE_POPULARITY: 0.0702681, RATIO_NOVELTY: 0.5442497,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 17.9588
# Function value obtained: -0.0044
# Current minimum: -0.0291
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 122, 'alpha': 0.2734064748328216, 'beta': 0.1653307089812229, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3441.26 column/sec. Elapsed time 6.46 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.47 sec. Users per second: 1834
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'topK': 122, 'alpha': 0.2734064748328216, 'beta': 0.1653307089812229, 'normalize_similarity': True} - results: PRECISION: 0.0650947, PRECISION_RECALL_MIN_DEN: 0.1302921, RECALL: 0.1169524, MAP: 0.0287667, MAP_MIN_DEN: 0.0589786, MRR: 0.1902828, NDCG: 0.1093971, F1: 0.0836375, HIT_RATE: 0.4294118, ARHR_ALL_HITS: 0.2327582, NOVELTY: 0.0050168, AVERAGE_POPULARITY: 0.2728620, DIVERSITY_MEAN_INTER_LIST: 0.9514010, DIVERSITY_HERFINDAHL: 0.9951306, COVERAGE_ITEM: 0.3901089, COVERAGE_ITEM_HIT: 0.0681757, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3407976, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0633997, SHANNON_ENTROPY: 9.8652094, RATIO_DIVERSITY_HERFINDAHL: 0.9954915, RATIO_DIVERSITY_GINI: 0.1842637, RATIO_SHANNON_ENTROPY: 0.7606932, RATIO_AVERAGE_POPULARITY: 2.2366989, RATIO_NOVELTY: 0.3545859,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 14.2755
# Function value obtained: -0.0288
# Current minimum: -0.0291
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 276, 'alpha': 0.32965275488043544, 'beta': 0.8869867907396344, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2472.30 column/sec. Elapsed time 8.99 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.74 sec. Users per second: 1487
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 276, 'alpha': 0.32965275488043544, 'beta': 0.8869867907396344, 'normalize_similarity': True} - results: PRECISION: 0.0049053, PRECISION_RECALL_MIN_DEN: 0.0082931, RECALL: 0.0067595, MAP: 0.0017272, MAP_MIN_DEN: 0.0028664, MRR: 0.0137560, NDCG: 0.0066847, F1: 0.0056850, HIT_RATE: 0.0402792, ARHR_ALL_HITS: 0.0153244, NOVELTY: 0.0078696, AVERAGE_POPULARITY: 0.0020808, DIVERSITY_MEAN_INTER_LIST: 0.9959741, DIVERSITY_HERFINDAHL: 0.9995875, COVERAGE_ITEM: 0.5252903, COVERAGE_ITEM_HIT: 0.0198452, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0319671, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1727078, SHANNON_ENTROPY: 12.1917333, RATIO_DIVERSITY_HERFINDAHL: 0.9999500, RATIO_DIVERSITY_GINI: 0.5019550, RATIO_SHANNON_ENTROPY: 0.9400883, RATIO_AVERAGE_POPULARITY: 0.0170566, RATIO_NOVELTY: 0.5562198,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 20.8083
# Function value obtained: -0.0017
# Current minimum: -0.0291
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 283, 'alpha': 0.2812401658870949, 'beta': 0.9494117104021136, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2223.07 column/sec. Elapsed time 10.00 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.81 sec. Users per second: 1473
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 283, 'alpha': 0.2812401658870949, 'beta': 0.9494117104021136, 'normalize_similarity': False} - results: PRECISION: 0.0032403, PRECISION_RECALL_MIN_DEN: 0.0055150, RECALL: 0.0044101, MAP: 0.0009991, MAP_MIN_DEN: 0.0015651, MRR: 0.0078147, NDCG: 0.0040437, F1: 0.0037358, HIT_RATE: 0.0259222, ARHR_ALL_HITS: 0.0087719, NOVELTY: 0.0080862, AVERAGE_POPULARITY: 0.0012525, DIVERSITY_MEAN_INTER_LIST: 0.9911434, DIVERSITY_HERFINDAHL: 0.9991045, COVERAGE_ITEM: 0.2555126, COVERAGE_ITEM_HIT: 0.0131851, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0205729, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0645709, SHANNON_ENTROPY: 10.8484289, RATIO_DIVERSITY_HERFINDAHL: 0.9994668, RATIO_DIVERSITY_GINI: 0.1876679, RATIO_SHANNON_ENTROPY: 0.8365079, RATIO_AVERAGE_POPULARITY: 0.0102672, RATIO_NOVELTY: 0.5715308,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 21.9457
# Function value obtained: -0.0010
# Current minimum: -0.0291
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 225, 'alpha': 0.29286566579294154, 'beta': 0.7906392626323916, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2744.95 column/sec. Elapsed time 8.10 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.20 sec. Users per second: 1619
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'topK': 225, 'alpha': 0.29286566579294154, 'beta': 0.7906392626323916, 'normalize_similarity': False} - results: PRECISION: 0.0085643, PRECISION_RECALL_MIN_DEN: 0.0179229, RECALL: 0.0158376, MAP: 0.0029357, MAP_MIN_DEN: 0.0061114, MRR: 0.0215665, NDCG: 0.0129678, F1: 0.0111170, HIT_RATE: 0.0670987, ARHR_ALL_HITS: 0.0249591, NOVELTY: 0.0079504, AVERAGE_POPULARITY: 0.0039385, DIVERSITY_MEAN_INTER_LIST: 0.9936641, DIVERSITY_HERFINDAHL: 0.9993565, COVERAGE_ITEM: 0.3726937, COVERAGE_ITEM_HIT: 0.0289803, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0532521, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1018752, SHANNON_ENTROPY: 11.4515480, RATIO_DIVERSITY_HERFINDAHL: 0.9997189, RATIO_DIVERSITY_GINI: 0.2960884, RATIO_SHANNON_ENTROPY: 0.8830136, RATIO_AVERAGE_POPULARITY: 0.0322843, RATIO_NOVELTY: 0.5619367,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 18.5777
# Function value obtained: -0.0029
# Current minimum: -0.0291
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 281, 'alpha': 0.3423329235236732, 'beta': 0.05772873331706418, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2502.33 column/sec. Elapsed time 8.88 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.61 sec. Users per second: 1518
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'topK': 281, 'alpha': 0.3423329235236732, 'beta': 0.05772873331706418, 'normalize_similarity': False} - results: PRECISION: 0.0457527, PRECISION_RECALL_MIN_DEN: 0.1000862, RECALL: 0.0918623, MAP: 0.0189041, MAP_MIN_DEN: 0.0423149, MRR: 0.1414014, NDCG: 0.0802932, F1: 0.0610827, HIT_RATE: 0.3414756, ARHR_ALL_HITS: 0.1630201, NOVELTY: 0.0042453, AVERAGE_POPULARITY: 0.5551466, DIVERSITY_MEAN_INTER_LIST: 0.6830702, DIVERSITY_HERFINDAHL: 0.9683002, COVERAGE_ITEM: 0.1521465, COVERAGE_ITEM_HIT: 0.0225452, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.2710081, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0096156, SHANNON_ENTROPY: 6.5817191, RATIO_DIVERSITY_HERFINDAHL: 0.9686514, RATIO_DIVERSITY_GINI: 0.0279466, RATIO_SHANNON_ENTROPY: 0.5075076, RATIO_AVERAGE_POPULARITY: 4.5506375, RATIO_NOVELTY: 0.3000588,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 19.5178
# Function value obtained: -0.0189
# Current minimum: -0.0291
# Iteration No: 31 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 159, 'alpha': 0.3053121130157536, 'beta': 0.7243387181718928, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3130.00 column/sec. Elapsed time 7.10 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.44 sec. Users per second: 1557
# SearchBayesianSkopt: Config 35 is suboptimal. Config: {'topK': 159, 'alpha': 0.3053121130157536, 'beta': 0.7243387181718928, 'normalize_similarity': True} - results: PRECISION: 0.0148355, PRECISION_RECALL_MIN_DEN: 0.0320808, RECALL: 0.0291520, MAP: 0.0055324, MAP_MIN_DEN: 0.0123078, MRR: 0.0418951, NDCG: 0.0244990, F1: 0.0196640, HIT_RATE: 0.1161515, ARHR_ALL_HITS: 0.0479557, NOVELTY: 0.0076551, AVERAGE_POPULARITY: 0.0140082, DIVERSITY_MEAN_INTER_LIST: 0.9959511, DIVERSITY_HERFINDAHL: 0.9995852, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0397804, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.0921823, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.1897741, SHANNON_ENTROPY: 12.2826210, RATIO_DIVERSITY_HERFINDAHL: 0.9999477, RATIO_DIVERSITY_GINI: 0.5515561, RATIO_SHANNON_ENTROPY: 0.9470966, RATIO_AVERAGE_POPULARITY: 0.1148280, RATIO_NOVELTY: 0.5410638,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 16.8368
# Function value obtained: -0.0055
# Current minimum: -0.0291
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 204, 'alpha': 0.3551351230978037, 'beta': 0.9495239658784812, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2845.10 column/sec. Elapsed time 7.81 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 6.40 sec. Users per second: 1567
# ...
# Time taken: 31.7898
# Function value obtained: -0.0309
# Current minimum: -0.0311
# Iteration No: 487 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1660778937361165, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4904.17 column/sec. Elapsed time 4.53 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.95 sec. Users per second: 1686
# SearchBayesianSkopt: Config 491 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1660778937361165, 'normalize_similarity': True} - results: PRECISION: 0.0678166, PRECISION_RECALL_MIN_DEN: 0.1317157, RECALL: 0.1174245, MAP: 0.0310490, MAP_MIN_DEN: 0.0614529, MRR: 0.2028241, NDCG: 0.1136319, F1: 0.0859780, HIT_RATE: 0.4369890, ARHR_ALL_HITS: 0.2494287, NOVELTY: 0.0053567, AVERAGE_POPULARITY: 0.1769773, DIVERSITY_MEAN_INTER_LIST: 0.9814912, DIVERSITY_HERFINDAHL: 0.9981393, COVERAGE_ITEM: 0.4621096, COVERAGE_ITEM_HIT: 0.0805058, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3468112, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0962488, SHANNON_ENTROPY: 10.7876745, RATIO_DIVERSITY_HERFINDAHL: 0.9985013, RATIO_DIVERSITY_GINI: 0.2797358, RATIO_SHANNON_ENTROPY: 0.8318232, RATIO_AVERAGE_POPULARITY: 1.4507147, RATIO_NOVELTY: 0.3786125,
#
# Iteration No: 487 ended. Search finished for the next optimal point.
# Time taken: 33.0178
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 488 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16643821469497075, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4683.23 column/sec. Elapsed time 4.75 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.58 sec. Users per second: 1798
# SearchBayesianSkopt: Config 492 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16643821469497075, 'normalize_similarity': True} - results: PRECISION: 0.0678066, PRECISION_RECALL_MIN_DEN: 0.1317058, RECALL: 0.1174198, MAP: 0.0310360, MAP_MIN_DEN: 0.0614276, MRR: 0.2028365, NDCG: 0.1136141, F1: 0.0859687, HIT_RATE: 0.4370887, ARHR_ALL_HITS: 0.2493944, NOVELTY: 0.0053569, AVERAGE_POPULARITY: 0.1769890, DIVERSITY_MEAN_INTER_LIST: 0.9814938, DIVERSITY_HERFINDAHL: 0.9981396, COVERAGE_ITEM: 0.4623796, COVERAGE_ITEM_HIT: 0.0805058, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3468903, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0963147, SHANNON_ENTROPY: 10.7881877, RATIO_DIVERSITY_HERFINDAHL: 0.9985016, RATIO_DIVERSITY_GINI: 0.2799274, RATIO_SHANNON_ENTROPY: 0.8318628, RATIO_AVERAGE_POPULARITY: 1.4508111, RATIO_NOVELTY: 0.3786250,
#
# Iteration No: 488 ended. Search finished for the next optimal point.
# Time taken: 32.6783
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 489 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16659204187900728, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4536.39 column/sec. Elapsed time 4.90 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.69 sec. Users per second: 1762
# SearchBayesianSkopt: Config 493 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16659204187900728, 'normalize_similarity': True} - results: PRECISION: 0.0678564, PRECISION_RECALL_MIN_DEN: 0.1317888, RECALL: 0.1174911, MAP: 0.0310353, MAP_MIN_DEN: 0.0614240, MRR: 0.2027815, NDCG: 0.1136360, F1: 0.0860279, HIT_RATE: 0.4372881, ARHR_ALL_HITS: 0.2493656, NOVELTY: 0.0053570, AVERAGE_POPULARITY: 0.1769347, DIVERSITY_MEAN_INTER_LIST: 0.9815089, DIVERSITY_HERFINDAHL: 0.9981411, COVERAGE_ITEM: 0.4625596, COVERAGE_ITEM_HIT: 0.0805508, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3470486, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0963546, SHANNON_ENTROPY: 10.7889004, RATIO_DIVERSITY_HERFINDAHL: 0.9985031, RATIO_DIVERSITY_GINI: 0.2800433, RATIO_SHANNON_ENTROPY: 0.8319177, RATIO_AVERAGE_POPULARITY: 1.4503656, RATIO_NOVELTY: 0.3786315,
#
# Iteration No: 489 ended. Search finished for the next optimal point.
# Time taken: 33.9273
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 490 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16765772217956135, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4593.87 column/sec. Elapsed time 4.84 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.75 sec. Users per second: 1744
# SearchBayesianSkopt: Config 494 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16765772217956135, 'normalize_similarity': True} - results: PRECISION: 0.0679262, PRECISION_RECALL_MIN_DEN: 0.1320356, RECALL: 0.1177533, MAP: 0.0310050, MAP_MIN_DEN: 0.0614350, MRR: 0.2025466, NDCG: 0.1136905, F1: 0.0861542, HIT_RATE: 0.4376869, ARHR_ALL_HITS: 0.2491124, NOVELTY: 0.0053564, AVERAGE_POPULARITY: 0.1773676, DIVERSITY_MEAN_INTER_LIST: 0.9813965, DIVERSITY_HERFINDAHL: 0.9981299, COVERAGE_ITEM: 0.4627846, COVERAGE_ITEM_HIT: 0.0808208, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3473651, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0963498, SHANNON_ENTROPY: 10.7878533, RATIO_DIVERSITY_HERFINDAHL: 0.9984918, RATIO_DIVERSITY_GINI: 0.2800295, RATIO_SHANNON_ENTROPY: 0.8318370, RATIO_AVERAGE_POPULARITY: 1.4539144, RATIO_NOVELTY: 0.3785880,
#
# Iteration No: 490 ended. Search finished for the next optimal point.
# Time taken: 33.5041
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 491 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1661331415360375, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4314.46 column/sec. Elapsed time 5.15 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.43 sec. Users per second: 1846
# SearchBayesianSkopt: Config 495 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1661331415360375, 'normalize_similarity': True} - results: PRECISION: 0.0678066, PRECISION_RECALL_MIN_DEN: 0.1317058, RECALL: 0.1174205, MAP: 0.0310468, MAP_MIN_DEN: 0.0614503, MRR: 0.2028152, NDCG: 0.1136242, F1: 0.0859689, HIT_RATE: 0.4369890, ARHR_ALL_HITS: 0.2494132, NOVELTY: 0.0053567, AVERAGE_POPULARITY: 0.1769756, DIVERSITY_MEAN_INTER_LIST: 0.9814918, DIVERSITY_HERFINDAHL: 0.9981394, COVERAGE_ITEM: 0.4621996, COVERAGE_ITEM_HIT: 0.0805058, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3468112, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0962601, SHANNON_ENTROPY: 10.7877212, RATIO_DIVERSITY_HERFINDAHL: 0.9985014, RATIO_DIVERSITY_GINI: 0.2797687, RATIO_SHANNON_ENTROPY: 0.8318268, RATIO_AVERAGE_POPULARITY: 1.4507008, RATIO_NOVELTY: 0.3786142,
#
# Iteration No: 491 ended. Search finished for the next optimal point.
# Time taken: 34.2997
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 492 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16624541289818368, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4622.05 column/sec. Elapsed time 4.81 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.43 sec. Users per second: 1848
# SearchBayesianSkopt: Config 496 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16624541289818368, 'normalize_similarity': True} - results: PRECISION: 0.0678166, PRECISION_RECALL_MIN_DEN: 0.1317224, RECALL: 0.1174342, MAP: 0.0310440, MAP_MIN_DEN: 0.0614488, MRR: 0.2028507, NDCG: 0.1136359, F1: 0.0859806, HIT_RATE: 0.4371884, ARHR_ALL_HITS: 0.2494354, NOVELTY: 0.0053568, AVERAGE_POPULARITY: 0.1769751, DIVERSITY_MEAN_INTER_LIST: 0.9814927, DIVERSITY_HERFINDAHL: 0.9981395, COVERAGE_ITEM: 0.4622896, COVERAGE_ITEM_HIT: 0.0805508, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3469695, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0962846, SHANNON_ENTROPY: 10.7878813, RATIO_DIVERSITY_HERFINDAHL: 0.9985014, RATIO_DIVERSITY_GINI: 0.2798400, RATIO_SHANNON_ENTROPY: 0.8318392, RATIO_AVERAGE_POPULARITY: 1.4506968, RATIO_NOVELTY: 0.3786170,
#
# Iteration No: 492 ended. Search finished for the next optimal point.
# Time taken: 33.3178
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 493 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1673255537110802, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5009.61 column/sec. Elapsed time 4.44 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.50 sec. Users per second: 1825
# SearchBayesianSkopt: Config 497 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.1673255537110802, 'normalize_similarity': True} - results: PRECISION: 0.0678863, PRECISION_RECALL_MIN_DEN: 0.1318089, RECALL: 0.1175250, MAP: 0.0310144, MAP_MIN_DEN: 0.0613550, MRR: 0.2026307, NDCG: 0.1135865, F1: 0.0860610, HIT_RATE: 0.4373878, ARHR_ALL_HITS: 0.2491973, NOVELTY: 0.0053572, AVERAGE_POPULARITY: 0.1769055, DIVERSITY_MEAN_INTER_LIST: 0.9815285, DIVERSITY_HERFINDAHL: 0.9981431, COVERAGE_ITEM: 0.4629196, COVERAGE_ITEM_HIT: 0.0808208, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3471277, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0964132, SHANNON_ENTROPY: 10.7900537, RATIO_DIVERSITY_HERFINDAHL: 0.9985050, RATIO_DIVERSITY_GINI: 0.2802136, RATIO_SHANNON_ENTROPY: 0.8320067, RATIO_AVERAGE_POPULARITY: 1.4501261, RATIO_NOVELTY: 0.3786458,
#
# Iteration No: 493 ended. Search finished for the next optimal point.
# Time taken: 31.8064
# Function value obtained: -0.0310
# Current minimum: -0.0311
# Iteration No: 494 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16754595945181885, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4308.95 column/sec. Elapsed time 5.16 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.22 sec. Users per second: 1923
# SearchBayesianSkopt: Config 498 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16754595945181885, 'normalize_similarity': True} - results: PRECISION: 0.0679262, PRECISION_RECALL_MIN_DEN: 0.1320505, RECALL: 0.1177682, MAP: 0.0310019, MAP_MIN_DEN: 0.0614276, MRR: 0.2025087, NDCG: 0.1136860, F1: 0.0861582, HIT_RATE: 0.4376869, ARHR_ALL_HITS: 0.2490778, NOVELTY: 0.0053561, AVERAGE_POPULARITY: 0.1774185, DIVERSITY_MEAN_INTER_LIST: 0.9813852, DIVERSITY_HERFINDAHL: 0.9981287, COVERAGE_ITEM: 0.4627396, COVERAGE_ITEM_HIT: 0.0808208, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3473651, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0963284, SHANNON_ENTROPY: 10.7871962, RATIO_DIVERSITY_HERFINDAHL: 0.9984907, RATIO_DIVERSITY_GINI: 0.2799671, RATIO_SHANNON_ENTROPY: 0.8317863, RATIO_AVERAGE_POPULARITY: 1.4543314, RATIO_NOVELTY: 0.3785699,
#
# Iteration No: 494 ended. Search finished for the next optimal point.
# Time taken: 33.8663
# Function value obtained: -0.0310
# Current minimum: -0.0311
# SearchBayesianSkopt: Testing config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16636683397294547, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 470 ( 3.7%) users with no interactions.
# RP3betaRecommender: URM Detected 329 ( 1.5%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4724.70 column/sec. Elapsed time 4.70 sec
# EvaluatorHoldout: Processed 10030 (100.0%) in 5.58 sec. Users per second: 1798
# SearchBayesianSkopt: Config 499 is suboptimal. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16636683397294547, 'normalize_similarity': True} - results: PRECISION: 0.0678265, PRECISION_RECALL_MIN_DEN: 0.1317257, RECALL: 0.1174261, MAP: 0.0310365, MAP_MIN_DEN: 0.0614316, MRR: 0.2027833, NDCG: 0.1136193, F1: 0.0859864, HIT_RATE: 0.4371884, ARHR_ALL_HITS: 0.2493703, NOVELTY: 0.0053568, AVERAGE_POPULARITY: 0.1770061, DIVERSITY_MEAN_INTER_LIST: 0.9814908, DIVERSITY_HERFINDAHL: 0.9981393, COVERAGE_ITEM: 0.4622896, COVERAGE_ITEM_HIT: 0.0805508, ITEMS_IN_GT: 0.7462425, COVERAGE_USER: 0.7936382, COVERAGE_USER_HIT: 0.3469695, USERS_IN_GT: 0.7936382, DIVERSITY_GINI: 0.0962892, SHANNON_ENTROPY: 10.7878800, RATIO_DIVERSITY_HERFINDAHL: 0.9985013, RATIO_DIVERSITY_GINI: 0.2798533, RATIO_SHANNON_ENTROPY: 0.8318391, RATIO_AVERAGE_POPULARITY: 1.4509508, RATIO_NOVELTY: 0.3786155,
#
# Iteration No: 495 ended. Search finished for the next optimal point.
# Time taken: 70.4198
# Function value obtained: -0.0310
# Current minimum: -0.0311
# SearchBayesianSkopt: Search complete. Best config is 430: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}
#
# RP3betaRecommender: URM Detected 236 ( 1.9%) users with no interactions.
# RP3betaRecommender: URM Detected 113 ( 0.5%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 22222 (100.0%), 4406.17 column/sec. Elapsed time 5.04 sec
# EvaluatorHoldout: Processed 10494 (100.0%) in 5.96 sec. Users per second: 1762
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 34, 'alpha': 0.37644615066224263, 'beta': 0.16604377135619697, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0946160, PRECISION_RECALL_MIN_DEN: 0.1628007, RECALL: 0.1365501, MAP: 0.0488017, MAP_MIN_DEN: 0.0838684, MRR: 0.2690800, NDCG: 0.1497197, F1: 0.1117796, HIT_RATE: 0.5143892, ARHR_ALL_HITS: 0.3574438, NOVELTY: 0.0053851, AVERAGE_POPULARITY: 0.1652310, DIVERSITY_MEAN_INTER_LIST: 0.9832965, DIVERSITY_HERFINDAHL: 0.9983203, COVERAGE_ITEM: 0.4571596, COVERAGE_ITEM_HIT: 0.1086311, ITEMS_IN_GT: 0.8019980, COVERAGE_USER: 0.8303529, COVERAGE_USER_HIT: 0.4271245, USERS_IN_GT: 0.8303529, DIVERSITY_GINI: 0.0967724, SHANNON_ENTROPY: 10.8746277, RATIO_DIVERSITY_HERFINDAHL: 0.9986815, RATIO_DIVERSITY_GINI: 0.2777522, RATIO_SHANNON_ENTROPY: 0.8377459, RATIO_AVERAGE_POPULARITY: 1.3373576, RATIO_NOVELTY: 0.3042081,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/RP3betaRecommender_last_try
#
# RP3betaRecommender: Saving model in file 'result_experiments_parallel/RP3betaRecommender_last_try_best_model_last'
# RP3betaRecommender: Saving complete

# %%
from Recommenders.DataIO import DataIO


data_loader = DataIO(folder_path = output_folder_path)

search_metadata = data_loader.load_data(RP3betaRecommender.RECOMMENDER_NAME + "_lower_topK" + "_metadata.zip")

# %%
from Recommenders.DataIO import DataIO
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender


data_loader = DataIO(folder_path = output_folder_path)

search_metadata = data_loader.load_data(SLIMElasticNetRecommender.RECOMMENDER_NAME + "_metadata.zip")

# %%
df = search_metadata["hyperparameters_df"]
df["result"] = pd.DataFrame(search_metadata["result_on_validation_df"]["MAP"].to_numpy(),columns=["MAP"])["MAP"]
df
# Out:
#     topK  l1_ratio     alpha    result
# 0    977  0.000019  0.564221  0.017875
# 1    127  0.000024  0.422338  0.021034
# 2    452   0.01146  0.969692  0.007588
# 3    730  0.003337  0.366839  0.017683
# 4    859  0.001629  0.345141  0.018318
# ..   ...       ...       ...       ...
# 195  392  0.011957     0.001  0.029264
# 196    5  0.000142     0.001  0.025104
# 197  355   0.00001  0.142083  0.023117
# 198  491  0.000111     0.001   0.02849
# 199    5   0.00001  0.907323  0.020864
#
# [200 rows x 4 columns]

# %%
df[df["result"] == df["result"].max()]
# Out:
#     topK  l1_ratio  alpha    result
# 124  530  0.050176  0.001  0.030464

# %%
_feature_importance(df.drop(columns=["beta"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 _feature_importance(df.drop(columns=["beta"]))
#
# NameError: name '_feature_importance' is not defined
