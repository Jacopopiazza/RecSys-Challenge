# %%
import os
os.chdir( "../")

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import scipy.sparse as sps
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample



urm_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["User"].values, df["Item"].values)))

urm_train_validation, urm_test = split_train_in_two_percentage_global_sample(urm_all, train_percentage = 0.80)
urm_train, urm_validation = split_train_in_two_percentage_global_sample(urm_train_validation, train_percentage = 0.80)
# Out:
# Warning: 218 (1.72 %) of 12638 users have no train items
# Warning: 2128 (16.84 %) of 12638 users have no sampled items
# Warning: 472 (3.73 %) of 12638 users have no train items
# Warning: 2602 (20.59 %) of 12638 users have no sampled items

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_validation = EvaluatorHoldout(urm_validation, cutoff_list=[10], ignore_users=[])
# Out:
# /Users/japo/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# EvaluatorHoldout: Ignoring 2602 (20.6%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_test = EvaluatorHoldout(urm_test, cutoff_list=[10], ignore_users=[])
# Out:
# EvaluatorHoldout: Ignoring 2128 (16.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %%
import os

output_folder_path = "result_experiments_parallel/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 200  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train_validation],     # For a CBF model simply put [URM_train_validation, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
#hyperparameterSearch = SearchBayesianSkopt(recommender_class,
#                                         evaluator_validation=evaluator_validation,
#                                         evaluator_test=evaluator_test)

# %%
similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"]

# %%
from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative, runHyperparameterSearch_Content
from Recommenders.NonPersonalizedRecommender import TopPop, Random
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
import os, multiprocessing
from functools import partial


runHyperparameterSearch_Collaborative_partial = partial(runHyperparameterSearch_Collaborative,
       URM_train = urm_train,
       URM_train_last_test = urm_train_validation,
       metric_to_optimize = metric_to_optimize,
       cutoff_to_optimize = cutoff_to_optimize,
       evaluator_validation_earlystopping = evaluator_validation,
       evaluator_validation = evaluator_validation,
       evaluator_test = evaluator_test,
       output_folder_path = output_folder_path,
       parallelizeKNN = True,
       allow_weighting = True,
       resume_from_saved = True,
       save_model = "best",
       similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"],
       n_cases = n_cases,
       n_random_starts = n_random_starts)

# %%
collaborative_algorithm_list = [
    SLIMElasticNetRecommender,
    P3alphaRecommender,
]

# %%
pool = multiprocessing.Pool(processes=int(multiprocessing.cpu_count()), maxtasksperchild=1)
pool.map(runHyperparameterSearch_Collaborative_partial, collaborative_algorithm_list)
# Out:
# /Users/japo/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# /Users/japo/miniconda3/envs/RecSysFramework/lib/python3.8/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# SearchBayesianSkopt: Resuming 'SLIMElasticNetRecommender' Failed, no such file exists.
#
# SearchBayesianSkopt: Resuming 'P3alphaRecommender' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 977, 'l1_ratio': 1.901158020497196e-05, 'alpha': 0.5642211444241505}
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 775, 'alpha': 1.1419260278663652, 'normalize_similarity': False}
# SLIMElasticNetRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 1723.65 column/sec. Elapsed time 12.89 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 8.01 sec. Users per second: 1253
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 775, 'alpha': 1.1419260278663652, 'normalize_similarity': False} - results: PRECISION: 0.0294440, PRECISION_RECALL_MIN_DEN: 0.0608717, RECALL: 0.0548088, MAP: 0.0116101, MAP_MIN_DEN: 0.0258382, MRR: 0.0874733, NDCG: 0.0495473, F1: 0.0383083, HIT_RATE: 0.2249900, ARHR_ALL_HITS: 0.1004540, NOVELTY: 0.0055186, AVERAGE_POPULARITY: 0.1327631, DIVERSITY_MEAN_INTER_LIST: 0.9919778, DIVERSITY_HERFINDAHL: 0.9991879, COVERAGE_ITEM: 0.4474845, COVERAGE_ITEM_HIT: 0.0518855, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.1786675, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.1364224, SHANNON_ENTROPY: 11.6623781, RATIO_DIVERSITY_HERFINDAHL: 0.9995498, RATIO_DIVERSITY_GINI: 0.3952705, RATIO_SHANNON_ENTROPY: 0.8990535, RATIO_AVERAGE_POPULARITY: 1.0752860, RATIO_NOVELTY: 0.3899592,
#
# EvaluatorHoldout: Processed 10510 (100.0%) in 7.67 sec. Users per second: 1371
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 775, 'alpha': 1.1419260278663652, 'normalize_similarity': False} - results:
# CUTOFF: 10 - PRECISION: 0.0347764, PRECISION_RECALL_MIN_DEN: 0.0662467, RECALL: 0.0574376, MAP: 0.0143126, MAP_MIN_DEN: 0.0290834, MRR: 0.1032286, NDCG: 0.0561337, F1: 0.0433226, HIT_RATE: 0.2542341, ARHR_ALL_HITS: 0.1208897, NOVELTY: 0.0055189, AVERAGE_POPULARITY: 0.1317354, DIVERSITY_MEAN_INTER_LIST: 0.9919655, DIVERSITY_HERFINDAHL: 0.9991871, COVERAGE_ITEM: 0.4544145, COVERAGE_ITEM_HIT: 0.0583206, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.2114259, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.1370416, SHANNON_ENTROPY: 11.6672909, RATIO_DIVERSITY_HERFINDAHL: 0.9995491, RATIO_DIVERSITY_GINI: 0.3970645, RATIO_SHANNON_ENTROPY: 0.8994323, RATIO_AVERAGE_POPULARITY: 1.0669622, RATIO_NOVELTY: 0.3899804,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments_parallel/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 40.9691
# Function value obtained: -0.0116
# Current minimum: -0.0116
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 120, 'alpha': 0.9997363752514326, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 3851.12 column/sec. Elapsed time 5.77 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 6.14 sec. Users per second: 1634
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 120, 'alpha': 0.9997363752514326, 'normalize_similarity': True} - results: PRECISION: 0.0544141, PRECISION_RECALL_MIN_DEN: 0.1065672, RECALL: 0.0952070, MAP: 0.0243937, MAP_MIN_DEN: 0.0493082, MRR: 0.1662982, NDCG: 0.0918724, F1: 0.0692497, HIT_RATE: 0.3685731, ARHR_ALL_HITS: 0.2003719, NOVELTY: 0.0052471, AVERAGE_POPULARITY: 0.1712854, DIVERSITY_MEAN_INTER_LIST: 0.9834406, DIVERSITY_HERFINDAHL: 0.9983343, COVERAGE_ITEM: 0.3660787, COVERAGE_ITEM_HIT: 0.0569256, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.2926887, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0857504, SHANNON_ENTROPY: 10.7904975, RATIO_DIVERSITY_HERFINDAHL: 0.9986959, RATIO_DIVERSITY_GINI: 0.2484534, RATIO_SHANNON_ENTROPY: 0.8318402, RATIO_AVERAGE_POPULARITY: 1.3872892, RATIO_NOVELTY: 0.3707750,
#
# EvaluatorHoldout: Processed 10510 (100.0%) in 5.97 sec. Users per second: 1761
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 120, 'alpha': 0.9997363752514326, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0646337, PRECISION_RECALL_MIN_DEN: 0.1140693, RECALL: 0.0968475, MAP: 0.0307213, MAP_MIN_DEN: 0.0552339, MRR: 0.1945240, NDCG: 0.1032899, F1: 0.0775274, HIT_RATE: 0.4040913, ARHR_ALL_HITS: 0.2424896, NOVELTY: 0.0052537, AVERAGE_POPULARITY: 0.1690776, DIVERSITY_MEAN_INTER_LIST: 0.9837251, DIVERSITY_HERFINDAHL: 0.9983631, COVERAGE_ITEM: 0.3749887, COVERAGE_ITEM_HIT: 0.0630906, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.3360500, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.0874062, SHANNON_ENTROPY: 10.8164261, RATIO_DIVERSITY_HERFINDAHL: 0.9987248, RATIO_DIVERSITY_GINI: 0.2532509, RATIO_SHANNON_ENTROPY: 0.8338390, RATIO_AVERAGE_POPULARITY: 1.3694077, RATIO_NOVELTY: 0.3712406,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments_parallel/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 20.5438
# Function value obtained: -0.0244
# Current minimum: -0.0244
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 852, 'alpha': 0.4444955945811072, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 1647.48 column/sec. Elapsed time 13.49 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 7.55 sec. Users per second: 1329
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 852, 'alpha': 0.4444955945811072, 'normalize_similarity': True} - results: PRECISION: 0.0576226, PRECISION_RECALL_MIN_DEN: 0.1169114, RECALL: 0.1051699, MAP: 0.0248305, MAP_MIN_DEN: 0.0506431, MRR: 0.1710448, NDCG: 0.0965115, F1: 0.0744526, HIT_RATE: 0.3931845, ARHR_ALL_HITS: 0.2051173, NOVELTY: 0.0047048, AVERAGE_POPULARITY: 0.3367566, DIVERSITY_MEAN_INTER_LIST: 0.9250221, DIVERSITY_HERFINDAHL: 0.9924930, COVERAGE_ITEM: 0.2767978, COVERAGE_ITEM_HIT: 0.0476555, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.3122329, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0371149, SHANNON_ENTROPY: 9.0952938, RATIO_DIVERSITY_HERFINDAHL: 0.9928525, RATIO_DIVERSITY_GINI: 0.1075367, RATIO_SHANNON_ENTROPY: 0.7011568, RATIO_AVERAGE_POPULARITY: 2.7274869, RATIO_NOVELTY: 0.3324541,
#
# EvaluatorHoldout: Processed 10510 (100.0%) in 7.95 sec. Users per second: 1322
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 852, 'alpha': 0.4444955945811072, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0684586, PRECISION_RECALL_MIN_DEN: 0.1246439, RECALL: 0.1068138, MAP: 0.0304121, MAP_MIN_DEN: 0.0568903, MRR: 0.1951078, NDCG: 0.1079473, F1: 0.0834395, HIT_RATE: 0.4361560, ARHR_ALL_HITS: 0.2421016, NOVELTY: 0.0047079, AVERAGE_POPULARITY: 0.3344538, DIVERSITY_MEAN_INTER_LIST: 0.9263697, DIVERSITY_HERFINDAHL: 0.9926282, COVERAGE_ITEM: 0.2835028, COVERAGE_ITEM_HIT: 0.0516155, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.3627156, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.0376667, SHANNON_ENTROPY: 9.1188346, RATIO_DIVERSITY_HERFINDAHL: 0.9929877, RATIO_DIVERSITY_GINI: 0.1091357, RATIO_SHANNON_ENTROPY: 0.7029716, RATIO_AVERAGE_POPULARITY: 2.7088356, RATIO_NOVELTY: 0.3326754,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments_parallel/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 41.6832
# Function value obtained: -0.0248
# Current minimum: -0.0248
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 991, 'alpha': 1.987237841721911, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 1506.61 column/sec. Elapsed time 14.75 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 7.89 sec. Users per second: 1272
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 991, 'alpha': 1.987237841721911, 'normalize_similarity': True} - results: PRECISION: 0.0294141, PRECISION_RECALL_MIN_DEN: 0.0636368, RECALL: 0.0578669, MAP: 0.0100764, MAP_MIN_DEN: 0.0230723, MRR: 0.0798402, NDCG: 0.0473360, F1: 0.0390028, HIT_RATE: 0.2380430, ARHR_ALL_HITS: 0.0895906, NOVELTY: 0.0052779, AVERAGE_POPULARITY: 0.2082760, DIVERSITY_MEAN_INTER_LIST: 0.9771818, DIVERSITY_HERFINDAHL: 0.9977084, COVERAGE_ITEM: 0.2983530, COVERAGE_ITEM_HIT: 0.0314103, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.1890331, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0770162, SHANNON_ENTROPY: 10.6568827, RATIO_DIVERSITY_HERFINDAHL: 0.9980699, RATIO_DIVERSITY_GINI: 0.2231470, RATIO_SHANNON_ENTROPY: 0.8215398, RATIO_AVERAGE_POPULARITY: 1.6868864, RATIO_NOVELTY: 0.3729511,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 32.9942
# Function value obtained: -0.0101
# Current minimum: -0.0248
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 3056.77 column/sec. Elapsed time 7.27 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 5.84 sec. Users per second: 1719
# SearchBayesianSkopt: New best config found. Config 4: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True} - results: PRECISION: 0.0619669, PRECISION_RECALL_MIN_DEN: 0.1241617, RECALL: 0.1116416, MAP: 0.0279392, MAP_MIN_DEN: 0.0565521, MRR: 0.1887240, NDCG: 0.1053516, F1: 0.0796975, HIT_RATE: 0.4127142, ARHR_ALL_HITS: 0.2284264, NOVELTY: 0.0048864, AVERAGE_POPULARITY: 0.2606848, DIVERSITY_MEAN_INTER_LIST: 0.9614725, DIVERSITY_HERFINDAHL: 0.9961377, COVERAGE_ITEM: 0.2720277, COVERAGE_ITEM_HIT: 0.0597156, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.3277417, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0428106, SHANNON_ENTROPY: 9.6966052, RATIO_DIVERSITY_HERFINDAHL: 0.9964985, RATIO_DIVERSITY_GINI: 0.1240396, RATIO_SHANNON_ENTROPY: 0.7475120, RATIO_AVERAGE_POPULARITY: 2.1113597, RATIO_NOVELTY: 0.3452889,
#
# EvaluatorHoldout: Processed 10510 (100.0%) in 6.12 sec. Users per second: 1718
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0739010, PRECISION_RECALL_MIN_DEN: 0.1324248, RECALL: 0.1133345, MAP: 0.0342611, MAP_MIN_DEN: 0.0620461, MRR: 0.2141955, NDCG: 0.1168556, F1: 0.0894652, HIT_RATE: 0.4564225, ARHR_ALL_HITS: 0.2688068, NOVELTY: 0.0048890, AVERAGE_POPULARITY: 0.2582500, DIVERSITY_MEAN_INTER_LIST: 0.9622610, DIVERSITY_HERFINDAHL: 0.9962169, COVERAGE_ITEM: 0.2760328, COVERAGE_ITEM_HIT: 0.0674557, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.3795696, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.0433967, SHANNON_ENTROPY: 9.7202363, RATIO_DIVERSITY_HERFINDAHL: 0.9965778, RATIO_DIVERSITY_GINI: 0.1257378, RATIO_SHANNON_ENTROPY: 0.7493337, RATIO_AVERAGE_POPULARITY: 2.0916400, RATIO_NOVELTY: 0.3454702,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments_parallel/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 23.9359
# Function value obtained: -0.0279
# Current minimum: -0.0279
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 38, 'alpha': 0.003467029899769114, 'normalize_similarity': False}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 5717.56 column/sec. Elapsed time 3.89 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 5.67 sec. Users per second: 1770
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 38, 'alpha': 0.003467029899769114, 'normalize_similarity': False} - results: PRECISION: 0.0429155, PRECISION_RECALL_MIN_DEN: 0.0928452, RECALL: 0.0848852, MAP: 0.0185584, MAP_MIN_DEN: 0.0398277, MRR: 0.1402202, NDCG: 0.0761129, F1: 0.0570089, HIT_RATE: 0.3241331, ARHR_ALL_HITS: 0.1609330, NOVELTY: 0.0042997, AVERAGE_POPULARITY: 0.4881906, DIVERSITY_MEAN_INTER_LIST: 0.8071475, DIVERSITY_HERFINDAHL: 0.9807067, COVERAGE_ITEM: 0.1485015, COVERAGE_ITEM_HIT: 0.0200252, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.2573983, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0113343, SHANNON_ENTROPY: 7.3065710, RATIO_DIVERSITY_HERFINDAHL: 0.9810620, RATIO_DIVERSITY_GINI: 0.0328401, RATIO_SHANNON_ENTROPY: 0.5632641, RATIO_AVERAGE_POPULARITY: 3.9539935, RATIO_NOVELTY: 0.3038301,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 10.7160
# Function value obtained: -0.0186
# Current minimum: -0.0279
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 10, 'alpha': 1.9802694200417101, 'normalize_similarity': False}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 6340.65 column/sec. Elapsed time 3.50 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 5.21 sec. Users per second: 1927
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 10, 'alpha': 1.9802694200417101, 'normalize_similarity': False} - results: PRECISION: 0.0051216, PRECISION_RECALL_MIN_DEN: 0.0094566, RECALL: 0.0082384, MAP: 0.0018528, MAP_MIN_DEN: 0.0036042, MRR: 0.0171637, NDCG: 0.0080035, F1: 0.0063164, HIT_RATE: 0.0479275, ARHR_ALL_HITS: 0.0178405, NOVELTY: 0.0062523, AVERAGE_POPULARITY: 0.0264553, DIVERSITY_MEAN_INTER_LIST: 0.9810041, DIVERSITY_HERFINDAHL: 0.9980906, COVERAGE_ITEM: 0.5081001, COVERAGE_ITEM_HIT: 0.0202502, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.0380598, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.2299746, SHANNON_ENTROPY: 12.2070562, RATIO_DIVERSITY_HERFINDAHL: 0.9984522, RATIO_DIVERSITY_GINI: 0.6663289, RATIO_SHANNON_ENTROPY: 0.9410428, RATIO_AVERAGE_POPULARITY: 0.2142686, RATIO_NOVELTY: 0.4418069,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 9.5637
# Function value obtained: -0.0019
# Current minimum: -0.0279
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 982, 'alpha': 0.00677518665512933, 'normalize_similarity': False}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 1455.73 column/sec. Elapsed time 15.27 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 7.76 sec. Users per second: 1293
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 982, 'alpha': 0.00677518665512933, 'normalize_similarity': False} - results: PRECISION: 0.0372360, PRECISION_RECALL_MIN_DEN: 0.0823846, RECALL: 0.0753972, MAP: 0.0144912, MAP_MIN_DEN: 0.0333124, MRR: 0.1144749, NDCG: 0.0646567, F1: 0.0498519, HIT_RATE: 0.2926465, ARHR_ALL_HITS: 0.1285368, NOVELTY: 0.0040302, AVERAGE_POPULARITY: 0.6491170, DIVERSITY_MEAN_INTER_LIST: 0.5159696, DIVERSITY_HERFINDAHL: 0.9515918, COVERAGE_ITEM: 0.0935559, COVERAGE_ITEM_HIT: 0.0108001, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.2323944, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0039639, SHANNON_ENTROPY: 5.5024456, RATIO_DIVERSITY_HERFINDAHL: 0.9519365, RATIO_DIVERSITY_GINI: 0.0114851, RATIO_SHANNON_ENTROPY: 0.4241839, RATIO_AVERAGE_POPULARITY: 5.2573824, RATIO_NOVELTY: 0.2847840,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 33.4234
# Function value obtained: -0.0145
# Current minimum: -0.0279
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 0.23701791349753504, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 6593.14 column/sec. Elapsed time 3.37 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 5.14 sec. Users per second: 1951
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 5, 'alpha': 0.23701791349753504, 'normalize_similarity': True} - results: PRECISION: 0.0361499, PRECISION_RECALL_MIN_DEN: 0.0577120, RECALL: 0.0477776, MAP: 0.0185565, MAP_MIN_DEN: 0.0329495, MRR: 0.1374546, NDCG: 0.0615337, F1: 0.0411582, HIT_RATE: 0.2600638, ARHR_ALL_HITS: 0.1588335, NOVELTY: 0.0054163, AVERAGE_POPULARITY: 0.0521560, DIVERSITY_MEAN_INTER_LIST: 0.8182552, DIVERSITY_HERFINDAHL: 0.9818174, COVERAGE_ITEM: 0.3555936, COVERAGE_ITEM_HIT: 0.0659707, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.2065200, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0723566, SHANNON_ENTROPY: 9.0913102, RATIO_DIVERSITY_HERFINDAHL: 0.9821730, RATIO_DIVERSITY_GINI: 0.2096463, RATIO_SHANNON_ENTROPY: 0.7008497, RATIO_AVERAGE_POPULARITY: 0.4224265, RATIO_NOVELTY: 0.3827276,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 9.3433
# Function value obtained: -0.0186
# Current minimum: -0.0279
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 491, 'alpha': 0.43433798561813974, 'normalize_similarity': True}
# P3alphaRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# P3alphaRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 2077.35 column/sec. Elapsed time 10.70 sec
# EvaluatorHoldout: Processed 10036 (100.0%) in 6.16 sec. Users per second: 1629
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 491, 'alpha': 0.43433798561813974, 'normalize_similarity': True} - results: PRECISION: 0.0610602, PRECISION_RECALL_MIN_DEN: 0.1221343, RECALL: 0.1095292, MAP: 0.0265583, MAP_MIN_DEN: 0.0538801, MRR: 0.1795043, NDCG: 0.1017849, F1: 0.0784090, HIT_RATE: 0.4080311, ARHR_ALL_HITS: 0.2172869, NOVELTY: 0.0047644, AVERAGE_POPULARITY: 0.3118548, DIVERSITY_MEAN_INTER_LIST: 0.9378345, DIVERSITY_HERFINDAHL: 0.9937741, COVERAGE_ITEM: 0.2814328, COVERAGE_ITEM_HIT: 0.0522005, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.3240228, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0395377, SHANNON_ENTROPY: 9.2992278, RATIO_DIVERSITY_HERFINDAHL: 0.9941341, RATIO_DIVERSITY_GINI: 0.1145565, RATIO_SHANNON_ENTROPY: 0.7168781, RATIO_AVERAGE_POPULARITY: 2.5258000, RATIO_NOVELTY: 0.3366662,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 23.1537
# Function value obtained: -0.0266
# Current minimum: -0.0279
# SearchBayesianSkopt: Search complete. Best config is 4: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True}
#
# P3alphaRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# P3alphaRecommender: URM Detected 110 ( 0.5%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True}
# P3alphaRecommender: Similarity column 22222 (100.0%), 2778.04 column/sec. Elapsed time 8.00 sec
# EvaluatorHoldout: Processed 10510 (100.0%) in 6.37 sec. Users per second: 1650
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 250, 'alpha': 0.0, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0866032, PRECISION_RECALL_MIN_DEN: 0.1544984, RECALL: 0.1317104, MAP: 0.0421304, MAP_MIN_DEN: 0.0754725, MRR: 0.2459587, NDCG: 0.1376967, F1: 0.1044969, HIT_RATE: 0.5013321, ARHR_ALL_HITS: 0.3183001, NOVELTY: 0.0048462, AVERAGE_POPULARITY: 0.2835490, DIVERSITY_MEAN_INTER_LIST: 0.9500616, DIVERSITY_HERFINDAHL: 0.9949971, COVERAGE_ITEM: 0.2399424, COVERAGE_ITEM_HIT: 0.0776258, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.4169172, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.0366238, SHANNON_ENTROPY: 9.4480111, RATIO_DIVERSITY_HERFINDAHL: 0.9953564, RATIO_DIVERSITY_GINI: 0.1049410, RATIO_SHANNON_ENTROPY: 0.7277330, RATIO_AVERAGE_POPULARITY: 2.2629442, RATIO_NOVELTY: 0.2737239,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments_parallel/P3alphaRecommender_best_model_last'
# P3alphaRecommender: Saving complete
# SLIMElasticNetRecommender: Processed 15236 (68.6%) in 5.00 min. Items per second: 50.78
# SLIMElasticNetRecommender: Processed 22222 (100.0%) in 7.45 min. Items per second: 49.71
# EvaluatorHoldout: Processed 10036 (100.0%) in 10.14 sec. Users per second: 989
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 977, 'l1_ratio': 1.901158020497196e-05, 'alpha': 0.5642211444241505} - results: PRECISION: 0.0432344, PRECISION_RECALL_MIN_DEN: 0.0952558, RECALL: 0.0871859, MAP: 0.0178750, MAP_MIN_DEN: 0.0405014, MRR: 0.1362661, NDCG: 0.0767009, F1: 0.0578043, HIT_RATE: 0.3300120, ARHR_ALL_HITS: 0.1557577, NOVELTY: 0.0041224, AVERAGE_POPULARITY: 0.5926109, DIVERSITY_MEAN_INTER_LIST: 0.6439562, DIVERSITY_HERFINDAHL: 0.9643892, COVERAGE_ITEM: 0.1060661, COVERAGE_ITEM_HIT: 0.0150302, ITEMS_IN_GT: 0.7413824, COVERAGE_USER: 0.7941130, COVERAGE_USER_HIT: 0.2620668, USERS_IN_GT: 0.7941130, DIVERSITY_GINI: 0.0057238, SHANNON_ENTROPY: 6.2149534, RATIO_DIVERSITY_HERFINDAHL: 0.9647385, RATIO_DIVERSITY_GINI: 0.0165843, RATIO_SHANNON_ENTROPY: 0.4791112, RATIO_AVERAGE_POPULARITY: 4.7997237, RATIO_NOVELTY: 0.2913002,
#
# EvaluatorHoldout: Processed 10510 (100.0%) in 9.98 sec. Users per second: 1054
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 977, 'l1_ratio': 1.901158020497196e-05, 'alpha': 0.5642211444241505} - results:
# CUTOFF: 10 - PRECISION: 0.0524929, PRECISION_RECALL_MIN_DEN: 0.1019603, RECALL: 0.0893590, MAP: 0.0222901, MAP_MIN_DEN: 0.0451133, MRR: 0.1632823, NDCG: 0.0868869, F1: 0.0661353, HIT_RATE: 0.3804948, ARHR_ALL_HITS: 0.1904129, NOVELTY: 0.0041287, AVERAGE_POPULARITY: 0.5878741, DIVERSITY_MEAN_INTER_LIST: 0.6514450, DIVERSITY_HERFINDAHL: 0.9651383, COVERAGE_ITEM: 0.1111511, COVERAGE_ITEM_HIT: 0.0180002, ITEMS_IN_GT: 0.8014580, COVERAGE_USER: 0.8316189, COVERAGE_USER_HIT: 0.3164266, USERS_IN_GT: 0.8316189, DIVERSITY_GINI: 0.0059720, SHANNON_ENTROPY: 6.2647671, RATIO_DIVERSITY_HERFINDAHL: 0.9654879, RATIO_DIVERSITY_GINI: 0.0173031, RATIO_SHANNON_ENTROPY: 0.4829513, RATIO_AVERAGE_POPULARITY: 4.7613587, RATIO_NOVELTY: 0.2917473,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_parallel/SLIMElasticNetRecommender
#
# SLIMElasticNetRecommender: Saving model in file 'result_experiments_parallel/SLIMElasticNetRecommender_best_model'
# SLIMElasticNetRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 474.8717
# Function value obtained: -0.0179
# Current minimum: -0.0179
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 61, 'l1_ratio': 0.050038571455028186, 'alpha': 0.3349391601118447}
# SLIMElasticNetRecommender: URM Detected 472 ( 3.7%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 341 ( 1.5%) items with no interactions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 pool = multiprocessing.Pool(processes=int(multiprocessing.cpu_count()), maxtasksperchild=1)
# ----> 2 pool.map(runHyperparameterSearch_Collaborative_partial, collaborative_algorithm_list)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/miniconda3/envs/RecSysFramework/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
