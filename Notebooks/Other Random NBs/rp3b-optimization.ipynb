# %%
import os
os.chdir( "../")

# %%
import pandas as pd
import numpy as np

path = "Dataset/data_train.csv"
df = pd.read_csv(filepath_or_buffer=path,
                               sep=",",
                               header=1,
                               engine='python',
                               names=['UserID', 'ItemID', 'Interaction'])


df
# Out:
#         UserID  ItemID  Interaction
# 0            1      15          1.0
# 1            1      16          1.0
# 2            1     133          1.0
# 3            1     161          1.0
# 4            1     187          1.0
# ...        ...     ...          ...
# 478724   13024   13605          1.0
# 478725   13024   13823          1.0
# 478726   13024   15122          1.0
# 478727   13024   18185          1.0
# 478728   13024   20014          1.0
#
# [478729 rows x 3 columns]

# %%
df.Interaction.value_counts()
# Out:
# 1.0    478729
# Name: Interaction, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478729 entries, 0 to 478728
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   UserID       478729 non-null  int64
#  1   ItemID       478729 non-null  int64
#  2   Interaction  478729 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 11.0 MB

# %%
user_ids = df["UserID"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
item_ids = df["ItemID"].unique().tolist()
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df["User"] = df["UserID"].map(user2user_encoded)
df["Item"] = df["ItemID"].map(item2item_encoded)

num_users = len(user2user_encoded)
num_items = len(item_encoded2item)
df["Interaction"] = df["Interaction"].values.astype(np.float32)

# min and max ratings will be used to normalize the ratings later
min_rating = 0.0
max_rating = max(df["Interaction"])

print(
    "Number of users: {}, Number of Items: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_items, min_rating, max_rating
    )
)
# Out:
# Number of users: 12638, Number of Items: 22222, Min rating: 0.0, Max rating: 1.0

# %%
df.UserID = df.User
df.ItemID = df.Item

# %%
df = df.drop(["User","Item"], axis=1)

# %%
df.head()
# Out:
#    UserID  ItemID  Interaction
# 0       0       0          1.0
# 1       0       1          1.0
# 2       0       2          1.0
# 3       0       3          1.0
# 4       0       4          1.0

# %%
userId_unique = df["UserID"].unique()
itemId_unique = df["ItemID"].unique()

# %%
num_users = len(userId_unique)
num_items = len(itemId_unique)

# %%
import scipy.sparse as sps

urm_all = sps.csr_matrix((df.Interaction, (df.UserID, df.ItemID)),
                         shape = (num_users, num_items))

urm_train = sps.csr_matrix((ratings_training, (user_ids_training, item_ids_training)),
                           shape = (num_users, num_items))

urm_validation = sps.csr_matrix((ratings_validation, (user_ids_validation, item_ids_validation)),
                                shape = (num_users, num_items))

urm_train_validation = sps.csr_matrix((ratings_training_validation, (user_ids_training_validation, item_ids_training_validation)),
                                      shape = (num_users, num_items))

urm_test = sps.csr_matrix((ratings_test, (user_ids_test, item_ids_test)),
                          shape = (num_users, num_items))

urm_all, urm_train, urm_test, urm_validation, urm_train_validation
# Out:
# (<12638x22222 sparse matrix of type '<class 'numpy.float32'>'
#  	with 478729 stored elements in Compressed Sparse Row format>,
#  <12638x22222 sparse matrix of type '<class 'numpy.float32'>'
#  	with 345881 stored elements in Compressed Sparse Row format>,
#  <12638x22222 sparse matrix of type '<class 'numpy.float32'>'
#  	with 71810 stored elements in Compressed Sparse Row format>,
#  <12638x22222 sparse matrix of type '<class 'numpy.float32'>'
#  	with 61038 stored elements in Compressed Sparse Row format>,
#  <12638x22222 sparse matrix of type '<class 'numpy.float32'>'
#  	with 406919 stored elements in Compressed Sparse Row format>)

# %%
from Recommenders.Recommender_import_list import *
from Evaluation.Evaluator import EvaluatorHoldout
evaluator_validation = EvaluatorHoldout(urm_validation, cutoff_list=[10], ignore_users=[])
evaluator_test = EvaluatorHoldout(urm_test, cutoff_list=[10], ignore_users=[])
# Out:
# 2023-12-08 11:50:47.098653: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-12-08 11:50:47.098678: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# EvaluatorHoldout: Ignoring 3038 (24.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users
# EvaluatorHoldout: Ignoring 2769 (21.9%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 0 Users

# %% [markdown]
# ## Insert model here

# %%
from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from functools import partial

output_folder_path = "result_experiments/SKOPT_test/"

n_cases = 300
n_random_starts = int(n_cases * 0.3)

runHyperparameterSearch_Collaborative_partial = partial(
                    runHyperparameterSearch_Collaborative,
                    URM_train = urm_train,
                    URM_train_last_test = urm_train_validation,
                    metric_to_optimize = "MAP",
                    cutoff_to_optimize = 10,
                    n_cases = n_cases,
                    n_random_starts = n_random_starts,
                    evaluator_validation_earlystopping = evaluator_validation,
                    evaluator_validation = evaluator_validation,
                    evaluator_test = evaluator_test,
                    output_folder_path = output_folder_path,
                    resume_from_saved = False
)

runHyperparameterSearch_Collaborative_partial(RP3betaRecommender)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 223, 'alpha': 1.9542268376679761, 'beta': 0.1919448971073961, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5142.49 column/sec. Elapsed time 4.32 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.99 sec. Users per second: 3214
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 223, 'alpha': 1.9542268376679761, 'beta': 0.1919448971073961, 'normalize_similarity': True} - results: PRECISION: 0.0206458, PRECISION_RECALL_MIN_DEN: 0.0523429, RECALL: 0.0495381, MAP: 0.0067518, MAP_MIN_DEN: 0.0181069, MRR: 0.0544204, NDCG: 0.0360621, F1: 0.0291450, HIT_RATE: 0.1702083, ARHR_ALL_HITS: 0.0604366, NOVELTY: 0.0060177, AVERAGE_POPULARITY: 0.0894528, DIVERSITY_MEAN_INTER_LIST: 0.9943814, DIVERSITY_HERFINDAHL: 0.9994278, COVERAGE_ITEM: 0.3672937, COVERAGE_ITEM_HIT: 0.0328953, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.1292926, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1277392, SHANNON_ENTROPY: 11.7763471, RATIO_DIVERSITY_HERFINDAHL: 0.9997884, RATIO_DIVERSITY_GINI: 0.3687875, RATIO_SHANNON_ENTROPY: 0.9074676, RATIO_AVERAGE_POPULARITY: 0.7335514, RATIO_NOVELTY: 0.3765179,
#
# EvaluatorHoldout: Processed 9869 (100.0%) in 2.98 sec. Users per second: 3309
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 223, 'alpha': 1.9542268376679761, 'beta': 0.1919448971073961, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0235991, PRECISION_RECALL_MIN_DEN: 0.0526023, RECALL: 0.0488381, MAP: 0.0081365, MAP_MIN_DEN: 0.0194699, MRR: 0.0635058, NDCG: 0.0389371, F1: 0.0318217, HIT_RATE: 0.1889756, ARHR_ALL_HITS: 0.0717367, NOVELTY: 0.0060160, AVERAGE_POPULARITY: 0.0896571, DIVERSITY_MEAN_INTER_LIST: 0.9943909, DIVERSITY_HERFINDAHL: 0.9994290, COVERAGE_ITEM: 0.3701737, COVERAGE_ITEM_HIT: 0.0362254, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.1475708, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.1280441, SHANNON_ENTROPY: 11.7801883, RATIO_DIVERSITY_HERFINDAHL: 0.9997896, RATIO_DIVERSITY_GINI: 0.3696676, RATIO_SHANNON_ENTROPY: 0.9077636, RATIO_AVERAGE_POPULARITY: 0.7352269, RATIO_NOVELTY: 0.3764126,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/SKOPT_test/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 13.5235
# Function value obtained: -0.0068
# Current minimum: -0.0068
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 723, 'alpha': 1.4223843968107606, 'beta': 0.813843043797482, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2916.26 column/sec. Elapsed time 7.62 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.58 sec. Users per second: 2095
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 723, 'alpha': 1.4223843968107606, 'beta': 0.813843043797482, 'normalize_similarity': False} - results: PRECISION: 0.0043646, PRECISION_RECALL_MIN_DEN: 0.0099289, RECALL: 0.0090503, MAP: 0.0013546, MAP_MIN_DEN: 0.0029802, MRR: 0.0122229, NDCG: 0.0068360, F1: 0.0058891, HIT_RATE: 0.0395833, ARHR_ALL_HITS: 0.0128596, NOVELTY: 0.0072890, AVERAGE_POPULARITY: 0.0057625, DIVERSITY_MEAN_INTER_LIST: 0.9982992, DIVERSITY_HERFINDAHL: 0.9998195, COVERAGE_ITEM: 0.6731167, COVERAGE_ITEM_HIT: 0.0173702, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0300680, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.3201957, SHANNON_ENTROPY: 13.1575097, RATIO_DIVERSITY_HERFINDAHL: 1.0001803, RATIO_DIVERSITY_GINI: 0.9244160, RATIO_SHANNON_ENTROPY: 1.0138979, RATIO_AVERAGE_POPULARITY: 0.0472547, RATIO_NOVELTY: 0.4560627,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 17.1687
# Function value obtained: -0.0014
# Current minimum: -0.0068
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 744, 'alpha': 1.8610583418190954, 'beta': 1.1971994376673274, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2965.92 column/sec. Elapsed time 7.49 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.72 sec. Users per second: 2035
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 744, 'alpha': 1.8610583418190954, 'beta': 1.1971994376673274, 'normalize_similarity': False} - results: PRECISION: 0.0027813, PRECISION_RECALL_MIN_DEN: 0.0063436, RECALL: 0.0058029, MAP: 0.0008760, MAP_MIN_DEN: 0.0018220, MRR: 0.0082752, NDCG: 0.0043652, F1: 0.0037603, HIT_RATE: 0.0262500, ARHR_ALL_HITS: 0.0085178, NOVELTY: 0.0073706, AVERAGE_POPULARITY: 0.0047460, DIVERSITY_MEAN_INTER_LIST: 0.9981399, DIVERSITY_HERFINDAHL: 0.9998036, COVERAGE_ITEM: 0.6353614, COVERAGE_ITEM_HIT: 0.0111601, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0199399, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2931239, SHANNON_ENTROPY: 13.0327325, RATIO_DIVERSITY_HERFINDAHL: 1.0001643, RATIO_DIVERSITY_GINI: 0.8462588, RATIO_SHANNON_ENTROPY: 1.0042828, RATIO_AVERAGE_POPULARITY: 0.0389189, RATIO_NOVELTY: 0.4611683,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 17.1586
# Function value obtained: -0.0009
# Current minimum: -0.0068
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 437, 'alpha': 1.7750404114078253, 'beta': 1.5826063037809042, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3803.22 column/sec. Elapsed time 5.84 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.96 sec. Users per second: 2425
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 437, 'alpha': 1.7750404114078253, 'beta': 1.5826063037809042, 'normalize_similarity': False} - results: PRECISION: 0.0022917, PRECISION_RECALL_MIN_DEN: 0.0052213, RECALL: 0.0047496, MAP: 0.0007074, MAP_MIN_DEN: 0.0014494, MRR: 0.0066499, NDCG: 0.0035387, F1: 0.0030916, HIT_RATE: 0.0215625, ARHR_ALL_HITS: 0.0068621, NOVELTY: 0.0075775, AVERAGE_POPULARITY: 0.0031035, DIVERSITY_MEAN_INTER_LIST: 0.9975918, DIVERSITY_HERFINDAHL: 0.9997488, COVERAGE_ITEM: 0.5515255, COVERAGE_ITEM_HIT: 0.0090451, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0163792, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2321565, SHANNON_ENTROPY: 12.6960407, RATIO_DIVERSITY_HERFINDAHL: 1.0001095, RATIO_DIVERSITY_GINI: 0.6702439, RATIO_SHANNON_ENTROPY: 0.9783378, RATIO_AVERAGE_POPULARITY: 0.0254500, RATIO_NOVELTY: 0.4741133,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 13.4201
# Function value obtained: -0.0007
# Current minimum: -0.0068
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 705, 'alpha': 1.2081397856112652, 'beta': 1.5322783542138076, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2996.67 column/sec. Elapsed time 7.42 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.65 sec. Users per second: 2064
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 705, 'alpha': 1.2081397856112652, 'beta': 1.5322783542138076, 'normalize_similarity': False} - results: PRECISION: 0.0023646, PRECISION_RECALL_MIN_DEN: 0.0049321, RECALL: 0.0043467, MAP: 0.0007605, MAP_MIN_DEN: 0.0015319, MRR: 0.0070619, NDCG: 0.0035890, F1: 0.0030629, HIT_RATE: 0.0218750, ARHR_ALL_HITS: 0.0073336, NOVELTY: 0.0078121, AVERAGE_POPULARITY: 0.0020574, DIVERSITY_MEAN_INTER_LIST: 0.9963801, DIVERSITY_HERFINDAHL: 0.9996276, COVERAGE_ITEM: 0.4405994, COVERAGE_ITEM_HIT: 0.0093601, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0166166, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1591190, SHANNON_ENTROPY: 12.1468329, RATIO_DIVERSITY_HERFINDAHL: 0.9999883, RATIO_DIVERSITY_GINI: 0.4593821, RATIO_SHANNON_ENTROPY: 0.9360167, RATIO_AVERAGE_POPULARITY: 0.0168717, RATIO_NOVELTY: 0.4887917,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 16.9949
# Function value obtained: -0.0008
# Current minimum: -0.0068
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 264, 'alpha': 1.32689906997807, 'beta': 1.7349073704166609, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4531.66 column/sec. Elapsed time 4.90 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.38 sec. Users per second: 2839
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 264, 'alpha': 1.32689906997807, 'beta': 1.7349073704166609, 'normalize_similarity': True} - results: PRECISION: 0.0015833, PRECISION_RECALL_MIN_DEN: 0.0036234, RECALL: 0.0032410, MAP: 0.0005385, MAP_MIN_DEN: 0.0011790, MRR: 0.0052044, NDCG: 0.0026178, F1: 0.0021274, HIT_RATE: 0.0151042, ARHR_ALL_HITS: 0.0052945, NOVELTY: 0.0079340, AVERAGE_POPULARITY: 0.0016796, DIVERSITY_MEAN_INTER_LIST: 0.9907870, DIVERSITY_HERFINDAHL: 0.9990684, COVERAGE_ITEM: 0.3202682, COVERAGE_ITEM_HIT: 0.0063901, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0114733, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0840674, SHANNON_ENTROPY: 11.1144252, RATIO_DIVERSITY_HERFINDAHL: 0.9994289, RATIO_DIVERSITY_GINI: 0.2427055, RATIO_SHANNON_ENTROPY: 0.8564609, RATIO_AVERAGE_POPULARITY: 0.0137732, RATIO_NOVELTY: 0.4964199,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 10.7966
# Function value obtained: -0.0005
# Current minimum: -0.0068
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 176, 'alpha': 1.1092321354395933, 'beta': 0.9466774027088689, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5436.83 column/sec. Elapsed time 4.09 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.03 sec. Users per second: 3169
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 176, 'alpha': 1.1092321354395933, 'beta': 0.9466774027088689, 'normalize_similarity': False} - results: PRECISION: 0.0048646, PRECISION_RECALL_MIN_DEN: 0.0098847, RECALL: 0.0086425, MAP: 0.0014419, MAP_MIN_DEN: 0.0027824, MRR: 0.0123455, NDCG: 0.0068336, F1: 0.0062252, HIT_RATE: 0.0419792, ARHR_ALL_HITS: 0.0133240, NOVELTY: 0.0075434, AVERAGE_POPULARITY: 0.0033129, DIVERSITY_MEAN_INTER_LIST: 0.9978090, DIVERSITY_HERFINDAHL: 0.9997705, COVERAGE_ITEM: 0.5914409, COVERAGE_ITEM_HIT: 0.0190802, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0318880, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2557199, SHANNON_ENTROPY: 12.8329841, RATIO_DIVERSITY_HERFINDAHL: 1.0001312, RATIO_DIVERSITY_GINI: 0.7382721, RATIO_SHANNON_ENTROPY: 0.9888905, RATIO_AVERAGE_POPULARITY: 0.0271670, RATIO_NOVELTY: 0.4719768,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 8.9707
# Function value obtained: -0.0014
# Current minimum: -0.0068
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 951, 'alpha': 0.5873519705178291, 'beta': 1.2249000521887397, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2635.20 column/sec. Elapsed time 8.43 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 5.01 sec. Users per second: 1915
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 951, 'alpha': 0.5873519705178291, 'beta': 1.2249000521887397, 'normalize_similarity': True} - results: PRECISION: 0.0031667, PRECISION_RECALL_MIN_DEN: 0.0062878, RECALL: 0.0054127, MAP: 0.0010248, MAP_MIN_DEN: 0.0020836, MRR: 0.0090750, NDCG: 0.0047124, F1: 0.0039957, HIT_RATE: 0.0281250, ARHR_ALL_HITS: 0.0096339, NOVELTY: 0.0079335, AVERAGE_POPULARITY: 0.0017143, DIVERSITY_MEAN_INTER_LIST: 0.9961330, DIVERSITY_HERFINDAHL: 0.9996029, COVERAGE_ITEM: 0.4443794, COVERAGE_ITEM_HIT: 0.0126451, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0213641, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1489493, SHANNON_ENTROPY: 12.0432970, RATIO_DIVERSITY_HERFINDAHL: 0.9999636, RATIO_DIVERSITY_GINI: 0.4300216, RATIO_SHANNON_ENTROPY: 0.9280384, RATIO_AVERAGE_POPULARITY: 0.0140578, RATIO_NOVELTY: 0.4963855,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 19.3563
# Function value obtained: -0.0010
# Current minimum: -0.0068
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 748, 'alpha': 1.9566100563827888, 'beta': 1.6234726137590063, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2859.93 column/sec. Elapsed time 7.77 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.78 sec. Users per second: 2007
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 748, 'alpha': 1.9566100563827888, 'beta': 1.6234726137590063, 'normalize_similarity': True} - results: PRECISION: 0.0015104, PRECISION_RECALL_MIN_DEN: 0.0036425, RECALL: 0.0033323, MAP: 0.0004799, MAP_MIN_DEN: 0.0009619, MRR: 0.0046424, NDCG: 0.0023824, F1: 0.0020786, HIT_RATE: 0.0145833, ARHR_ALL_HITS: 0.0047206, NOVELTY: 0.0076542, AVERAGE_POPULARITY: 0.0027102, DIVERSITY_MEAN_INTER_LIST: 0.9926640, DIVERSITY_HERFINDAHL: 0.9992561, COVERAGE_ITEM: 0.3577536, COVERAGE_ITEM_HIT: 0.0059401, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0110777, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1034043, SHANNON_ENTROPY: 11.4310706, RATIO_DIVERSITY_HERFINDAHL: 0.9996166, RATIO_DIVERSITY_GINI: 0.2985319, RATIO_SHANNON_ENTROPY: 0.8808611, RATIO_AVERAGE_POPULARITY: 0.0222245, RATIO_NOVELTY: 0.4789130,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 17.8517
# Function value obtained: -0.0005
# Current minimum: -0.0068
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 103, 'alpha': 1.6318835729163867, 'beta': 0.45049419903101684, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 6872.83 column/sec. Elapsed time 3.23 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.81 sec. Users per second: 3417
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 103, 'alpha': 1.6318835729163867, 'beta': 0.45049419903101684, 'normalize_similarity': True} - results: PRECISION: 0.0163125, PRECISION_RECALL_MIN_DEN: 0.0415678, RECALL: 0.0392347, MAP: 0.0050824, MAP_MIN_DEN: 0.0132729, MRR: 0.0400447, NDCG: 0.0274331, F1: 0.0230441, HIT_RATE: 0.1337500, ARHR_ALL_HITS: 0.0449398, NOVELTY: 0.0067016, AVERAGE_POPULARITY: 0.0339508, DIVERSITY_MEAN_INTER_LIST: 0.9961253, DIVERSITY_HERFINDAHL: 0.9996022, COVERAGE_ITEM: 0.4333543, COVERAGE_ITEM_HIT: 0.0333903, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.1015984, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1606690, SHANNON_ENTROPY: 12.1414895, RATIO_DIVERSITY_HERFINDAHL: 0.9999628, RATIO_DIVERSITY_GINI: 0.4638569, RATIO_SHANNON_ENTROPY: 0.9356049, RATIO_AVERAGE_POPULARITY: 0.2784111, RATIO_NOVELTY: 0.4193056,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 7.1098
# Function value obtained: -0.0051
# Current minimum: -0.0068
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 403, 'alpha': 0.7578195576564235, 'beta': 0.2187396064237062, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3756.13 column/sec. Elapsed time 5.92 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.22 sec. Users per second: 2980
# SearchBayesianSkopt: New best config found. Config 10: {'topK': 403, 'alpha': 0.7578195576564235, 'beta': 0.2187396064237062, 'normalize_similarity': False} - results: PRECISION: 0.0511667, PRECISION_RECALL_MIN_DEN: 0.1151485, RECALL: 0.1068371, MAP: 0.0226276, MAP_MIN_DEN: 0.0525231, MRR: 0.1602830, NDCG: 0.0943397, F1: 0.0691945, HIT_RATE: 0.3587500, ARHR_ALL_HITS: 0.1895212, NOVELTY: 0.0054032, AVERAGE_POPULARITY: 0.2355125, DIVERSITY_MEAN_INTER_LIST: 0.9559560, DIVERSITY_HERFINDAHL: 0.9955856, COVERAGE_ITEM: 0.5440554, COVERAGE_ITEM_HIT: 0.0629556, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.2725115, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1413340, SHANNON_ENTROPY: 10.8120140, RATIO_DIVERSITY_HERFINDAHL: 0.9959449, RATIO_DIVERSITY_GINI: 0.4080361, RATIO_SHANNON_ENTROPY: 0.8331575, RATIO_AVERAGE_POPULARITY: 1.9313046, RATIO_NOVELTY: 0.3380702,
#
# EvaluatorHoldout: Processed 9869 (100.0%) in 3.12 sec. Users per second: 3167
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 403, 'alpha': 0.7578195576564235, 'beta': 0.2187396064237062, 'normalize_similarity': False} - results:
# CUTOFF: 10 - PRECISION: 0.0593677, PRECISION_RECALL_MIN_DEN: 0.1234691, RECALL: 0.1118070, MAP: 0.0266946, MAP_MIN_DEN: 0.0552953, MRR: 0.1781544, NDCG: 0.1022338, F1: 0.0775550, HIT_RATE: 0.3950755, ARHR_ALL_HITS: 0.2166576, NOVELTY: 0.0054048, AVERAGE_POPULARITY: 0.2353054, DIVERSITY_MEAN_INTER_LIST: 0.9559406, DIVERSITY_HERFINDAHL: 0.9955844, COVERAGE_ITEM: 0.5508955, COVERAGE_ITEM_HIT: 0.0697057, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.3085140, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.1434162, SHANNON_ENTROPY: 10.8263459, RATIO_DIVERSITY_HERFINDAHL: 0.9959436, RATIO_DIVERSITY_GINI: 0.4140476, RATIO_SHANNON_ENTROPY: 0.8342619, RATIO_AVERAGE_POPULARITY: 1.9296064, RATIO_NOVELTY: 0.3381727,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/SKOPT_test/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 17.3993
# Function value obtained: -0.0226
# Current minimum: -0.0226
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 888, 'alpha': 1.9425175748943644, 'beta': 0.8848552874730375, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2626.26 column/sec. Elapsed time 8.46 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.61 sec. Users per second: 2081
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'topK': 888, 'alpha': 1.9425175748943644, 'beta': 0.8848552874730375, 'normalize_similarity': False} - results: PRECISION: 0.0033229, PRECISION_RECALL_MIN_DEN: 0.0079222, RECALL: 0.0073684, MAP: 0.0009962, MAP_MIN_DEN: 0.0022467, MRR: 0.0093771, NDCG: 0.0052849, F1: 0.0045803, HIT_RATE: 0.0311458, ARHR_ALL_HITS: 0.0096576, NOVELTY: 0.0071536, AVERAGE_POPULARITY: 0.0082955, DIVERSITY_MEAN_INTER_LIST: 0.9984098, DIVERSITY_HERFINDAHL: 0.9998306, COVERAGE_ITEM: 0.6864369, COVERAGE_ITEM_HIT: 0.0133201, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0236588, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.3390040, SHANNON_ENTROPY: 13.2378376, RATIO_DIVERSITY_HERFINDAHL: 1.0001913, RATIO_DIVERSITY_GINI: 0.9787161, RATIO_SHANNON_ENTROPY: 1.0200879, RATIO_AVERAGE_POPULARITY: 0.0680270, RATIO_NOVELTY: 0.4475879,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 18.2897
# Function value obtained: -0.0010
# Current minimum: -0.0226
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 839, 'alpha': 1.026793122814494, 'beta': 0.6827853304534158, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2737.70 column/sec. Elapsed time 8.12 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.73 sec. Users per second: 2030
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 839, 'alpha': 1.026793122814494, 'beta': 0.6827853304534158, 'normalize_similarity': True} - results: PRECISION: 0.0138125, PRECISION_RECALL_MIN_DEN: 0.0324592, RECALL: 0.0299071, MAP: 0.0043050, MAP_MIN_DEN: 0.0102707, MRR: 0.0331077, NDCG: 0.0218470, F1: 0.0188973, HIT_RATE: 0.1104167, ARHR_ALL_HITS: 0.0376310, NOVELTY: 0.0072357, AVERAGE_POPULARITY: 0.0146001, DIVERSITY_MEAN_INTER_LIST: 0.9979175, DIVERSITY_HERFINDAHL: 0.9997814, COVERAGE_ITEM: 0.6627666, COVERAGE_ITEM_HIT: 0.0403654, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0838740, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2933958, SHANNON_ENTROPY: 13.0025092, RATIO_DIVERSITY_HERFINDAHL: 1.0001421, RATIO_DIVERSITY_GINI: 0.8470438, RATIO_SHANNON_ENTROPY: 1.0019538, RATIO_AVERAGE_POPULARITY: 0.1197269, RATIO_NOVELTY: 0.4527267,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 18.0559
# Function value obtained: -0.0043
# Current minimum: -0.0226
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 772, 'alpha': 0.5775496932690732, 'beta': 1.9273127043926297, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2816.02 column/sec. Elapsed time 7.89 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.61 sec. Users per second: 2081
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 772, 'alpha': 0.5775496932690732, 'beta': 1.9273127043926297, 'normalize_similarity': True} - results: PRECISION: 0.0014375, PRECISION_RECALL_MIN_DEN: 0.0031570, RECALL: 0.0027808, MAP: 0.0004799, MAP_MIN_DEN: 0.0009775, MRR: 0.0044754, NDCG: 0.0022717, F1: 0.0018953, HIT_RATE: 0.0132292, ARHR_ALL_HITS: 0.0046320, NOVELTY: 0.0081254, AVERAGE_POPULARITY: 0.0011845, DIVERSITY_MEAN_INTER_LIST: 0.9929173, DIVERSITY_HERFINDAHL: 0.9992814, COVERAGE_ITEM: 0.2769328, COVERAGE_ITEM_HIT: 0.0057151, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0100491, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0722517, SHANNON_ENTROPY: 11.0121500, RATIO_DIVERSITY_HERFINDAHL: 0.9996419, RATIO_DIVERSITY_GINI: 0.2085931, RATIO_SHANNON_ENTROPY: 0.8485797, RATIO_AVERAGE_POPULARITY: 0.0097132, RATIO_NOVELTY: 0.5083911,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 17.6484
# Function value obtained: -0.0005
# Current minimum: -0.0226
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 917, 'alpha': 0.6577838956933771, 'beta': 0.6127703197907751, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2659.76 column/sec. Elapsed time 8.35 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.73 sec. Users per second: 2029
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'topK': 917, 'alpha': 0.6577838956933771, 'beta': 0.6127703197907751, 'normalize_similarity': True} - results: PRECISION: 0.0303437, PRECISION_RECALL_MIN_DEN: 0.0689180, RECALL: 0.0635070, MAP: 0.0113939, MAP_MIN_DEN: 0.0260421, MRR: 0.0799711, NDCG: 0.0506655, F1: 0.0410661, HIT_RATE: 0.2211458, ARHR_ALL_HITS: 0.0951026, NOVELTY: 0.0067803, AVERAGE_POPULARITY: 0.0743663, DIVERSITY_MEAN_INTER_LIST: 0.9948564, DIVERSITY_HERFINDAHL: 0.9994753, COVERAGE_ITEM: 0.7425074, COVERAGE_ITEM_HIT: 0.0580056, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.1679854, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.3342421, SHANNON_ENTROPY: 12.9304967, RATIO_DIVERSITY_HERFINDAHL: 0.9998359, RATIO_DIVERSITY_GINI: 0.9649682, RATIO_SHANNON_ENTROPY: 0.9964046, RATIO_AVERAGE_POPULARITY: 0.6098360, RATIO_NOVELTY: 0.4242343,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 18.6818
# Function value obtained: -0.0114
# Current minimum: -0.0226
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 495, 'alpha': 0.9687735592651947, 'beta': 1.5027574887843864, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3477.87 column/sec. Elapsed time 6.39 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.03 sec. Users per second: 2381
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 495, 'alpha': 0.9687735592651947, 'beta': 1.5027574887843864, 'normalize_similarity': True} - results: PRECISION: 0.0021146, PRECISION_RECALL_MIN_DEN: 0.0044051, RECALL: 0.0038697, MAP: 0.0007396, MAP_MIN_DEN: 0.0015174, MRR: 0.0069063, NDCG: 0.0033669, F1: 0.0027348, HIT_RATE: 0.0195833, ARHR_ALL_HITS: 0.0071454, NOVELTY: 0.0079605, AVERAGE_POPULARITY: 0.0016145, DIVERSITY_MEAN_INTER_LIST: 0.9937613, DIVERSITY_HERFINDAHL: 0.9993658, COVERAGE_ITEM: 0.3691837, COVERAGE_ITEM_HIT: 0.0085051, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0148758, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1073397, SHANNON_ENTROPY: 11.5196606, RATIO_DIVERSITY_HERFINDAHL: 0.9997264, RATIO_DIVERSITY_GINI: 0.3098934, RATIO_SHANNON_ENTROPY: 0.8876877, RATIO_AVERAGE_POPULARITY: 0.0132399, RATIO_NOVELTY: 0.4980788,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 14.4560
# Function value obtained: -0.0007
# Current minimum: -0.0226
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 405, 'alpha': 0.1491140425987514, 'beta': 0.11848679980911661, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3863.89 column/sec. Elapsed time 5.75 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.13 sec. Users per second: 3070
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 405, 'alpha': 0.1491140425987514, 'beta': 0.11848679980911661, 'normalize_similarity': True} - results: PRECISION: 0.0528438, PRECISION_RECALL_MIN_DEN: 0.1245728, RECALL: 0.1163244, MAP: 0.0222949, MAP_MIN_DEN: 0.0541730, MRR: 0.1612091, NDCG: 0.0980840, F1: 0.0726735, HIT_RATE: 0.3797917, ARHR_ALL_HITS: 0.1887634, NOVELTY: 0.0047209, AVERAGE_POPULARITY: 0.3666713, DIVERSITY_MEAN_INTER_LIST: 0.8929544, DIVERSITY_HERFINDAHL: 0.9892861, COVERAGE_ITEM: 0.3002430, COVERAGE_ITEM_HIT: 0.0495905, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.2884950, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0377685, SHANNON_ENTROPY: 8.8025991, RATIO_DIVERSITY_HERFINDAHL: 0.9896431, RATIO_DIVERSITY_GINI: 0.1090390, RATIO_SHANNON_ENTROPY: 0.6783150, RATIO_AVERAGE_POPULARITY: 3.0068636, RATIO_NOVELTY: 0.2953774,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 11.7597
# Function value obtained: -0.0223
# Current minimum: -0.0226
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 306, 'alpha': 0.6349545715310171, 'beta': 1.9392336316930865, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4319.30 column/sec. Elapsed time 5.14 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.26 sec. Users per second: 2948
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 306, 'alpha': 0.6349545715310171, 'beta': 1.9392336316930865, 'normalize_similarity': False} - results: PRECISION: 0.0011042, PRECISION_RECALL_MIN_DEN: 0.0024409, RECALL: 0.0021417, MAP: 0.0003927, MAP_MIN_DEN: 0.0007727, MRR: 0.0037154, NDCG: 0.0017938, F1: 0.0014571, HIT_RATE: 0.0104167, ARHR_ALL_HITS: 0.0038162, NOVELTY: 0.0082094, AVERAGE_POPULARITY: 0.0009893, DIVERSITY_MEAN_INTER_LIST: 0.9905214, DIVERSITY_HERFINDAHL: 0.9990418, COVERAGE_ITEM: 0.1550266, COVERAGE_ITEM_HIT: 0.0044100, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0079126, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0452524, SHANNON_ENTROPY: 10.3489483, RATIO_DIVERSITY_HERFINDAHL: 0.9994023, RATIO_DIVERSITY_GINI: 0.1306453, RATIO_SHANNON_ENTROPY: 0.7974744, RATIO_AVERAGE_POPULARITY: 0.0081129, RATIO_NOVELTY: 0.5136493,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 11.1225
# Function value obtained: -0.0004
# Current minimum: -0.0226
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 195, 'alpha': 1.8024043088578112, 'beta': 0.9229472336593185, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5437.89 column/sec. Elapsed time 4.09 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.38 sec. Users per second: 2844
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'topK': 195, 'alpha': 1.8024043088578112, 'beta': 0.9229472336593185, 'normalize_similarity': True} - results: PRECISION: 0.0030104, PRECISION_RECALL_MIN_DEN: 0.0070916, RECALL: 0.0065153, MAP: 0.0008338, MAP_MIN_DEN: 0.0019189, MRR: 0.0078187, NDCG: 0.0045883, F1: 0.0041181, HIT_RATE: 0.0282292, ARHR_ALL_HITS: 0.0080725, NOVELTY: 0.0073333, AVERAGE_POPULARITY: 0.0051050, DIVERSITY_MEAN_INTER_LIST: 0.9945033, DIVERSITY_HERFINDAHL: 0.9994400, COVERAGE_ITEM: 0.4081991, COVERAGE_ITEM_HIT: 0.0116101, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0214433, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1301188, SHANNON_ENTROPY: 11.7871493, RATIO_DIVERSITY_HERFINDAHL: 0.9998006, RATIO_DIVERSITY_GINI: 0.3756573, RATIO_SHANNON_ENTROPY: 0.9083000, RATIO_AVERAGE_POPULARITY: 0.0418634, RATIO_NOVELTY: 0.4588321,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 9.3597
# Function value obtained: -0.0008
# Current minimum: -0.0226
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 166, 'alpha': 0.0046211577544885704, 'beta': 1.9898266461738023, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 5713.36 column/sec. Elapsed time 3.89 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.82 sec. Users per second: 3401
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 166, 'alpha': 0.0046211577544885704, 'beta': 1.9898266461738023, 'normalize_similarity': True} - results: PRECISION: 0.0009062, PRECISION_RECALL_MIN_DEN: 0.0021007, RECALL: 0.0018759, MAP: 0.0003546, MAP_MIN_DEN: 0.0008095, MRR: 0.0033388, NDCG: 0.0016424, F1: 0.0012221, HIT_RATE: 0.0084375, ARHR_ALL_HITS: 0.0034364, NOVELTY: 0.0081779, AVERAGE_POPULARITY: 0.0010690, DIVERSITY_MEAN_INTER_LIST: 0.9877829, DIVERSITY_HERFINDAHL: 0.9987680, COVERAGE_ITEM: 0.2274773, COVERAGE_ITEM_HIT: 0.0035100, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0064092, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0470157, SHANNON_ENTROPY: 10.3537400, RATIO_DIVERSITY_HERFINDAHL: 0.9991284, RATIO_DIVERSITY_GINI: 0.1357360, RATIO_SHANNON_ENTROPY: 0.7978436, RATIO_AVERAGE_POPULARITY: 0.0087661, RATIO_NOVELTY: 0.5116780,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 8.2569
# Function value obtained: -0.0004
# Current minimum: -0.0226
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 652, 'alpha': 1.4279681347718463, 'beta': 1.9253468012441353, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3016.77 column/sec. Elapsed time 7.37 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.60 sec. Users per second: 2086
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 652, 'alpha': 1.4279681347718463, 'beta': 1.9253468012441353, 'normalize_similarity': True} - results: PRECISION: 0.0014687, PRECISION_RECALL_MIN_DEN: 0.0034462, RECALL: 0.0031061, MAP: 0.0004908, MAP_MIN_DEN: 0.0010615, MRR: 0.0048158, NDCG: 0.0024222, F1: 0.0019944, HIT_RATE: 0.0143750, ARHR_ALL_HITS: 0.0048619, NOVELTY: 0.0079427, AVERAGE_POPULARITY: 0.0016524, DIVERSITY_MEAN_INTER_LIST: 0.9912084, DIVERSITY_HERFINDAHL: 0.9991105, COVERAGE_ITEM: 0.3161732, COVERAGE_ITEM_HIT: 0.0059401, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0109194, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0845211, SHANNON_ENTROPY: 11.1399881, RATIO_DIVERSITY_HERFINDAHL: 0.9994710, RATIO_DIVERSITY_GINI: 0.2440152, RATIO_SHANNON_ENTROPY: 0.8584307, RATIO_AVERAGE_POPULARITY: 0.0135505, RATIO_NOVELTY: 0.4969647,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 16.6134
# Function value obtained: -0.0005
# Current minimum: -0.0226
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 301, 'alpha': 1.7569264849972395, 'beta': 0.31394453374300363, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4334.79 column/sec. Elapsed time 5.13 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.21 sec. Users per second: 2989
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'topK': 301, 'alpha': 1.7569264849972395, 'beta': 0.31394453374300363, 'normalize_similarity': True} - results: PRECISION: 0.0200208, PRECISION_RECALL_MIN_DEN: 0.0512540, RECALL: 0.0485575, MAP: 0.0063602, MAP_MIN_DEN: 0.0172574, MRR: 0.0503987, NDCG: 0.0345484, F1: 0.0283519, HIT_RATE: 0.1637500, ARHR_ALL_HITS: 0.0564026, NOVELTY: 0.0063297, AVERAGE_POPULARITY: 0.0630112, DIVERSITY_MEAN_INTER_LIST: 0.9960016, DIVERSITY_HERFINDAHL: 0.9995898, COVERAGE_ITEM: 0.4264243, COVERAGE_ITEM_HIT: 0.0354154, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.1243868, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1621087, SHANNON_ENTROPY: 12.1487345, RATIO_DIVERSITY_HERFINDAHL: 0.9999505, RATIO_DIVERSITY_GINI: 0.4680135, RATIO_SHANNON_ENTROPY: 0.9361632, RATIO_AVERAGE_POPULARITY: 0.5167190, RATIO_NOVELTY: 0.3960371,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 10.6695
# Function value obtained: -0.0064
# Current minimum: -0.0226
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 866, 'alpha': 1.1008565357024929, 'beta': 0.5098473770727189, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2646.01 column/sec. Elapsed time 8.40 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.81 sec. Users per second: 1998
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 866, 'alpha': 1.1008565357024929, 'beta': 0.5098473770727189, 'normalize_similarity': True} - results: PRECISION: 0.0270208, PRECISION_RECALL_MIN_DEN: 0.0629870, RECALL: 0.0585434, MAP: 0.0093678, MAP_MIN_DEN: 0.0222479, MRR: 0.0666865, NDCG: 0.0443415, F1: 0.0369755, HIT_RATE: 0.2023958, ARHR_ALL_HITS: 0.0788027, NOVELTY: 0.0066555, AVERAGE_POPULARITY: 0.0653153, DIVERSITY_MEAN_INTER_LIST: 0.9958380, DIVERSITY_HERFINDAHL: 0.9995734, COVERAGE_ITEM: 0.6502115, COVERAGE_ITEM_HIT: 0.0500405, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.1537427, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2783790, SHANNON_ENTROPY: 12.7793240, RATIO_DIVERSITY_HERFINDAHL: 0.9999341, RATIO_DIVERSITY_GINI: 0.8036896, RATIO_SHANNON_ENTROPY: 0.9847555, RATIO_AVERAGE_POPULARITY: 0.5356140, RATIO_NOVELTY: 0.4164249,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 18.4876
# Function value obtained: -0.0094
# Current minimum: -0.0226
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 993, 'alpha': 0.7647289548223917, 'beta': 0.7700833567958729, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2555.15 column/sec. Elapsed time 8.70 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 5.14 sec. Users per second: 1867
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 993, 'alpha': 0.7647289548223917, 'beta': 0.7700833567958729, 'normalize_similarity': True} - results: PRECISION: 0.0108542, PRECISION_RECALL_MIN_DEN: 0.0242032, RECALL: 0.0217420, MAP: 0.0035661, MAP_MIN_DEN: 0.0079965, MRR: 0.0279594, NDCG: 0.0170541, F1: 0.0144797, HIT_RATE: 0.0871875, ARHR_ALL_HITS: 0.0314759, NOVELTY: 0.0074811, AVERAGE_POPULARITY: 0.0067914, DIVERSITY_MEAN_INTER_LIST: 0.9981189, DIVERSITY_HERFINDAHL: 0.9998015, COVERAGE_ITEM: 0.6786068, COVERAGE_ITEM_HIT: 0.0378904, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0662288, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.3093442, SHANNON_ENTROPY: 13.0912245, RATIO_DIVERSITY_HERFINDAHL: 1.0001622, RATIO_DIVERSITY_GINI: 0.8930873, RATIO_SHANNON_ENTROPY: 1.0087901, RATIO_AVERAGE_POPULARITY: 0.0556927, RATIO_NOVELTY: 0.4680815,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 19.7041
# Function value obtained: -0.0036
# Current minimum: -0.0226
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 590, 'alpha': 0.4073494407190873, 'beta': 1.5476310536781916, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3160.95 column/sec. Elapsed time 7.03 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.56 sec. Users per second: 2107
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 590, 'alpha': 0.4073494407190873, 'beta': 1.5476310536781916, 'normalize_similarity': True} - results: PRECISION: 0.0017187, PRECISION_RECALL_MIN_DEN: 0.0037127, RECALL: 0.0032245, MAP: 0.0006172, MAP_MIN_DEN: 0.0012347, MRR: 0.0056522, NDCG: 0.0027739, F1: 0.0022423, HIT_RATE: 0.0155208, ARHR_ALL_HITS: 0.0059012, NOVELTY: 0.0080835, AVERAGE_POPULARITY: 0.0012943, DIVERSITY_MEAN_INTER_LIST: 0.9934799, DIVERSITY_HERFINDAHL: 0.9993376, COVERAGE_ITEM: 0.3278733, COVERAGE_ITEM_HIT: 0.0068401, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0117898, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0876372, SHANNON_ENTROPY: 11.2631468, RATIO_DIVERSITY_HERFINDAHL: 0.9996982, RATIO_DIVERSITY_GINI: 0.2530117, RATIO_SHANNON_ENTROPY: 0.8679212, RATIO_AVERAGE_POPULARITY: 0.0106139, RATIO_NOVELTY: 0.5057732,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 15.9902
# Function value obtained: -0.0006
# Current minimum: -0.0226
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 254, 'alpha': 0.18105256475124556, 'beta': 0.2501266954408204, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4885.43 column/sec. Elapsed time 4.55 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.06 sec. Users per second: 3135
# SearchBayesianSkopt: New best config found. Config 25: {'topK': 254, 'alpha': 0.18105256475124556, 'beta': 0.2501266954408204, 'normalize_similarity': True} - results: PRECISION: 0.0532188, PRECISION_RECALL_MIN_DEN: 0.1255274, RECALL: 0.1172449, MAP: 0.0231015, MAP_MIN_DEN: 0.0556571, MRR: 0.1657253, NDCG: 0.0999559, F1: 0.0732077, HIT_RATE: 0.3798958, ARHR_ALL_HITS: 0.1947668, NOVELTY: 0.0048412, AVERAGE_POPULARITY: 0.3427238, DIVERSITY_MEAN_INTER_LIST: 0.9106651, DIVERSITY_HERFINDAHL: 0.9910570, COVERAGE_ITEM: 0.3778688, COVERAGE_ITEM_HIT: 0.0542255, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.2885741, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0541816, SHANNON_ENTROPY: 9.1866561, RATIO_DIVERSITY_HERFINDAHL: 0.9914146, RATIO_DIVERSITY_GINI: 0.1564242, RATIO_SHANNON_ENTROPY: 0.7079099, RATIO_AVERAGE_POPULARITY: 2.8104834, RATIO_NOVELTY: 0.3029070,
#
# EvaluatorHoldout: Processed 9869 (100.0%) in 3.20 sec. Users per second: 3085
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 254, 'alpha': 0.18105256475124556, 'beta': 0.2501266954408204, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0618604, PRECISION_RECALL_MIN_DEN: 0.1311415, RECALL: 0.1196143, MAP: 0.0271507, MAP_MIN_DEN: 0.0580284, MRR: 0.1833294, NDCG: 0.1072151, F1: 0.0815473, HIT_RATE: 0.4175702, ARHR_ALL_HITS: 0.2218773, NOVELTY: 0.0048383, AVERAGE_POPULARITY: 0.3434243, DIVERSITY_MEAN_INTER_LIST: 0.9099456, DIVERSITY_HERFINDAHL: 0.9909853, COVERAGE_ITEM: 0.3850239, COVERAGE_ITEM_HIT: 0.0603006, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.3260801, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.0549243, SHANNON_ENTROPY: 9.1923726, RATIO_DIVERSITY_HERFINDAHL: 0.9913429, RATIO_DIVERSITY_GINI: 0.1585683, RATIO_SHANNON_ENTROPY: 0.7083504, RATIO_AVERAGE_POPULARITY: 2.8162279, RATIO_NOVELTY: 0.3027254,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/SKOPT_test/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 14.9520
# Function value obtained: -0.0231
# Current minimum: -0.0231
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 426, 'alpha': 0.5029705477480803, 'beta': 1.2494653198271637, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3676.34 column/sec. Elapsed time 6.04 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.96 sec. Users per second: 2423
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 426, 'alpha': 0.5029705477480803, 'beta': 1.2494653198271637, 'normalize_similarity': True} - results: PRECISION: 0.0026250, PRECISION_RECALL_MIN_DEN: 0.0053602, RECALL: 0.0046612, MAP: 0.0008958, MAP_MIN_DEN: 0.0018466, MRR: 0.0079404, NDCG: 0.0040667, F1: 0.0033586, HIT_RATE: 0.0232292, ARHR_ALL_HITS: 0.0084149, NOVELTY: 0.0080141, AVERAGE_POPULARITY: 0.0014953, DIVERSITY_MEAN_INTER_LIST: 0.9949203, DIVERSITY_HERFINDAHL: 0.9994817, COVERAGE_ITEM: 0.3941589, COVERAGE_ITEM_HIT: 0.0105301, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0176452, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1159841, SHANNON_ENTROPY: 11.6607303, RATIO_DIVERSITY_HERFINDAHL: 0.9998423, RATIO_DIVERSITY_GINI: 0.3348502, RATIO_SHANNON_ENTROPY: 0.8985583, RATIO_AVERAGE_POPULARITY: 0.0122622, RATIO_NOVELTY: 0.5014315,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 13.6877
# Function value obtained: -0.0009
# Current minimum: -0.0231
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 891, 'alpha': 1.8099301636855456, 'beta': 0.6189876028934566, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2721.65 column/sec. Elapsed time 8.16 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.80 sec. Users per second: 2000
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 891, 'alpha': 1.8099301636855456, 'beta': 0.6189876028934566, 'normalize_similarity': True} - results: PRECISION: 0.0066146, PRECISION_RECALL_MIN_DEN: 0.0174592, RECALL: 0.0164716, MAP: 0.0017566, MAP_MIN_DEN: 0.0045601, MRR: 0.0156671, NDCG: 0.0105749, F1: 0.0094388, HIT_RATE: 0.0596875, ARHR_ALL_HITS: 0.0165722, NOVELTY: 0.0070089, AVERAGE_POPULARITY: 0.0126818, DIVERSITY_MEAN_INTER_LIST: 0.9967956, DIVERSITY_HERFINDAHL: 0.9996692, COVERAGE_ITEM: 0.4844298, COVERAGE_ITEM_HIT: 0.0220502, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0453395, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1885071, SHANNON_ENTROPY: 12.3763997, RATIO_DIVERSITY_HERFINDAHL: 1.0000299, RATIO_DIVERSITY_GINI: 0.5442264, RATIO_SHANNON_ENTROPY: 0.9537067, RATIO_AVERAGE_POPULARITY: 0.1039965, RATIO_NOVELTY: 0.4385381,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 18.0449
# Function value obtained: -0.0018
# Current minimum: -0.0231
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 813, 'alpha': 0.7895193061253414, 'beta': 1.484398400663785, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2777.11 column/sec. Elapsed time 8.00 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.86 sec. Users per second: 1977
# ...
#
# Iteration No: 292 ended. Search finished for the next optimal point.
# Time taken: 19.5008
# Function value obtained: -0.0192
# Current minimum: -0.0268
# Iteration No: 293 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 252, 'alpha': 0.6312502904874563, 'beta': 0.556085012803541, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 4793.04 column/sec. Elapsed time 4.64 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 3.08 sec. Users per second: 3115
# SearchBayesianSkopt: Config 292 is suboptimal. Config: {'topK': 252, 'alpha': 0.6312502904874563, 'beta': 0.556085012803541, 'normalize_similarity': False} - results: PRECISION: 0.0370000, PRECISION_RECALL_MIN_DEN: 0.0836443, RECALL: 0.0776798, MAP: 0.0154472, MAP_MIN_DEN: 0.0347727, MRR: 0.1102129, NDCG: 0.0654213, F1: 0.0501248, HIT_RATE: 0.2669792, ARHR_ALL_HITS: 0.1300406, NOVELTY: 0.0066099, AVERAGE_POPULARITY: 0.0964185, DIVERSITY_MEAN_INTER_LIST: 0.9917014, DIVERSITY_HERFINDAHL: 0.9991598, COVERAGE_ITEM: 0.6794168, COVERAGE_ITEM_HIT: 0.0681757, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.2028011, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.2772827, SHANNON_ENTROPY: 12.5728418, RATIO_DIVERSITY_HERFINDAHL: 0.9995203, RATIO_DIVERSITY_GINI: 0.8005247, RATIO_SHANNON_ENTROPY: 0.9688443, RATIO_AVERAGE_POPULARITY: 0.7906738, RATIO_NOVELTY: 0.4135703,
#
# Iteration No: 293 ended. Search finished for the next optimal point.
# Time taken: 14.4398
# Function value obtained: -0.0154
# Current minimum: -0.0268
# Iteration No: 294 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 42, 'alpha': 0.23841836732797625, 'beta': 0.21167904579065971, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8108.38 column/sec. Elapsed time 2.74 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.35 sec. Users per second: 4089
# SearchBayesianSkopt: Config 293 is suboptimal. Config: {'topK': 42, 'alpha': 0.23841836732797625, 'beta': 0.21167904579065971, 'normalize_similarity': True} - results: PRECISION: 0.0593438, PRECISION_RECALL_MIN_DEN: 0.1334752, RECALL: 0.1238694, MAP: 0.0268106, MAP_MIN_DEN: 0.0609326, MRR: 0.1856888, NDCG: 0.1093562, F1: 0.0802440, HIT_RATE: 0.4046875, ARHR_ALL_HITS: 0.2217901, NOVELTY: 0.0052874, AVERAGE_POPULARITY: 0.1894573, DIVERSITY_MEAN_INTER_LIST: 0.9795631, DIVERSITY_HERFINDAHL: 0.9979461, COVERAGE_ITEM: 0.4251643, COVERAGE_ITEM_HIT: 0.0762758, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.3074062, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0861231, SHANNON_ENTROPY: 10.6682441, RATIO_DIVERSITY_HERFINDAHL: 0.9983062, RATIO_DIVERSITY_GINI: 0.2486402, RATIO_SHANNON_ENTROPY: 0.8220788, RATIO_AVERAGE_POPULARITY: 1.5536321, RATIO_NOVELTY: 0.3308217,
#
# Iteration No: 294 ended. Search finished for the next optimal point.
# Time taken: 9.8524
# Function value obtained: -0.0268
# Current minimum: -0.0268
# Iteration No: 295 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 886, 'alpha': 0.5146707839319687, 'beta': 0.39956055224286813, 'normalize_similarity': False}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 2676.10 column/sec. Elapsed time 8.30 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.69 sec. Users per second: 2045
# SearchBayesianSkopt: Config 294 is suboptimal. Config: {'topK': 886, 'alpha': 0.5146707839319687, 'beta': 0.39956055224286813, 'normalize_similarity': False} - results: PRECISION: 0.0493750, PRECISION_RECALL_MIN_DEN: 0.1183237, RECALL: 0.1109860, MAP: 0.0215038, MAP_MIN_DEN: 0.0531116, MRR: 0.1585098, NDCG: 0.0947423, F1: 0.0683450, HIT_RATE: 0.3626042, ARHR_ALL_HITS: 0.1839139, NOVELTY: 0.0048220, AVERAGE_POPULARITY: 0.4044021, DIVERSITY_MEAN_INTER_LIST: 0.8455574, DIVERSITY_HERFINDAHL: 0.9845469, COVERAGE_ITEM: 0.4445144, COVERAGE_ITEM_HIT: 0.0476105, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.2754392, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0686152, SHANNON_ENTROPY: 8.7601702, RATIO_DIVERSITY_HERFINDAHL: 0.9849022, RATIO_DIVERSITY_GINI: 0.1980946, RATIO_SHANNON_ENTROPY: 0.6750455, RATIO_AVERAGE_POPULARITY: 3.3162722, RATIO_NOVELTY: 0.3017079,
#
# Iteration No: 295 ended. Search finished for the next optimal point.
# Time taken: 23.3764
# Function value obtained: -0.0215
# Current minimum: -0.0268
# Iteration No: 296 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8183.09 column/sec. Elapsed time 2.72 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.32 sec. Users per second: 4132
# SearchBayesianSkopt: New best config found. Config 295: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True} - results: PRECISION: 0.0595000, PRECISION_RECALL_MIN_DEN: 0.1338820, RECALL: 0.1242650, MAP: 0.0268304, MAP_MIN_DEN: 0.0609240, MRR: 0.1852517, NDCG: 0.1094278, F1: 0.0804698, HIT_RATE: 0.4054167, ARHR_ALL_HITS: 0.2215520, NOVELTY: 0.0052939, AVERAGE_POPULARITY: 0.1881774, DIVERSITY_MEAN_INTER_LIST: 0.9798531, DIVERSITY_HERFINDAHL: 0.9979751, COVERAGE_ITEM: 0.4270993, COVERAGE_ITEM_HIT: 0.0769058, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.3079601, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0868656, SHANNON_ENTROPY: 10.6847515, RATIO_DIVERSITY_HERFINDAHL: 0.9983352, RATIO_DIVERSITY_GINI: 0.2507840, RATIO_SHANNON_ENTROPY: 0.8233509, RATIO_AVERAGE_POPULARITY: 1.5431358, RATIO_NOVELTY: 0.3312327,
#
# EvaluatorHoldout: Processed 9869 (100.0%) in 2.34 sec. Users per second: 4210
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0685378, PRECISION_RECALL_MIN_DEN: 0.1409059, RECALL: 0.1277862, MAP: 0.0315921, MAP_MIN_DEN: 0.0652098, MRR: 0.2059632, NDCG: 0.1187282, F1: 0.0892218, HIT_RATE: 0.4438140, ARHR_ALL_HITS: 0.2532958, NOVELTY: 0.0052932, AVERAGE_POPULARITY: 0.1883256, DIVERSITY_MEAN_INTER_LIST: 0.9798354, DIVERSITY_HERFINDAHL: 0.9979736, COVERAGE_ITEM: 0.4360544, COVERAGE_ITEM_HIT: 0.0846908, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.3465738, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.0883504, SHANNON_ENTROPY: 10.6970628, RATIO_DIVERSITY_HERFINDAHL: 0.9983337, RATIO_DIVERSITY_GINI: 0.2550707, RATIO_SHANNON_ENTROPY: 0.8242996, RATIO_AVERAGE_POPULARITY: 1.5443513, RATIO_NOVELTY: 0.3311894,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/SKOPT_test/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 296 ended. Search finished for the next optimal point.
# Time taken: 12.6784
# Function value obtained: -0.0268
# Current minimum: -0.0268
# Iteration No: 297 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 40, 'alpha': 0.2438833961837448, 'beta': 0.22183530066284196, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8111.84 column/sec. Elapsed time 2.74 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.42 sec. Users per second: 3974
# SearchBayesianSkopt: Config 296 is suboptimal. Config: {'topK': 40, 'alpha': 0.2438833961837448, 'beta': 0.22183530066284196, 'normalize_similarity': True} - results: PRECISION: 0.0593542, PRECISION_RECALL_MIN_DEN: 0.1335413, RECALL: 0.1239242, MAP: 0.0268142, MAP_MIN_DEN: 0.0608660, MRR: 0.1855823, NDCG: 0.1093417, F1: 0.0802650, HIT_RATE: 0.4050000, ARHR_ALL_HITS: 0.2217417, NOVELTY: 0.0053016, AVERAGE_POPULARITY: 0.1864619, DIVERSITY_MEAN_INTER_LIST: 0.9802753, DIVERSITY_HERFINDAHL: 0.9980173, COVERAGE_ITEM: 0.4322293, COVERAGE_ITEM_HIT: 0.0766808, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.3076436, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0880911, SHANNON_ENTROPY: 10.7050754, RATIO_DIVERSITY_HERFINDAHL: 0.9983774, RATIO_DIVERSITY_GINI: 0.2543220, RATIO_SHANNON_ENTROPY: 0.8249170, RATIO_AVERAGE_POPULARITY: 1.5290686, RATIO_NOVELTY: 0.3317104,
#
# Iteration No: 297 ended. Search finished for the next optimal point.
# Time taken: 10.1031
# Function value obtained: -0.0268
# Current minimum: -0.0268
# Iteration No: 298 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 37, 'alpha': 0.24968710196864252, 'beta': 0.23672913281000196, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8126.28 column/sec. Elapsed time 2.73 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.32 sec. Users per second: 4146
# SearchBayesianSkopt: Config 297 is suboptimal. Config: {'topK': 37, 'alpha': 0.24968710196864252, 'beta': 0.23672913281000196, 'normalize_similarity': True} - results: PRECISION: 0.0595729, PRECISION_RECALL_MIN_DEN: 0.1337101, RECALL: 0.1240269, MAP: 0.0268211, MAP_MIN_DEN: 0.0608353, MRR: 0.1857116, NDCG: 0.1094056, F1: 0.0804864, HIT_RATE: 0.4075000, ARHR_ALL_HITS: 0.2218351, NOVELTY: 0.0053205, AVERAGE_POPULARITY: 0.1833831, DIVERSITY_MEAN_INTER_LIST: 0.9809370, DIVERSITY_HERFINDAHL: 0.9980835, COVERAGE_ITEM: 0.4401494, COVERAGE_ITEM_HIT: 0.0776258, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.3095426, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0910382, SHANNON_ENTROPY: 10.7570269, RATIO_DIVERSITY_HERFINDAHL: 0.9984436, RATIO_DIVERSITY_GINI: 0.2628304, RATIO_SHANNON_ENTROPY: 0.8289203, RATIO_AVERAGE_POPULARITY: 1.5038209, RATIO_NOVELTY: 0.3328933,
#
# Iteration No: 298 ended. Search finished for the next optimal point.
# Time taken: 9.9654
# Function value obtained: -0.0268
# Current minimum: -0.0268
# Iteration No: 299 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 35, 'alpha': 0.26724409185439124, 'beta': 0.2867932242273855, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 8275.22 column/sec. Elapsed time 2.69 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 2.37 sec. Users per second: 4051
# SearchBayesianSkopt: Config 298 is suboptimal. Config: {'topK': 35, 'alpha': 0.26724409185439124, 'beta': 0.2867932242273855, 'normalize_similarity': True} - results: PRECISION: 0.0590417, PRECISION_RECALL_MIN_DEN: 0.1326159, RECALL: 0.1229776, MAP: 0.0264664, MAP_MIN_DEN: 0.0602849, MRR: 0.1834838, NDCG: 0.1084216, F1: 0.0797806, HIT_RATE: 0.4037500, ARHR_ALL_HITS: 0.2191069, NOVELTY: 0.0053281, AVERAGE_POPULARITY: 0.1829042, DIVERSITY_MEAN_INTER_LIST: 0.9814658, DIVERSITY_HERFINDAHL: 0.9981364, COVERAGE_ITEM: 0.4499595, COVERAGE_ITEM_HIT: 0.0767258, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.3066941, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.0929906, SHANNON_ENTROPY: 10.7773486, RATIO_DIVERSITY_HERFINDAHL: 0.9984965, RATIO_DIVERSITY_GINI: 0.2684671, RATIO_SHANNON_ENTROPY: 0.8304863, RATIO_AVERAGE_POPULARITY: 1.4998936, RATIO_NOVELTY: 0.3333693,
#
# Iteration No: 299 ended. Search finished for the next optimal point.
# Time taken: 10.1309
# Function value obtained: -0.0265
# Current minimum: -0.0268
# Iteration No: 300 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 520, 'alpha': 1.9994012780909534, 'beta': 0.5322236186996864, 'normalize_similarity': True}
# RP3betaRecommender: URM Detected 343 ( 2.7%) users with no interactions.
# RP3betaRecommender: URM Detected 195 ( 0.9%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3284.84 column/sec. Elapsed time 6.77 sec
# EvaluatorHoldout: Processed 9600 (100.0%) in 4.01 sec. Users per second: 2394
# SearchBayesianSkopt: Config 299 is suboptimal. Config: {'topK': 520, 'alpha': 1.9994012780909534, 'beta': 0.5322236186996864, 'normalize_similarity': True} - results: PRECISION: 0.0075417, PRECISION_RECALL_MIN_DEN: 0.0207538, RECALL: 0.0196881, MAP: 0.0020387, MAP_MIN_DEN: 0.0055179, MRR: 0.0183078, NDCG: 0.0125238, F1: 0.0109058, HIT_RATE: 0.0684375, ARHR_ALL_HITS: 0.0193069, NOVELTY: 0.0068353, AVERAGE_POPULARITY: 0.0198272, DIVERSITY_MEAN_INTER_LIST: 0.9965019, DIVERSITY_HERFINDAHL: 0.9996398, COVERAGE_ITEM: 0.4373144, COVERAGE_ITEM_HIT: 0.0225452, ITEMS_IN_GT: 0.6822968, COVERAGE_USER: 0.7596139, COVERAGE_USER_HIT: 0.0519861, USERS_IN_GT: 0.7596139, DIVERSITY_GINI: 0.1681140, SHANNON_ENTROPY: 12.2212023, RATIO_DIVERSITY_HERFINDAHL: 1.0000005, RATIO_DIVERSITY_GINI: 0.4853508, RATIO_SHANNON_ENTROPY: 0.9417475, RATIO_AVERAGE_POPULARITY: 0.1625913, RATIO_NOVELTY: 0.4276710,
#
# Iteration No: 300 ended. Search finished for the next optimal point.
# Time taken: 18.7127
# Function value obtained: -0.0020
# Current minimum: -0.0268
# SearchBayesianSkopt: Search complete. Best config is 295: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True}
#
# RP3betaRecommender: URM Detected 154 ( 1.2%) users with no interactions.
# RP3betaRecommender: URM Detected 86 ( 0.4%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 22222 (100.0%), 7551.58 column/sec. Elapsed time 2.94 sec
# EvaluatorHoldout: Processed 9869 (100.0%) in 2.35 sec. Users per second: 4208
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 41, 'alpha': 0.24025759098180052, 'beta': 0.21463311953617964, 'normalize_similarity': True} - results:
# CUTOFF: 10 - PRECISION: 0.0782146, PRECISION_RECALL_MIN_DEN: 0.1604451, RECALL: 0.1448284, MAP: 0.0383880, MAP_MIN_DEN: 0.0782973, MRR: 0.2374257, NDCG: 0.1380660, F1: 0.1015741, HIT_RATE: 0.4775560, ARHR_ALL_HITS: 0.2989765, NOVELTY: 0.0053065, AVERAGE_POPULARITY: 0.1817120, DIVERSITY_MEAN_INTER_LIST: 0.9811599, DIVERSITY_HERFINDAHL: 0.9981060, COVERAGE_ITEM: 0.4182342, COVERAGE_ITEM_HIT: 0.0970660, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.3729229, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.0875020, SHANNON_ENTROPY: 10.7565692, RATIO_DIVERSITY_HERFINDAHL: 0.9984660, RATIO_DIVERSITY_GINI: 0.2502471, RATIO_SHANNON_ENTROPY: 0.8283610, RATIO_AVERAGE_POPULARITY: 1.4716037, RATIO_NOVELTY: 0.2820400,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/SKOPT_test/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model_last'
# RP3betaRecommender: Saving complete

# %%
recommender = RP3betaRecommender(urm_train_validation)
recommender.load_model(output_folder_path, 
                file_name = recommender.RECOMMENDER_NAME + "_best_model.zip")
# Out:
# RP3betaRecommender: URM Detected 154 ( 1.2%) users with no interactions.
# RP3betaRecommender: URM Detected 86 ( 0.4%) items with no interactions.
# RP3betaRecommender: Loading model from file 'result_experiments/SKOPT_test/RP3betaRecommender_best_model.zip'
# RP3betaRecommender: Loading complete

# %%
evaluator_test.evaluateRecommender(recommender)
# Out:
# EvaluatorHoldout: Processed 9869 (100.0%) in 2.45 sec. Users per second: 4030
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#  cutoff
#  10      0.076431                 0.155019  0.139553  0.037291      0.0753
#
#               MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#  cutoff                                                        ...
#  10      0.232035  0.133691  0.098768  0.468133      0.291401  ...
#
#         COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#  cutoff
#  10          0.780899          0.365564    0.780899       0.087325
#
#         SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#  cutoff
#  10           10.691689                   0.998314             0.249742
#
#         RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#  cutoff
#  10                  0.823365                 1.532302      0.280926
#
#  [1 rows x 27 columns],
#  'CUTOFF: 10 - PRECISION: 0.0764312, PRECISION_RECALL_MIN_DEN: 0.1550195, RECALL: 0.1395533, MAP: 0.0372912, MAP_MIN_DEN: 0.0752996, MRR: 0.2320348, NDCG: 0.1336913, F1: 0.0987685, HIT_RATE: 0.4681325, ARHR_ALL_HITS: 0.2914006, NOVELTY: 0.0052856, AVERAGE_POPULARITY: 0.1892070, DIVERSITY_MEAN_INTER_LIST: 0.9796404, DIVERSITY_HERFINDAHL: 0.9979541, COVERAGE_ITEM: 0.4309243, COVERAGE_ITEM_HIT: 0.0914859, ITEMS_IN_GT: 0.7282873, COVERAGE_USER: 0.7808989, COVERAGE_USER_HIT: 0.3655642, USERS_IN_GT: 0.7808989, DIVERSITY_GINI: 0.0873253, SHANNON_ENTROPY: 10.6916890, RATIO_DIVERSITY_HERFINDAHL: 0.9983140, RATIO_DIVERSITY_GINI: 0.2497419, RATIO_SHANNON_ENTROPY: 0.8233646, RATIO_AVERAGE_POPULARITY: 1.5323022, RATIO_NOVELTY: 0.2809262, \n')
